# %%
from sklearn.ensemble import RandomForestClassifier
#import deepchem as dc
import numpy as np
import pandas as pd
import tempfile
#import chemprop
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import backend as K
from tensorflow.keras import initializers
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import os
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# %%
def ROC_AUC(y_true, y_score):
	auc = roc_auc_score(y_true, y_score)
	return auc

# %%
fingerprint_list = ['MorganFP', 'RDkitFP', 'AtomPairFP', 'TorsionFP', 'AvalonFP', 
'EstateFP', 'MACCSFP', 'PharmacoErGFP', 'PharmacoPFP', 'PubChemFP', 'MHFP6', 'MAP4']
descriptor_list = ['Property', 'Constitution', 'Autocorr', 'Fragment', 'Charge', 
'Estate', 'MOE', 'Connectivity', 'Topology', 'Kappa', 'Path', 'Matrix', 'InfoContent']

# %%
# free GPU memory
from numba import cuda 
device = cuda.get_current_device()
device.reset()
cuda.close()

# %%
def fetch_y_train_val_test_Ext(data_type,fold):
    i = fold; b = data_type
    #if b=='Ext': true_file = 'Ext.csv'
    if b[:3]=='Ext': true_file = f'{b}.csv'
    else: true_file = f'rand_/fold_{i}/{b}_full.csv' 
    print('true_file = ',true_file)
    df = pd.read_csv(true_file)
    y = df.iloc[:,1].astype('int').values
    return y

# %%
def fetch_X_train_val_test_Ext(data_type,fold):
    #i = 0;b = data_type = 'train'
    i = fold; b = data_type
    y_file = f'rand_/fold_{i}/{b}_full.csv'    
    X_train_files = []
    X_train_dfl = []
    for model,feature in zip(models,features):
        pred_file = f'{model}/p_{data_type}_{feature}_fold{i}.csv'
        X_train_files.append(pred_file)
        if model=='DMPNN':X_train_dfl.append(pd.read_csv(pred_file).iloc[:,1])
        else:X_train_dfl.append(pd.read_csv(pred_file))
    X_train_df = pd.concat(X_train_dfl,axis=1)
    return X_train_df.values

# %%
def fetch_X_train_val_test_Ext_topN(data_type,fold,topN):
    #i = 0;b = data_type = 'train'
    i = fold; b = data_type
    y_file = f'rand_/fold_{i}/{b}_full.csv'    
    X_train_files = []
    X_train_dfl = []
    for model,feature in zip(models[:topN],features[:topN]):
        pred_file = f'{model}/p_{data_type}_{feature}_fold{i}.csv'
        X_train_files.append(pred_file)
        if model=='DMPNN':X_train_dfl.append(pd.read_csv(pred_file).iloc[:,1])
        else:X_train_dfl.append(pd.read_csv(pred_file))
    #print('X_train_files = ',X_train_files)
    X_train_df = pd.concat(X_train_dfl,axis=1)
    return X_train_df.values

# %%
df = pd.read_csv('grouped_sort_roc.csv')
features = df['feat'].fillna('').values  ## change 'nan' to ''
models = df['model'].values

# %% [markdown]
# # Train fcnn ensemble model

# %% [markdown]
# test  n_Dense, seem  increase before 600, after that litte grow

# %%
# seem the keras model can only run once inside a function, otherwise will get GPU errors.
def run_one_keras_fcnn(n_Dense,i):
    model = Sequential()
    model.add(Dense(n_Dense, input_shape=(n_feats,), activation='relu'),)
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['AUC'])
    #print(model.summary)
    #get X and Y (main set and external set)
    y_train_2dim=y_train[:,np.newaxis]  ### change shape from(2769,) to (2769, 1)
    y_val_2dim = y_val[:,np.newaxis]
    print(y_train_2dim.shape)
    #model.fit(X_T, y_T_2dim,batch_size=4096,verbose=0, epochs=100)
    ### using early stop by monitor val_loss of X_valid, y_valid_2dim
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    model.fit(X_train, y_train_2dim, batch_size=4096, verbose=0, epochs=200, 
              validation_data=(X_val, y_val_2dim), callbacks=[early_stopping])    
    ## prediction
    y_prob_train = model.predict(X_train) 
    train_roc_auc = ROC_AUC(y_train,y_prob_train[:, 0])
    print('train_roc_auc = ', train_roc_auc )
    y_prob_val=model.predict(X_val)  ## no need other parameters here
    val_roc_auc = ROC_AUC(y_val,y_prob_val[:, 0])
    y_prob_test=model.predict(X_test)  
    test_roc_auc = ROC_AUC(y_test,y_prob_test[:, 0])
    print('test_roc_auc, val_roc_auc = ', test_roc_auc, val_roc_auc)
    y_prob_Ext=model.predict(X_Ext)  ## no need other parameters here
    Ext_roc_auc = ROC_AUC(y_Ext,y_prob_Ext[:, 0])
    print('Ext_roc_auc = ', Ext_roc_auc)    
    ## save predition
    if not os.path.exists(f'esb/{n_Dense}'):os.mkdir(f'esb/{n_Dense}')
    pd.DataFrame(y_prob_train[:,0],columns=['prob']).to_csv(f'esb/{n_Dense}/p_train_Top{n_feats}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_val[:, 0],columns=['prob']).to_csv(f'esb/{n_Dense}/p_val_Top{n_feats}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_test[:,0],columns=['prob']).to_csv(f'esb/{n_Dense}/p_test_Top{n_feats}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_Ext[:,0],columns=['prob']).to_csv(f'esb/{n_Dense}/p_Ext_Top{n_feats}_fold{i}.csv',index=False)   
    ## save model
    model_save_name = f'esb/{n_Dense}/model_esbTop{n_feats}_fold{i}.h5'
    model.save(model_save_name)    
    model = ''
    return train_roc_auc,val_roc_auc,test_roc_auc,Ext_roc_auc

# %%
if not os.path.exists('esb'):os.mkdir('esb')
performance = []
num_folds = 5
#n_Dense = 800
for n_Dense in [200,400,600,800,1000,1200]:
    for i in range(num_folds): 
        print(f'processing n_Dense:{n_Dense}, i: {i}')
        X_train = fetch_X_train_val_test_Ext('train',i)
        y_train = fetch_y_train_val_test_Ext('train',i)
        X_val = fetch_X_train_val_test_Ext('val',i)
        y_val = fetch_y_train_val_test_Ext('val',i)
        X_test = fetch_X_train_val_test_Ext('test',i)
        y_test = fetch_y_train_val_test_Ext('test',i)
        X_Ext = fetch_X_train_val_test_Ext('Ext',i)
        y_Ext = fetch_y_train_val_test_Ext('Ext',i)
        n_feats = X_train.shape[1]
        train_roc_auc,val_roc_auc,test_roc_auc,Ext_roc_auc = run_one_keras_fcnn(n_Dense,i)
        results = {'fold':i,'Top_n_feats':n_feats,'n_Dense':n_Dense,'train_roc_auc':train_roc_auc,
        'val_roc_auc':val_roc_auc,"test_roc_auc":test_roc_auc,'Ext_roc_auc':Ext_roc_auc}
        print('results = ',results)
        performance.append(results)
        pd.DataFrame([results]).to_csv('esb/esb_append.csv',mode='a')
pd.DataFrame(performance).to_csv('esb/esb.csv',mode='a')
# Out:
# processing n_Dense:200, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# 2023-01-26 17:04:19.984735: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-26 17:04:22.636299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8089 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:25:00.0, compute capability: 8.6
# 2023-01-26 17:04:22.638762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 8089 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:61:00.0, compute capability: 8.6
# 2023-01-26 17:04:22.640102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 8089 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2023-01-26 17:04:22.641567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 14245 MB memory:  -> device: 3, name: NVIDIA RTX A4000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-01-26 17:04:22.642801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 6116 MB memory:  -> device: 4, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:e1:00.0, compute capability: 8.6
# (2769, 1)
# 2023-01-26 17:04:25.714659: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 87/87 [==============================] - 0s 943us/step
# train_roc_auc =  0.9999800933773729
# 11/11 [==============================] - 0s 861us/step
# 11/11 [==============================] - 0s 826us/step
# test_roc_auc, val_roc_auc =  0.9728431372549018 0.9345446075005824
# 14/14 [==============================] - 0s 962us/step
# Ext_roc_auc =  0.9312624141187198
# results =  {'fold': 0, 'Top_n_feats': 151, 'n_Dense': 200, 'train_roc_auc': 0.9999800933773729, 'val_roc_auc': 0.9345446075005824, 'test_roc_auc': 0.9728431372549018, 'Ext_roc_auc': 0.9312624141187198}
# processing n_Dense:200, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 903us/step
# train_roc_auc =  0.9996919679706942
# 11/11 [==============================] - 0s 853us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9117647058823529 0.9226448403145562
# 14/14 [==============================] - 0s 860us/step
# Ext_roc_auc =  0.9393702582136694
# results =  {'fold': 1, 'Top_n_feats': 151, 'n_Dense': 200, 'train_roc_auc': 0.9996919679706942, 'val_roc_auc': 0.9226448403145562, 'test_roc_auc': 0.9117647058823529, 'Ext_roc_auc': 0.9393702582136694}
# processing n_Dense:200, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999741226040576
# 11/11 [==============================] - 0s 843us/step
# 11/11 [==============================] - 0s 975us/step
# test_roc_auc, val_roc_auc =  0.9660894660894661 0.9558326709062004
# 14/14 [==============================] - 0s 793us/step
# Ext_roc_auc =  0.9436032691869362
# results =  {'fold': 2, 'Top_n_feats': 151, 'n_Dense': 200, 'train_roc_auc': 0.9999741226040576, 'val_roc_auc': 0.9558326709062004, 'test_roc_auc': 0.9660894660894661, 'Ext_roc_auc': 0.9436032691869362}
# processing n_Dense:200, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 883us/step
# train_roc_auc =  0.9999119514768416
# 11/11 [==============================] - 0s 897us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.925749063670412 0.9331871345029239
# 14/14 [==============================] - 0s 979us/step
# Ext_roc_auc =  0.9078180456513952
# results =  {'fold': 3, 'Top_n_feats': 151, 'n_Dense': 200, 'train_roc_auc': 0.9999119514768416, 'val_roc_auc': 0.9331871345029239, 'test_roc_auc': 0.925749063670412, 'Ext_roc_auc': 0.9078180456513952}
# processing n_Dense:200, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 719us/step
# train_roc_auc =  0.9999577378208084
# 11/11 [==============================] - 0s 973us/step
# 11/11 [==============================] - 0s 846us/step
# test_roc_auc, val_roc_auc =  0.9420604743798661 0.9419926199261993
# 14/14 [==============================] - 0s 837us/step
# Ext_roc_auc =  0.9183680114616912
# results =  {'fold': 4, 'Top_n_feats': 151, 'n_Dense': 200, 'train_roc_auc': 0.9999577378208084, 'val_roc_auc': 0.9419926199261993, 'test_roc_auc': 0.9420604743798661, 'Ext_roc_auc': 0.9183680114616912}
# processing n_Dense:400, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 954us/step
# train_roc_auc =  0.9999954061640092
# 11/11 [==============================] - 0s 901us/step
# 11/11 [==============================] - 0s 938us/step
# test_roc_auc, val_roc_auc =  0.9747058823529412 0.9348241323084091
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9228940770407996
# results =  {'fold': 0, 'Top_n_feats': 151, 'n_Dense': 400, 'train_roc_auc': 0.9999954061640092, 'val_roc_auc': 0.9348241323084091, 'test_roc_auc': 0.9747058823529412, 'Ext_roc_auc': 0.9228940770407996}
# processing n_Dense:400, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 980us/step
# train_roc_auc =  0.9998312978617003
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 987us/step
# test_roc_auc, val_roc_auc =  0.9131372549019607 0.9235542716524903
# 14/14 [==============================] - 0s 878us/step
# Ext_roc_auc =  0.9382631630360457
# results =  {'fold': 1, 'Top_n_feats': 151, 'n_Dense': 400, 'train_roc_auc': 0.9998312978617003, 'val_roc_auc': 0.9235542716524903, 'test_roc_auc': 0.9131372549019607, 'Ext_roc_auc': 0.9382631630360457}
# processing n_Dense:400, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 898us/step
# train_roc_auc =  0.9999802114031029
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9661856661856661 0.9569753577106518
# 14/14 [==============================] - 0s 902us/step
# Ext_roc_auc =  0.9292435935007
# results =  {'fold': 2, 'Top_n_feats': 151, 'n_Dense': 400, 'train_roc_auc': 0.9999802114031029, 'val_roc_auc': 0.9569753577106518, 'test_roc_auc': 0.9661856661856661, 'Ext_roc_auc': 0.9292435935007}
# processing n_Dense:400, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 975us/step
# train_roc_auc =  0.9999448739681096
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 874us/step
# test_roc_auc, val_roc_auc =  0.9254681647940075 0.9450292397660819
# 14/14 [==============================] - 0s 848us/step
# Ext_roc_auc =  0.9351698088632738
# results =  {'fold': 3, 'Top_n_feats': 151, 'n_Dense': 400, 'train_roc_auc': 0.9999448739681096, 'val_roc_auc': 0.9450292397660819, 'test_roc_auc': 0.9254681647940075, 'Ext_roc_auc': 0.9351698088632738}
# processing n_Dense:400, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 942us/step
# train_roc_auc =  0.999971569079453
# 11/11 [==============================] - 0s 937us/step
# 11/11 [==============================] - 0s 869us/step
# test_roc_auc, val_roc_auc =  0.9399330074235017 0.9465190651906519
# 14/14 [==============================] - 0s 821us/step
# Ext_roc_auc =  0.926247924196542
# results =  {'fold': 4, 'Top_n_feats': 151, 'n_Dense': 400, 'train_roc_auc': 0.999971569079453, 'val_roc_auc': 0.9465190651906519, 'test_roc_auc': 0.9399330074235017, 'Ext_roc_auc': 0.926247924196542}
# processing n_Dense:600, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 869us/step
# train_roc_auc =  0.999996171803341
# 11/11 [==============================] - 0s 838us/step
# 11/11 [==============================] - 0s 856us/step
# test_roc_auc, val_roc_auc =  0.9754901960784313 0.9359888190076869
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9340952753085214
# results =  {'fold': 0, 'Top_n_feats': 151, 'n_Dense': 600, 'train_roc_auc': 0.999996171803341, 'val_roc_auc': 0.9359888190076869, 'test_roc_auc': 0.9754901960784313, 'Ext_roc_auc': 0.9340952753085214}
# processing n_Dense:600, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 929us/step
# train_roc_auc =  0.99985012622535
# 11/11 [==============================] - 0s 952us/step
# 11/11 [==============================] - 0s 972us/step
# test_roc_auc, val_roc_auc =  0.9117156862745098 0.9277269566147756
# 14/14 [==============================] - 0s 796us/step
# Ext_roc_auc =  0.9412588323402038
# results =  {'fold': 1, 'Top_n_feats': 151, 'n_Dense': 600, 'train_roc_auc': 0.99985012622535, 'val_roc_auc': 0.9277269566147756, 'test_roc_auc': 0.9117156862745098, 'Ext_roc_auc': 0.9412588323402038}
# processing n_Dense:600, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 926us/step
# train_roc_auc =  0.9999695560047737
# 11/11 [==============================] - 0s 909us/step
# 11/11 [==============================] - 0s 955us/step
# test_roc_auc, val_roc_auc =  0.9676286676286677 0.9582174085850557
# 14/14 [==============================] - 0s 900us/step
# Ext_roc_auc =  0.9418123799290157
# results =  {'fold': 2, 'Top_n_feats': 151, 'n_Dense': 600, 'train_roc_auc': 0.9999695560047737, 'val_roc_auc': 0.9582174085850557, 'test_roc_auc': 0.9676286676286677, 'Ext_roc_auc': 0.9418123799290157}
# processing n_Dense:600, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 852us/step
# train_roc_auc =  0.9999448739681096
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 981us/step
# test_roc_auc, val_roc_auc =  0.9302902621722846 0.9384990253411306
# 14/14 [==============================] - 0s 932us/step
# Ext_roc_auc =  0.9488456904692129
# results =  {'fold': 3, 'Top_n_feats': 151, 'n_Dense': 600, 'train_roc_auc': 0.9999448739681096, 'val_roc_auc': 0.9384990253411306, 'test_roc_auc': 0.9302902621722846, 'Ext_roc_auc': 0.9488456904692129}
# processing n_Dense:600, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 916us/step
# train_roc_auc =  0.9999754110957431
# 11/11 [==============================] - 0s 923us/step
# 11/11 [==============================] - 0s 932us/step
# test_roc_auc, val_roc_auc =  0.9392087633532501 0.947109471094711
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9210055029142653
# results =  {'fold': 4, 'Top_n_feats': 151, 'n_Dense': 600, 'train_roc_auc': 0.9999754110957431, 'val_roc_auc': 0.947109471094711, 'test_roc_auc': 0.9392087633532501, 'Ext_roc_auc': 0.9210055029142653}
# processing n_Dense:800, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 853us/step
# train_roc_auc =  0.9999900466886865
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9752450980392158 0.9332867458653622
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9341603985542639
# results =  {'fold': 0, 'Top_n_feats': 151, 'n_Dense': 800, 'train_roc_auc': 0.9999900466886865, 'val_roc_auc': 0.9332867458653622, 'test_roc_auc': 0.9752450980392158, 'Ext_roc_auc': 0.9341603985542639}
# processing n_Dense:800, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 997us/step
# train_roc_auc =  0.9998900423562869
# 11/11 [==============================] - 0s 846us/step
# 11/11 [==============================] - 0s 872us/step
# test_roc_auc, val_roc_auc =  0.916813725490196 0.9268175252768416
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9303181270554525
# results =  {'fold': 1, 'Top_n_feats': 151, 'n_Dense': 800, 'train_roc_auc': 0.9998900423562869, 'val_roc_auc': 0.9268175252768416, 'test_roc_auc': 0.916813725490196, 'Ext_roc_auc': 0.9303181270554525}
# processing n_Dense:800, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999733615041769
# 11/11 [==============================] - 0s 930us/step
# 11/11 [==============================] - 0s 902us/step
# test_roc_auc, val_roc_auc =  0.969023569023569 0.955981717011129
# 14/14 [==============================] - 0s 943us/step
# Ext_roc_auc =  0.9456220898049559
# results =  {'fold': 2, 'Top_n_feats': 151, 'n_Dense': 800, 'train_roc_auc': 0.9999733615041769, 'val_roc_auc': 0.955981717011129, 'test_roc_auc': 0.969023569023569, 'Ext_roc_auc': 0.9456220898049559}
# processing n_Dense:800, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999425770501141
# 11/11 [==============================] - 0s 881us/step
# 11/11 [==============================] - 0s 850us/step
# test_roc_auc, val_roc_auc =  0.9290262172284645 0.9417153996101365
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9462733222623816
# results =  {'fold': 3, 'Top_n_feats': 151, 'n_Dense': 800, 'train_roc_auc': 0.9999425770501141, 'val_roc_auc': 0.9417153996101365, 'test_roc_auc': 0.9290262172284645, 'Ext_roc_auc': 0.9462733222623816}
# processing n_Dense:800, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 917us/step
# train_roc_auc =  0.999973105885969
# 11/11 [==============================] - 0s 924us/step
# 11/11 [==============================] - 0s 891us/step
# test_roc_auc, val_roc_auc =  0.9321473836682963 0.9404182041820418
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9295366481065417
# results =  {'fold': 4, 'Top_n_feats': 151, 'n_Dense': 800, 'train_roc_auc': 0.999973105885969, 'val_roc_auc': 0.9404182041820418, 'test_roc_auc': 0.9321473836682963, 'Ext_roc_auc': 0.9295366481065417}
# processing n_Dense:1000, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 900us/step
# train_roc_auc =  0.999996171803341
# 11/11 [==============================] - 0s 840us/step
# 11/11 [==============================] - 0s 985us/step
# test_roc_auc, val_roc_auc =  0.9729411764705883 0.9363615187514558
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9316857152160463
# results =  {'fold': 0, 'Top_n_feats': 151, 'n_Dense': 1000, 'train_roc_auc': 0.999996171803341, 'val_roc_auc': 0.9363615187514558, 'test_roc_auc': 0.9729411764705883, 'Ext_roc_auc': 0.9316857152160463}
# processing n_Dense:1000, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9998779922035512
# 11/11 [==============================] - 0s 901us/step
# 11/11 [==============================] - 0s 902us/step
# test_roc_auc, val_roc_auc =  0.9127450980392157 0.9282886642058525
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9320438930676306
# results =  {'fold': 1, 'Top_n_feats': 151, 'n_Dense': 1000, 'train_roc_auc': 0.9998779922035512, 'val_roc_auc': 0.9282886642058525, 'test_roc_auc': 0.9127450980392157, 'Ext_roc_auc': 0.9320438930676306}
# processing n_Dense:1000, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 931us/step
# train_roc_auc =  0.9999764059036995
# 11/11 [==============================] - 0s 947us/step
# 11/11 [==============================] - 0s 867us/step
# test_roc_auc, val_roc_auc =  0.9678691678691678 0.9551868044515104
# 14/14 [==============================] - 0s 866us/step
# Ext_roc_auc =  0.9472827325713914
# results =  {'fold': 2, 'Top_n_feats': 151, 'n_Dense': 1000, 'train_roc_auc': 0.9999764059036995, 'val_roc_auc': 0.9551868044515104, 'test_roc_auc': 0.9678691678691678, 'Ext_roc_auc': 0.9472827325713914}
# processing n_Dense:1000, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 950us/step
# train_roc_auc =  0.9999525303614277
# 11/11 [==============================] - 0s 947us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9303370786516854 0.9389376218323587
# 14/14 [==============================] - 0s 816us/step
# Ext_roc_auc =  0.9493666764351534
# results =  {'fold': 3, 'Top_n_feats': 151, 'n_Dense': 1000, 'train_roc_auc': 0.9999525303614277, 'val_roc_auc': 0.9389376218323587, 'test_roc_auc': 0.9303370786516854, 'Ext_roc_auc': 0.9493666764351534}
# processing n_Dense:1000, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 917us/step
# train_roc_auc =  0.9999761794990011
# 11/11 [==============================] - 0s 855us/step
# 11/11 [==============================] - 0s 883us/step
# test_roc_auc, val_roc_auc =  0.9361759913090711 0.9417958179581796
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9277783204714923
# results =  {'fold': 4, 'Top_n_feats': 151, 'n_Dense': 1000, 'train_roc_auc': 0.9999761794990011, 'val_roc_auc': 0.9417958179581796, 'test_roc_auc': 0.9361759913090711, 'Ext_roc_auc': 0.9277783204714923}
# processing n_Dense:1200, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 999us/step
# train_roc_auc =  0.9999954061640092
# 11/11 [==============================] - 0s 925us/step
# 11/11 [==============================] - 0s 973us/step
# test_roc_auc, val_roc_auc =  0.9724019607843137 0.9344980200326113
# 14/14 [==============================] - 0s 784us/step
# Ext_roc_auc =  0.9359838494350559
# results =  {'fold': 0, 'Top_n_feats': 151, 'n_Dense': 1200, 'train_roc_auc': 0.9999954061640092, 'val_roc_auc': 0.9344980200326113, 'test_roc_auc': 0.9724019607843137, 'Ext_roc_auc': 0.9359838494350559}
# processing n_Dense:1200, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 873us/step
# train_roc_auc =  0.9998365698035223
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 887us/step
# test_roc_auc, val_roc_auc =  0.9093137254901961 0.9254266302894132
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9377421770701051
# results =  {'fold': 1, 'Top_n_feats': 151, 'n_Dense': 1200, 'train_roc_auc': 0.9998365698035223, 'val_roc_auc': 0.9254266302894132, 'test_roc_auc': 0.9093137254901961, 'Ext_roc_auc': 0.9377421770701051}
# processing n_Dense:1200, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999703171046542
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 856us/step
# test_roc_auc, val_roc_auc =  0.9664742664742665 0.9571244038155803
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9499853472697078
# results =  {'fold': 2, 'Top_n_feats': 151, 'n_Dense': 1200, 'train_roc_auc': 0.9999703171046542, 'val_roc_auc': 0.9571244038155803, 'test_roc_auc': 0.9664742664742665, 'Ext_roc_auc': 0.9499853472697078}
# processing n_Dense:1200, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 934us/step
# train_roc_auc =  0.9999586554760822
# 11/11 [==============================] - 0s 858us/step
# 11/11 [==============================] - 0s 945us/step
# test_roc_auc, val_roc_auc =  0.9295411985018727 0.9418615984405458
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9457523362964411
# results =  {'fold': 3, 'Top_n_feats': 151, 'n_Dense': 1200, 'train_roc_auc': 0.9999586554760822, 'val_roc_auc': 0.9418615984405458, 'test_roc_auc': 0.9295411985018727, 'Ext_roc_auc': 0.9457523362964411}
# processing n_Dense:1200, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 920us/step
# train_roc_auc =  0.999974642692485
# 11/11 [==============================] - 0s 839us/step
# 11/11 [==============================] - 0s 846us/step
# test_roc_auc, val_roc_auc =  0.9369002353793228 0.9449938499384993
# 14/14 [==============================] - 0s 970us/step
# Ext_roc_auc =  0.9262804858194132
# results =  {'fold': 4, 'Top_n_feats': 151, 'n_Dense': 1200, 'train_roc_auc': 0.999974642692485, 'val_roc_auc': 0.9449938499384993, 'test_roc_auc': 0.9369002353793228, 'Ext_roc_auc': 0.9262804858194132}

# %% [markdown]
# # load model and pred

# %%
# seem the keras model can only run once inside a function, otherwise will get GPU errors.
def load_one_keras_fcnn_pred_ext_files(n_Dense,i,ext_files):
    model_save_name = f'esb/{n_Dense}/model_esbTop{n_feats}_fold{i}.h5'
    model = tf.keras.models.load_model(model_save_name)
    rocs_dic = {}
    for ext_file in ext_files:
        ext_base = ext_file.replace('.csv','')
        print(f'processing n_Dense:{n_Dense}, i: {i}, ext_base:{ext_base}')
        X_e = fetch_X_train_val_test_Ext_topN(ext_base,i,topN)
        #fetch_X_train_val_test_Ext(ext_base,i)                
        y_e= fetch_y_train_val_test_Ext(ext_base,i)
        #print('n_feats,X_e.shape = ',n_feats, X_e.shape)
        assert n_feats == X_e.shape[1]
        y_prob_e=model.predict(X_e)  ## no need other parameters here
        e_roc_auc = ROC_AUC(y_e,y_prob_e[:, 0])
        print(f'{ext_base}_roc_auc = ', e_roc_auc) 
        rocs_dic.update({f'{ext_base}_roc_auc':e_roc_auc})
        ## save predition
        if not os.path.exists(f'esb/{n_Dense}'):os.mkdir(f'esb/{n_Dense}')
        pd.DataFrame(y_prob_e[:,0],columns=['prob']).to_csv(f'esb/{n_Dense}/p_{ext_base}_Top{n_feats}_fold{i}.csv',index=False)   
    return rocs_dic

# %%
if not os.path.exists('esb'):os.mkdir('esb')
performance = []
num_folds = 5
n_Dense = 800
n_feats = topN = 151
ext_files = ['Ext_rm_sim_0_6.csv','Ext_rm_sim_0_7.csv','Ext_rm_sim_0_8.csv','Ext_rm_sim_0_9.csv']
#for n_Dense in [200,400,600,800,1200]:
for i in range(num_folds): 
    results = {'fold':i,'Top_n_feats':n_feats,'n_Dense':n_Dense}
    rocs_dic = load_one_keras_fcnn_pred_ext_files(n_Dense,i,ext_files)
    results.update(rocs_dic)
    performance.append(results)
    pd.DataFrame([results]).to_csv('esb/esb_append.csv',mode='a')
pd.DataFrame(performance).to_csv('esb/esb.csv',mode='a')
# Out:
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 68ms/step
# Ext_rm_sim_0_6_roc_auc =  0.03703703703703705
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7789473684210526
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8561502347417841
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9234276409525748
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 67ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7221052631578948
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8547417840375586
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9216364746590677
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 67ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8136842105263159
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.880093896713615
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9373498880521066
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 68ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7852631578947369
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.888262910798122
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9381640545491552
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 69ms/step
# Ext_rm_sim_0_6_roc_auc =  0.07407407407407407
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7873684210526315
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8668544600938967
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9291675147567678

# %% [markdown]
# selecting baseline models from 140 to 10

# %%
if not os.path.exists('esb'):os.mkdir('esb')
performance = []
num_folds = 5
n_Dense = 800
for topN in [140,130,120,100,90,80,70,60,50,40,30,25,20,15,10]:
    for i in range(num_folds): 
        print(f'processing topN:{topN}, i: {i}')
        X_train = fetch_X_train_val_test_Ext_topN('train',i,topN)
        y_train = fetch_y_train_val_test_Ext('train',i)
        X_val = fetch_X_train_val_test_Ext_topN('val',i,topN)
        y_val = fetch_y_train_val_test_Ext('val',i)
        X_test = fetch_X_train_val_test_Ext_topN('test',i,topN)
        y_test = fetch_y_train_val_test_Ext('test',i)
        X_Ext = fetch_X_train_val_test_Ext_topN('Ext',i,topN)
        y_Ext = fetch_y_train_val_test_Ext('Ext',i)
        n_feats = X_train.shape[1]
        assert n_feats==topN
        train_roc_auc,val_roc_auc,test_roc_auc,Ext_roc_auc = run_one_keras_fcnn(n_Dense,i)
        results = {'fold':i,'Top_n_feats':n_feats,'n_Dense':n_Dense,'train_roc_auc':train_roc_auc,
        'val_roc_auc':val_roc_auc,"test_roc_auc":test_roc_auc,'Ext_roc_auc':Ext_roc_auc}
        print('results = ',results)
        performance.append(results)
        pd.DataFrame([results]).to_csv('esb/esb_append_topN.csv',mode='a')
pd.DataFrame(performance).to_csv('esb/esb_topN.csv',mode='a')
# Out:
# processing topN:140, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 933us/step
# train_roc_auc =  0.9999946405246773
# 11/11 [==============================] - 0s 873us/step
# 11/11 [==============================] - 0s 862us/step
# test_roc_auc, val_roc_auc =  0.974264705882353 0.9313766596785465
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9328253720165414
# results =  {'fold': 0, 'Top_n_feats': 140, 'n_Dense': 800, 'train_roc_auc': 0.9999946405246773, 'val_roc_auc': 0.9313766596785465, 'test_roc_auc': 0.974264705882353, 'Ext_roc_auc': 0.9328253720165414}
# processing topN:140, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 886us/step
# train_roc_auc =  0.9998275321889705
# 11/11 [==============================] - 0s 891us/step
# 11/11 [==============================] - 0s 882us/step
# test_roc_auc, val_roc_auc =  0.9104411764705882 0.9269780131600064
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9278434437172348
# results =  {'fold': 1, 'Top_n_feats': 140, 'n_Dense': 800, 'train_roc_auc': 0.9998275321889705, 'val_roc_auc': 0.9269780131600064, 'test_roc_auc': 0.9104411764705882, 'Ext_roc_auc': 0.9278434437172348}
# processing topN:140, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 957us/step
# train_roc_auc =  0.9999672727051316
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9675324675324676 0.9588135930047695
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9395981895737684
# results =  {'fold': 2, 'Top_n_feats': 140, 'n_Dense': 800, 'train_roc_auc': 0.9999672727051316, 'val_roc_auc': 0.9588135930047695, 'test_roc_auc': 0.9675324675324676, 'Ext_roc_auc': 0.9395981895737684}
# processing topN:140, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 987us/step
# train_roc_auc =  0.9999456396074414
# 11/11 [==============================] - 0s 975us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9265449438202247 0.9393762183235868
# 14/14 [==============================] - 0s 927us/step
# Ext_roc_auc =  0.9465663768682232
# results =  {'fold': 3, 'Top_n_feats': 140, 'n_Dense': 800, 'train_roc_auc': 0.9999456396074414, 'val_roc_auc': 0.9393762183235868, 'test_roc_auc': 0.9265449438202247, 'Ext_roc_auc': 0.9465663768682232}
# processing topN:140, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999800215152912
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.933686402317581 0.9401230012300124
# 14/14 [==============================] - 0s 848us/step
# Ext_roc_auc =  0.9282341831916903
# results =  {'fold': 4, 'Top_n_feats': 140, 'n_Dense': 800, 'train_roc_auc': 0.9999800215152912, 'val_roc_auc': 0.9401230012300124, 'test_roc_auc': 0.933686402317581, 'Ext_roc_auc': 0.9282341831916903}
# processing topN:130, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999946405246773
# 11/11 [==============================] - 0s 817us/step
# 11/11 [==============================] - 0s 866us/step
# test_roc_auc, val_roc_auc =  0.9734313725490196 0.9333100395993478
# 14/14 [==============================] - 0s 914us/step
# Ext_roc_auc =  0.9351698088632737
# results =  {'fold': 0, 'Top_n_feats': 130, 'n_Dense': 800, 'train_roc_auc': 0.9999946405246773, 'val_roc_auc': 0.9333100395993478, 'test_roc_auc': 0.9734313725490196, 'Ext_roc_auc': 0.9351698088632737}
# processing topN:130, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9998139757671428
# 11/11 [==============================] - 0s 864us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9092156862745098 0.927245492965281
# 14/14 [==============================] - 0s 999us/step
# Ext_roc_auc =  0.940705284751392
# results =  {'fold': 1, 'Top_n_feats': 130, 'n_Dense': 800, 'train_roc_auc': 0.9998139757671428, 'val_roc_auc': 0.927245492965281, 'test_roc_auc': 0.9092156862745098, 'Ext_roc_auc': 0.940705284751392}
# processing topN:130, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 874us/step
# train_roc_auc =  0.9999733615041769
# 11/11 [==============================] - 0s 819us/step
# 11/11 [==============================] - 0s 842us/step
# test_roc_auc, val_roc_auc =  0.9668109668109669 0.953795707472178
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.945166227084758
# results =  {'fold': 2, 'Top_n_feats': 130, 'n_Dense': 800, 'train_roc_auc': 0.9999733615041769, 'val_roc_auc': 0.953795707472178, 'test_roc_auc': 0.9668109668109669, 'Ext_roc_auc': 0.945166227084758}
# processing topN:130, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 971us/step
# train_roc_auc =  0.999963249312073
# 11/11 [==============================] - 0s 829us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9293305243445693 0.9353313840155947
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9476083488001042
# results =  {'fold': 3, 'Top_n_feats': 130, 'n_Dense': 800, 'train_roc_auc': 0.999963249312073, 'val_roc_auc': 0.9353313840155947, 'test_roc_auc': 0.9293305243445693, 'Ext_roc_auc': 0.9476083488001042}
# processing topN:130, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 826us/step
# train_roc_auc =  0.9999792531120332
# 11/11 [==============================] - 0s 904us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9322831794314683 0.9349077490774907
# 14/14 [==============================] - 0s 883us/step
# Ext_roc_auc =  0.9301227573182248
# results =  {'fold': 4, 'Top_n_feats': 130, 'n_Dense': 800, 'train_roc_auc': 0.9999792531120332, 'val_roc_auc': 0.9349077490774907, 'test_roc_auc': 0.9322831794314683, 'Ext_roc_auc': 0.9301227573182248}
# processing topN:120, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999969374426728
# 11/11 [==============================] - 0s 876us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.972843137254902 0.9338923829489868
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9335742893425808
# results =  {'fold': 0, 'Top_n_feats': 120, 'n_Dense': 800, 'train_roc_auc': 0.9999969374426728, 'val_roc_auc': 0.9338923829489868, 'test_roc_auc': 0.972843137254902, 'Ext_roc_auc': 0.9335742893425808}
# processing topN:120, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 916us/step
# train_roc_auc =  0.9998938080290168
# 11/11 [==============================] - 0s 951us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9099999999999999 0.9244102070293693
# 14/14 [==============================] - 0s 974us/step
# Ext_roc_auc =  0.9334440428510956
# results =  {'fold': 1, 'Top_n_feats': 120, 'n_Dense': 800, 'train_roc_auc': 0.9998938080290168, 'val_roc_auc': 0.9244102070293693, 'test_roc_auc': 0.9099999999999999, 'Ext_roc_auc': 0.9334440428510956}
# processing topN:120, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 884us/step
# train_roc_auc =  0.9999741226040576
# 11/11 [==============================] - 0s 858us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9662337662337662 0.954391891891892
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9386213408876299
# results =  {'fold': 2, 'Top_n_feats': 120, 'n_Dense': 800, 'train_roc_auc': 0.9999741226040576, 'val_roc_auc': 0.954391891891892, 'test_roc_auc': 0.9662337662337662, 'Ext_roc_auc': 0.9386213408876299}
# processing topN:120, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 894us/step
# train_roc_auc =  0.9999609523940777
# 11/11 [==============================] - 0s 817us/step
# 11/11 [==============================] - 0s 868us/step
# test_roc_auc, val_roc_auc =  0.9288389513108614 0.9383040935672514
# 14/14 [==============================] - 0s 954us/step
# Ext_roc_auc =  0.9415193253231741
# results =  {'fold': 3, 'Top_n_feats': 120, 'n_Dense': 800, 'train_roc_auc': 0.9999609523940777, 'val_roc_auc': 0.9383040935672514, 'test_roc_auc': 0.9288389513108614, 'Ext_roc_auc': 0.9415193253231741}
# processing topN:120, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999815583218074
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9363117870722434 0.9358917589175892
# 14/14 [==============================] - 0s 829us/step
# Ext_roc_auc =  0.9243267884471362
# results =  {'fold': 4, 'Top_n_feats': 120, 'n_Dense': 800, 'train_roc_auc': 0.9999815583218074, 'val_roc_auc': 0.9358917589175892, 'test_roc_auc': 0.9363117870722434, 'Ext_roc_auc': 0.9243267884471362}
# processing topN:100, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 894us/step
# train_roc_auc =  0.9999984687213364
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 920us/step
# test_roc_auc, val_roc_auc =  0.9732843137254902 0.9333799208013045
# 14/14 [==============================] - 0s 841us/step
# Ext_roc_auc =  0.9337045358340659
# results =  {'fold': 0, 'Top_n_feats': 100, 'n_Dense': 800, 'train_roc_auc': 0.9999984687213364, 'val_roc_auc': 0.9333799208013045, 'test_roc_auc': 0.9732843137254902, 'Ext_roc_auc': 0.9337045358340659}
# processing topN:100, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 964us/step
# train_roc_auc =  0.9999525525236032
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9142156862745099 0.9261220777831274
# 14/14 [==============================] - 0s 788us/step
# Ext_roc_auc =  0.9321415779362443
# results =  {'fold': 1, 'Top_n_feats': 100, 'n_Dense': 800, 'train_roc_auc': 0.9999525525236032, 'val_roc_auc': 0.9261220777831274, 'test_roc_auc': 0.9142156862745099, 'Ext_roc_auc': 0.9321415779362443}
# processing topN:100, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 974us/step
# train_roc_auc =  0.9999847780023867
# 11/11 [==============================] - 0s 997us/step
# 11/11 [==============================] - 0s 976us/step
# test_roc_auc, val_roc_auc =  0.9649831649831649 0.957372813990461
# 14/14 [==============================] - 0s 970us/step
# Ext_roc_auc =  0.9401842987854514
# results =  {'fold': 2, 'Top_n_feats': 100, 'n_Dense': 800, 'train_roc_auc': 0.9999847780023867, 'val_roc_auc': 0.957372813990461, 'test_roc_auc': 0.9649831649831649, 'Ext_roc_auc': 0.9401842987854514}
# processing topN:100, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999724369840547
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 879us/step
# test_roc_auc, val_roc_auc =  0.9262172284644195 0.9345029239766082
# 14/14 [==============================] - 0s 943us/step
# Ext_roc_auc =  0.9430171599752531
# results =  {'fold': 3, 'Top_n_feats': 100, 'n_Dense': 800, 'train_roc_auc': 0.9999724369840547, 'val_roc_auc': 0.9345029239766082, 'test_roc_auc': 0.9262172284644195, 'Ext_roc_auc': 0.9430171599752531}
# processing topN:100, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 942us/step
# train_roc_auc =  0.9999838635315813
# 11/11 [==============================] - 0s 860us/step
# 11/11 [==============================] - 0s 932us/step
# test_roc_auc, val_roc_auc =  0.9312420785804816 0.9322017220172202
# 14/14 [==============================] - 0s 907us/step
# Ext_roc_auc =  0.923968610595552
# results =  {'fold': 4, 'Top_n_feats': 100, 'n_Dense': 800, 'train_roc_auc': 0.9999838635315813, 'val_roc_auc': 0.9322017220172202, 'test_roc_auc': 0.9312420785804816, 'Ext_roc_auc': 0.923968610595552}
# processing topN:90, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 901us/step
# train_roc_auc =  1.0
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 943us/step
# test_roc_auc, val_roc_auc =  0.9736764705882354 0.9282552993244817
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9302855654325811
# results =  {'fold': 0, 'Top_n_feats': 90, 'n_Dense': 800, 'train_roc_auc': 1.0, 'val_roc_auc': 0.9282552993244817, 'test_roc_auc': 0.9736764705882354, 'Ext_roc_auc': 0.9302855654325811}
# processing topN:90, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 908us/step
# train_roc_auc =  0.9999789122327125
# 11/11 [==============================] - 0s 816us/step
# 11/11 [==============================] - 0s 821us/step
# test_roc_auc, val_roc_auc =  0.9227941176470589 0.9325415931097202
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9166422454495131
# results =  {'fold': 1, 'Top_n_feats': 90, 'n_Dense': 800, 'train_roc_auc': 0.9999789122327125, 'val_roc_auc': 0.9325415931097202, 'test_roc_auc': 0.9227941176470589, 'Ext_roc_auc': 0.9166422454495131}
# processing topN:90, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 933us/step
# train_roc_auc =  0.9999824947027448
# 11/11 [==============================] - 0s 922us/step
# 11/11 [==============================] - 0s 902us/step
# test_roc_auc, val_roc_auc =  0.963924963924964 0.9534479332273449
# 14/14 [==============================] - 0s 985us/step
# Ext_roc_auc =  0.9224382143206017
# results =  {'fold': 2, 'Top_n_feats': 90, 'n_Dense': 800, 'train_roc_auc': 0.9999824947027448, 'val_roc_auc': 0.9534479332273449, 'test_roc_auc': 0.963924963924964, 'Ext_roc_auc': 0.9224382143206017}
# processing topN:90, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 949us/step
# train_roc_auc =  0.9999770308200457
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9263576779026217 0.9370857699805069
# 14/14 [==============================] - 0s 928us/step
# Ext_roc_auc =  0.9260851160821856
# results =  {'fold': 3, 'Top_n_feats': 90, 'n_Dense': 800, 'train_roc_auc': 0.9999770308200457, 'val_roc_auc': 0.9370857699805069, 'test_roc_auc': 0.9263576779026217, 'Ext_roc_auc': 0.9260851160821856}
# processing topN:90, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 876us/step
# train_roc_auc =  0.9999838635315813
# 11/11 [==============================] - 0s 814us/step
# 11/11 [==============================] - 0s 858us/step
# test_roc_auc, val_roc_auc =  0.9313326090892631 0.9343173431734317
# 14/14 [==============================] - 0s 984us/step
# Ext_roc_auc =  0.9109113998241671
# results =  {'fold': 4, 'Top_n_feats': 90, 'n_Dense': 800, 'train_roc_auc': 0.9999838635315813, 'val_roc_auc': 0.9343173431734317, 'test_roc_auc': 0.9313326090892631, 'Ext_roc_auc': 0.9109113998241671}
# processing topN:80, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 930us/step
# train_roc_auc =  0.9999984687213364
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.971421568627451 0.9283950617283951
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9242616652013936
# results =  {'fold': 0, 'Top_n_feats': 80, 'n_Dense': 800, 'train_roc_auc': 0.9999984687213364, 'val_roc_auc': 0.9283950617283951, 'test_roc_auc': 0.971421568627451, 'Ext_roc_auc': 0.9242616652013936}
# processing topN:80, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 867us/step
# train_roc_auc =  0.999962343272701
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9208333333333335 0.9354303750066869
# 14/14 [==============================] - 0s 929us/step
# Ext_roc_auc =  0.9180098336101071
# results =  {'fold': 1, 'Top_n_feats': 80, 'n_Dense': 800, 'train_roc_auc': 0.999962343272701, 'val_roc_auc': 0.9354303750066869, 'test_roc_auc': 0.9208333333333335, 'Ext_roc_auc': 0.9180098336101071}
# processing topN:80, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 997us/step
# train_roc_auc =  0.9999771670035802
# 11/11 [==============================] - 0s 911us/step
# 11/11 [==============================] - 0s 938us/step
# test_roc_auc, val_roc_auc =  0.9634920634920635 0.9581677265500795
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9254664452476311
# results =  {'fold': 2, 'Top_n_feats': 80, 'n_Dense': 800, 'train_roc_auc': 0.9999771670035802, 'val_roc_auc': 0.9581677265500795, 'test_roc_auc': 0.9634920634920635, 'Ext_roc_auc': 0.9254664452476311}
# processing topN:80, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 862us/step
# train_roc_auc =  0.9999709057053912
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 985us/step
# test_roc_auc, val_roc_auc =  0.9306179775280898 0.9356237816764132
# 14/14 [==============================] - 0s 770us/step
# Ext_roc_auc =  0.9151769724203054
# results =  {'fold': 3, 'Top_n_feats': 80, 'n_Dense': 800, 'train_roc_auc': 0.9999709057053912, 'val_roc_auc': 0.9356237816764132, 'test_roc_auc': 0.9306179775280898, 'Ext_roc_auc': 0.9151769724203054}
# processing topN:80, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 940us/step
# train_roc_auc =  0.9999854003380975
# 11/11 [==============================] - 0s 880us/step
# 11/11 [==============================] - 0s 830us/step
# test_roc_auc, val_roc_auc =  0.9311515480717001 0.9259532595325952
# 14/14 [==============================] - 0s 925us/step
# Ext_roc_auc =  0.9125720425906028
# results =  {'fold': 4, 'Top_n_feats': 80, 'n_Dense': 800, 'train_roc_auc': 0.9999854003380975, 'val_roc_auc': 0.9259532595325952, 'test_roc_auc': 0.9311515480717001, 'Ext_roc_auc': 0.9125720425906028}
# processing topN:70, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 852us/step
# train_roc_auc =  0.9999969374426728
# 11/11 [==============================] - 0s 845us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.972156862745098 0.9328674586536222
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.929699456220898
# results =  {'fold': 0, 'Top_n_feats': 70, 'n_Dense': 800, 'train_roc_auc': 0.9999969374426728, 'val_roc_auc': 0.9328674586536222, 'test_roc_auc': 0.972156862745098, 'Ext_roc_auc': 0.929699456220898}
# processing topN:70, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 862us/step
# train_roc_auc =  0.9999653558108849
# 11/11 [==============================] - 0s 817us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.919950980392157 0.9371422457604451
# 14/14 [==============================] - 0s 780us/step
# Ext_roc_auc =  0.9186610660675328
# results =  {'fold': 1, 'Top_n_feats': 70, 'n_Dense': 800, 'train_roc_auc': 0.9999653558108849, 'val_roc_auc': 0.9371422457604451, 'test_roc_auc': 0.919950980392157, 'Ext_roc_auc': 0.9186610660675328}
# processing topN:70, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 878us/step
# train_roc_auc =  0.9999855391022675
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 937us/step
# test_roc_auc, val_roc_auc =  0.9675324675324676 0.9557829888712241
# 14/14 [==============================] - 0s 877us/step
# Ext_roc_auc =  0.9266712252938686
# results =  {'fold': 2, 'Top_n_feats': 70, 'n_Dense': 800, 'train_roc_auc': 0.9999855391022675, 'val_roc_auc': 0.9557829888712241, 'test_roc_auc': 0.9675324675324676, 'Ext_roc_auc': 0.9266712252938686}
# processing topN:70, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 831us/step
# train_roc_auc =  0.9999609523940776
# 11/11 [==============================] - 0s 981us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9291900749063671 0.9381578947368421
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9343557682914917
# results =  {'fold': 3, 'Top_n_feats': 70, 'n_Dense': 800, 'train_roc_auc': 0.9999609523940776, 'val_roc_auc': 0.9381578947368421, 'test_roc_auc': 0.9291900749063671, 'Ext_roc_auc': 0.9343557682914917}
# processing topN:70, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 925us/step
# train_roc_auc =  0.9999869371446134
# 11/11 [==============================] - 0s 800us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9517019735650913 0.9329397293972939
# 14/14 [==============================] - 0s 790us/step
# Ext_roc_auc =  0.9202891472110969
# results =  {'fold': 4, 'Top_n_feats': 70, 'n_Dense': 800, 'train_roc_auc': 0.9999869371446134, 'val_roc_auc': 0.9329397293972939, 'test_roc_auc': 0.9517019735650913, 'Ext_roc_auc': 0.9202891472110969}
# processing topN:60, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 918us/step
# train_roc_auc =  0.9999869841313592
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 952us/step
# test_roc_auc, val_roc_auc =  0.9734803921568627 0.9266247379454926
# 14/14 [==============================] - 0s 828us/step
# Ext_roc_auc =  0.9346488228973332
# results =  {'fold': 0, 'Top_n_feats': 60, 'n_Dense': 800, 'train_roc_auc': 0.9999869841313592, 'val_roc_auc': 0.9266247379454926, 'test_roc_auc': 0.9734803921568627, 'Ext_roc_auc': 0.9346488228973332}
# processing topN:60, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999405023708675
# 11/11 [==============================] - 0s 800us/step
# 11/11 [==============================] - 0s 810us/step
# test_roc_auc, val_roc_auc =  0.9355392156862745 0.9474134702829937
# 14/14 [==============================] - 0s 882us/step
# Ext_roc_auc =  0.9310344827586208
# results =  {'fold': 1, 'Top_n_feats': 60, 'n_Dense': 800, 'train_roc_auc': 0.9999405023708675, 'val_roc_auc': 0.9474134702829937, 'test_roc_auc': 0.9355392156862745, 'Ext_roc_auc': 0.9310344827586208}
# processing topN:60, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 874us/step
# train_roc_auc =  0.9999611839060863
# 11/11 [==============================] - 0s 784us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9666666666666667 0.955385532591415
# 14/14 [==============================] - 0s 875us/step
# Ext_roc_auc =  0.9208426947999089
# results =  {'fold': 2, 'Top_n_feats': 60, 'n_Dense': 800, 'train_roc_auc': 0.9999611839060863, 'val_roc_auc': 0.955385532591415, 'test_roc_auc': 0.9666666666666667, 'Ext_roc_auc': 0.9208426947999089}
# processing topN:60, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 848us/step
# train_roc_auc =  0.9999387488534551
# 11/11 [==============================] - 0s 815us/step
# 11/11 [==============================] - 0s 879us/step
# test_roc_auc, val_roc_auc =  0.9342228464419475 0.935916179337232
# 14/14 [==============================] - 0s 778us/step
# Ext_roc_auc =  0.9353651786005015
# results =  {'fold': 3, 'Top_n_feats': 60, 'n_Dense': 800, 'train_roc_auc': 0.9999387488534551, 'val_roc_auc': 0.935916179337232, 'test_roc_auc': 0.9342228464419475, 'Ext_roc_auc': 0.9353651786005015}
# processing topN:60, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 900us/step
# train_roc_auc =  0.9999362225295836
# 11/11 [==============================] - 0s 785us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9554137244251313 0.9381549815498155
# 14/14 [==============================] - 0s 944us/step
# Ext_roc_auc =  0.9254664452476312
# results =  {'fold': 4, 'Top_n_feats': 60, 'n_Dense': 800, 'train_roc_auc': 0.9999362225295836, 'val_roc_auc': 0.9381549815498155, 'test_roc_auc': 0.9554137244251313, 'Ext_roc_auc': 0.9254664452476312}
# processing topN:50, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 859us/step
# train_roc_auc =  0.9999601867547457
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 887us/step
# test_roc_auc, val_roc_auc =  0.9741176470588235 0.9292802236198463
# 14/14 [==============================] - 0s 891us/step
# Ext_roc_auc =  0.9340301520627788
# results =  {'fold': 0, 'Top_n_feats': 50, 'n_Dense': 800, 'train_roc_auc': 0.9999601867547457, 'val_roc_auc': 0.9292802236198463, 'test_roc_auc': 0.9741176470588235, 'Ext_roc_auc': 0.9340301520627788}
# processing topN:50, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 855us/step
# train_roc_auc =  0.9999789122327125
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9211764705882353 0.9325950890707752
# 14/14 [==============================] - 0s 918us/step
# Ext_roc_auc =  0.9255966917391163
# results =  {'fold': 1, 'Top_n_feats': 50, 'n_Dense': 800, 'train_roc_auc': 0.9999789122327125, 'val_roc_auc': 0.9325950890707752, 'test_roc_auc': 0.9211764705882353, 'Ext_roc_auc': 0.9255966917391163}
# processing topN:50, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 907us/step
# train_roc_auc =  0.9999581395065636
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9649831649831649 0.9545906200317965
# 14/14 [==============================] - 0s 960us/step
# Ext_roc_auc =  0.9214288040115919
# results =  {'fold': 2, 'Top_n_feats': 50, 'n_Dense': 800, 'train_roc_auc': 0.9999581395065636, 'val_roc_auc': 0.9545906200317965, 'test_roc_auc': 0.9649831649831649, 'Ext_roc_auc': 0.9214288040115919}
# processing topN:50, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 882us/step
# train_roc_auc =  0.9999456396074414
# 11/11 [==============================] - 0s 959us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9360018726591761 0.9367933723196881
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.92771319722575
# results =  {'fold': 3, 'Top_n_feats': 50, 'n_Dense': 800, 'train_roc_auc': 0.9999456396074414, 'val_roc_auc': 0.9367933723196881, 'test_roc_auc': 0.9360018726591761, 'Ext_roc_auc': 0.92771319722575}
# processing topN:50, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 904us/step
# train_roc_auc =  0.9999392961426157
# 11/11 [==============================] - 0s 845us/step
# 11/11 [==============================] - 0s 810us/step
# test_roc_auc, val_roc_auc =  0.9540557667934093 0.939680196801968
# 14/14 [==============================] - 0s 786us/step
# Ext_roc_auc =  0.9280062518315912
# results =  {'fold': 4, 'Top_n_feats': 50, 'n_Dense': 800, 'train_roc_auc': 0.9999392961426157, 'val_roc_auc': 0.939680196801968, 'test_roc_auc': 0.9540557667934093, 'Ext_roc_auc': 0.9280062518315912}
# processing topN:40, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 965us/step
# train_roc_auc =  0.9999647805907367
# 11/11 [==============================] - 0s 794us/step
# 11/11 [==============================] - 0s 813us/step
# test_roc_auc, val_roc_auc =  0.9750490196078431 0.9300722105753553
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9383282862817883
# results =  {'fold': 0, 'Top_n_feats': 40, 'n_Dense': 800, 'train_roc_auc': 0.9999647805907367, 'val_roc_auc': 0.9300722105753553, 'test_roc_auc': 0.9750490196078431, 'Ext_roc_auc': 0.9383282862817883}
# processing topN:40, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 842us/step
# train_roc_auc =  0.9999389961017756
# 11/11 [==============================] - 0s 964us/step
# 11/11 [==============================] - 0s 876us/step
# test_roc_auc, val_roc_auc =  0.9375980392156863 0.9482159096988177
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9405424766370356
# results =  {'fold': 1, 'Top_n_feats': 40, 'n_Dense': 800, 'train_roc_auc': 0.9999389961017756, 'val_roc_auc': 0.9482159096988177, 'test_roc_auc': 0.9375980392156863, 'Ext_roc_auc': 0.9405424766370356}
# processing topN:40, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999718393044156
# 11/11 [==============================] - 0s 877us/step
# 11/11 [==============================] - 0s 862us/step
# test_roc_auc, val_roc_auc =  0.9712842712842713 0.9680544515103338
# 14/14 [==============================] - 0s 853us/step
# Ext_roc_auc =  0.9420728729119858
# results =  {'fold': 2, 'Top_n_feats': 40, 'n_Dense': 800, 'train_roc_auc': 0.9999718393044156, 'val_roc_auc': 0.9680544515103338, 'test_roc_auc': 0.9712842712842713, 'Ext_roc_auc': 0.9420728729119858}
# processing topN:40, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 846us/step
# train_roc_auc =  0.9999226704274871
# 11/11 [==============================] - 0s 838us/step
# 11/11 [==============================] - 0s 853us/step
# test_roc_auc, val_roc_auc =  0.9353698501872658 0.9368421052631579
# 14/14 [==============================] - 0s 811us/step
# Ext_roc_auc =  0.9417798183061444
# results =  {'fold': 3, 'Top_n_feats': 40, 'n_Dense': 800, 'train_roc_auc': 0.9999226704274871, 'val_roc_auc': 0.9368421052631579, 'test_roc_auc': 0.9353698501872658, 'Ext_roc_auc': 0.9417798183061444}
# processing topN:40, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 948us/step
# train_roc_auc =  0.9999354541263256
# 11/11 [==============================] - 0s 894us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9592612710483432 0.9400246002460024
# 14/14 [==============================] - 0s 839us/step
# Ext_roc_auc =  0.9283969913060466
# results =  {'fold': 4, 'Top_n_feats': 40, 'n_Dense': 800, 'train_roc_auc': 0.9999354541263256, 'val_roc_auc': 0.9400246002460024, 'test_roc_auc': 0.9592612710483432, 'Ext_roc_auc': 0.9283969913060466}
# processing topN:30, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 881us/step
# train_roc_auc =  0.9998997012475328
# 11/11 [==============================] - 0s 847us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9748039215686275 0.9279291870486839
# 14/14 [==============================] - 0s 805us/step
# Ext_roc_auc =  0.9376770538243626
# results =  {'fold': 0, 'Top_n_feats': 30, 'n_Dense': 800, 'train_roc_auc': 0.9998997012475328, 'val_roc_auc': 0.9279291870486839, 'test_roc_auc': 0.9748039215686275, 'Ext_roc_auc': 0.9376770538243626}
# processing topN:30, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 990us/step
# train_roc_auc =  0.9998742265308213
# 11/11 [==============================] - 0s 925us/step
# 11/11 [==============================] - 0s 929us/step
# test_roc_auc, val_roc_auc =  0.9366666666666666 0.9482694056598726
# 14/14 [==============================] - 0s 912us/step
# Ext_roc_auc =  0.9456220898049559
# results =  {'fold': 1, 'Top_n_feats': 30, 'n_Dense': 800, 'train_roc_auc': 0.9998742265308213, 'val_roc_auc': 0.9482694056598726, 'test_roc_auc': 0.9366666666666666, 'Ext_roc_auc': 0.9456220898049559}
# processing topN:30, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 910us/step
# train_roc_auc =  0.9999391120095471
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 816us/step
# test_roc_auc, val_roc_auc =  0.9682539682539683 0.9691971383147854
# 14/14 [==============================] - 0s 969us/step
# Ext_roc_auc =  0.9466315001139657
# results =  {'fold': 2, 'Top_n_feats': 30, 'n_Dense': 800, 'train_roc_auc': 0.9999391120095471, 'val_roc_auc': 0.9691971383147854, 'test_roc_auc': 0.9682539682539683, 'Ext_roc_auc': 0.9466315001139657}
# processing topN:30, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 869us/step
# train_roc_auc =  0.9997894491837519
# 11/11 [==============================] - 0s 987us/step
# 11/11 [==============================] - 0s 975us/step
# test_roc_auc, val_roc_auc =  0.9312734082397004 0.9376218323586745
# 14/14 [==============================] - 0s 974us/step
# Ext_roc_auc =  0.9459151444107974
# results =  {'fold': 3, 'Top_n_feats': 30, 'n_Dense': 800, 'train_roc_auc': 0.9997894491837519, 'val_roc_auc': 0.9376218323586745, 'test_roc_auc': 0.9312734082397004, 'Ext_roc_auc': 0.9459151444107974}
# processing topN:30, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 849us/step
# train_roc_auc =  0.9998486245581681
# 11/11 [==============================] - 0s 989us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9581749049429659 0.9383517835178352
# 14/14 [==============================] - 0s 940us/step
# Ext_roc_auc =  0.9327928103936699
# results =  {'fold': 4, 'Top_n_feats': 30, 'n_Dense': 800, 'train_roc_auc': 0.9998486245581681, 'val_roc_auc': 0.9383517835178352, 'test_roc_auc': 0.9581749049429659, 'Ext_roc_auc': 0.9327928103936699}
# processing topN:25, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 905us/step
# train_roc_auc =  0.9998889822968874
# 11/11 [==============================] - 0s 902us/step
# 11/11 [==============================] - 0s 809us/step
# test_roc_auc, val_roc_auc =  0.9745588235294118 0.9295131609597019
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9405099150141644
# results =  {'fold': 0, 'Top_n_feats': 25, 'n_Dense': 800, 'train_roc_auc': 0.9998889822968874, 'val_roc_auc': 0.9295131609597019, 'test_roc_auc': 0.9745588235294118, 'Ext_roc_auc': 0.9405099150141644}
# processing topN:25, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 904us/step
# train_roc_auc =  0.9998689545889995
# 11/11 [==============================] - 0s 810us/step
# 11/11 [==============================] - 0s 884us/step
# test_roc_auc, val_roc_auc =  0.9362254901960785 0.947948429893543
# 14/14 [==============================] - 0s 976us/step
# Ext_roc_auc =  0.9484875126176289
# results =  {'fold': 1, 'Top_n_feats': 25, 'n_Dense': 800, 'train_roc_auc': 0.9998689545889995, 'val_roc_auc': 0.947948429893543, 'test_roc_auc': 0.9362254901960785, 'Ext_roc_auc': 0.9484875126176289}
# processing topN:25, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 893us/step
# train_roc_auc =  0.9999330232105019
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 986us/step
# test_roc_auc, val_roc_auc =  0.9669552669552669 0.9711347376788553
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9473478558171339
# results =  {'fold': 2, 'Top_n_feats': 25, 'n_Dense': 800, 'train_roc_auc': 0.9999330232105019, 'val_roc_auc': 0.9711347376788553, 'test_roc_auc': 0.9669552669552669, 'Ext_roc_auc': 0.9473478558171339}
# processing topN:25, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 834us/step
# train_roc_auc =  0.9997052288572527
# 11/11 [==============================] - 0s 924us/step
# 11/11 [==============================] - 0s 820us/step
# test_roc_auc, val_roc_auc =  0.9301029962546816 0.9374269005847954
# 14/14 [==============================] - 0s 913us/step
# Ext_roc_auc =  0.9550649604376282
# results =  {'fold': 3, 'Top_n_feats': 25, 'n_Dense': 800, 'train_roc_auc': 0.9997052288572527, 'val_roc_auc': 0.9374269005847954, 'test_roc_auc': 0.9301029962546816, 'Ext_roc_auc': 0.9550649604376282}
# processing topN:25, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 873us/step
# train_roc_auc =  0.9998340248962655
# 11/11 [==============================] - 0s 996us/step
# 11/11 [==============================] - 0s 880us/step
# test_roc_auc, val_roc_auc =  0.9577675176534493 0.9389421894218942
# 14/14 [==============================] - 0s 879us/step
# Ext_roc_auc =  0.9371886294812933
# results =  {'fold': 4, 'Top_n_feats': 25, 'n_Dense': 800, 'train_roc_auc': 0.9998340248962655, 'val_roc_auc': 0.9389421894218942, 'test_roc_auc': 0.9577675176534493, 'Ext_roc_auc': 0.9371886294812933}
# processing topN:20, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 908us/step
# train_roc_auc =  0.9996072270227808
# 11/11 [==============================] - 0s 980us/step
# 11/11 [==============================] - 0s 873us/step
# test_roc_auc, val_roc_auc =  0.9738725490196078 0.9296529233636153
# 14/14 [==============================] - 0s 791us/step
# Ext_roc_auc =  0.9443196248901045
# results =  {'fold': 0, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9996072270227808, 'val_roc_auc': 0.9296529233636153, 'test_roc_auc': 0.9738725490196078, 'Ext_roc_auc': 0.9443196248901045}
# processing topN:20, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 911us/step
# train_roc_auc =  0.9996791646834124
# 11/11 [==============================] - 0s 938us/step
# 11/11 [==============================] - 0s 886us/step
# test_roc_auc, val_roc_auc =  0.932843137254902 0.9492323329588616
# 14/14 [==============================] - 0s 949us/step
# Ext_roc_auc =  0.9492689915665397
# results =  {'fold': 1, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9996791646834124, 'val_roc_auc': 0.9492323329588616, 'test_roc_auc': 0.932843137254902, 'Ext_roc_auc': 0.9492689915665397}
# processing topN:20, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 907us/step
# train_roc_auc =  0.9996879490489297
# 11/11 [==============================] - 0s 877us/step
# 11/11 [==============================] - 0s 993us/step
# test_roc_auc, val_roc_auc =  0.9658008658008659 0.9707869634340223
# 14/14 [==============================] - 0s 787us/step
# Ext_roc_auc =  0.9521018527563414
# results =  {'fold': 2, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9996879490489297, 'val_roc_auc': 0.9707869634340223, 'test_roc_auc': 0.9658008658008659, 'Ext_roc_auc': 0.9521018527563414}
# processing topN:20, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 959us/step
# train_roc_auc =  0.9995260692536089
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 816us/step
# test_roc_auc, val_roc_auc =  0.9316947565543071 0.9374269005847953
# 14/14 [==============================] - 0s 902us/step
# Ext_roc_auc =  0.9590700400507962
# results =  {'fold': 3, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9995260692536089, 'val_roc_auc': 0.9374269005847953, 'test_roc_auc': 0.9316947565543071, 'Ext_roc_auc': 0.9590700400507962}
# processing topN:20, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 834us/step
# train_roc_auc =  0.9996303980328877
# 11/11 [==============================] - 0s 900us/step
# 11/11 [==============================] - 0s 952us/step
# test_roc_auc, val_roc_auc =  0.9579938439254028 0.939680196801968
# 14/14 [==============================] - 0s 942us/step
# Ext_roc_auc =  0.943342776203966
# results =  {'fold': 4, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9996303980328877, 'val_roc_auc': 0.939680196801968, 'test_roc_auc': 0.9579938439254028, 'Ext_roc_auc': 0.943342776203966}
# processing topN:15, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 955us/step
# train_roc_auc =  0.9994717088610503
# 11/11 [==============================] - 0s 982us/step
# 11/11 [==============================] - 0s 927us/step
# test_roc_auc, val_roc_auc =  0.9729901960784314 0.929140461215933
# 14/14 [==============================] - 0s 865us/step
# Ext_roc_auc =  0.9480967731431735
# results =  {'fold': 0, 'Top_n_feats': 15, 'n_Dense': 800, 'train_roc_auc': 0.9994717088610503, 'val_roc_auc': 0.929140461215933, 'test_roc_auc': 0.9729901960784314, 'Ext_roc_auc': 0.9480967731431735}
# processing topN:15, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 989us/step
# train_roc_auc =  0.9994193332650491
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9321078431372549 0.9503022521799604
# 14/14 [==============================] - 0s 773us/step
# Ext_roc_auc =  0.9509621959558464
# results =  {'fold': 1, 'Top_n_feats': 15, 'n_Dense': 800, 'train_roc_auc': 0.9994193332650491, 'val_roc_auc': 0.9503022521799604, 'test_roc_auc': 0.9321078431372549, 'Ext_roc_auc': 0.9509621959558464}
# processing topN:15, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 905us/step
# train_roc_auc =  0.9991430015343774
# 11/11 [==============================] - 0s 876us/step
# 11/11 [==============================] - 0s 850us/step
# test_roc_auc, val_roc_auc =  0.9516594516594516 0.9647257551669317
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9278108820943636
# results =  {'fold': 2, 'Top_n_feats': 15, 'n_Dense': 800, 'train_roc_auc': 0.9991430015343774, 'val_roc_auc': 0.9647257551669317, 'test_roc_auc': 0.9516594516594516, 'Ext_roc_auc': 0.9278108820943636}
# processing topN:15, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 882us/step
# train_roc_auc =  0.9992757051921065
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9303838951310861 0.934551656920078
# 14/14 [==============================] - 0s 874us/step
# Ext_roc_auc =  0.9657777343622806
# results =  {'fold': 3, 'Top_n_feats': 15, 'n_Dense': 800, 'train_roc_auc': 0.9992757051921065, 'val_roc_auc': 0.934551656920078, 'test_roc_auc': 0.9303838951310861, 'Ext_roc_auc': 0.9657777343622806}
# processing topN:15, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 854us/step
# train_roc_auc =  0.999149377593361
# 11/11 [==============================] - 0s 848us/step
# 11/11 [==============================] - 0s 860us/step
# test_roc_auc, val_roc_auc =  0.9582654354517472 0.9382041820418204
# 14/14 [==============================] - 0s 857us/step
# Ext_roc_auc =  0.944840610856045
# results =  {'fold': 4, 'Top_n_feats': 15, 'n_Dense': 800, 'train_roc_auc': 0.999149377593361, 'val_roc_auc': 0.9382041820418204, 'test_roc_auc': 0.9582654354517472, 'Ext_roc_auc': 0.944840610856045}
# processing topN:10, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9997381513485205
# 11/11 [==============================] - 0s 941us/step
# 11/11 [==============================] - 0s 962us/step
# test_roc_auc, val_roc_auc =  0.9687254901960785 0.919916142557652
# 14/14 [==============================] - 0s 822us/step
# Ext_roc_auc =  0.9338999055712938
# results =  {'fold': 0, 'Top_n_feats': 10, 'n_Dense': 800, 'train_roc_auc': 0.9997381513485205, 'val_roc_auc': 0.919916142557652, 'test_roc_auc': 0.9687254901960785, 'Ext_roc_auc': 0.9338999055712938}
# processing topN:10, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 872us/step
# train_roc_auc =  0.9998358166689763
# 11/11 [==============================] - 0s 992us/step
# 11/11 [==============================] - 0s 929us/step
# test_roc_auc, val_roc_auc =  0.928578431372549 0.9401915155405768
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9353651786005014
# results =  {'fold': 1, 'Top_n_feats': 10, 'n_Dense': 800, 'train_roc_auc': 0.9998358166689763, 'val_roc_auc': 0.9401915155405768, 'test_roc_auc': 0.928578431372549, 'Ext_roc_auc': 0.9353651786005014}
# processing topN:10, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9992023673250687
# 11/11 [==============================] - 0s 956us/step
# 11/11 [==============================] - 0s 979us/step
# test_roc_auc, val_roc_auc =  0.9544011544011544 0.9646760731319555
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.925108267396047
# results =  {'fold': 2, 'Top_n_feats': 10, 'n_Dense': 800, 'train_roc_auc': 0.9992023673250687, 'val_roc_auc': 0.9646760731319555, 'test_roc_auc': 0.9544011544011544, 'Ext_roc_auc': 0.925108267396047}
# processing topN:10, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 941us/step
# train_roc_auc =  0.9994449114844369
# 11/11 [==============================] - 0s 875us/step
# 11/11 [==============================] - 0s 854us/step
# test_roc_auc, val_roc_auc =  0.9306647940074907 0.9323099415204679
# 14/14 [==============================] - 0s 897us/step
# Ext_roc_auc =  0.9687734036664388
# results =  {'fold': 3, 'Top_n_feats': 10, 'n_Dense': 800, 'train_roc_auc': 0.9994449114844369, 'val_roc_auc': 0.9323099415204679, 'test_roc_auc': 0.9306647940074907, 'Ext_roc_auc': 0.9687734036664388}
# processing topN:10, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 904us/step
# train_roc_auc =  0.9995059167050868
# 11/11 [==============================] - 0s 820us/step
# 11/11 [==============================] - 0s 866us/step
# test_roc_auc, val_roc_auc =  0.9583559659605286 0.9360393603936039
# 14/14 [==============================] - 0s 798us/step
# Ext_roc_auc =  0.9420403112891147
# results =  {'fold': 4, 'Top_n_feats': 10, 'n_Dense': 800, 'train_roc_auc': 0.9995059167050868, 'val_roc_auc': 0.9360393603936039, 'test_roc_auc': 0.9583559659605286, 'Ext_roc_auc': 0.9420403112891147}

# %% [markdown]
# above shows n_feat(ie topN) set 20 or 25 was better than others

# %% [markdown]
# # load model and pred ext, set n_Dense=800, topN = n_feats = 20,

# %%
if not os.path.exists('esb'):os.mkdir('esb')
performance = []
num_folds = 5
n_Dense = 800
n_feats = topN = 20
ext_files = ['Ext_rm_sim_0_6.csv','Ext_rm_sim_0_7.csv','Ext_rm_sim_0_8.csv','Ext_rm_sim_0_9.csv']
#for n_Dense in [200,400,600,800,1200]:
for i in range(num_folds): 
    results = {'fold':i,'Top_n_feats':n_feats,'n_Dense':n_Dense}
    rocs_dic = load_one_keras_fcnn_pred_ext_files(n_Dense,i,ext_files)
    results.update(rocs_dic)
    performance.append(results)
    pd.DataFrame([results]).to_csv('esb/esb_append.csv',mode='a')
pd.DataFrame(performance).to_csv('esb/esb.csv',mode='a')
# Out:
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 68ms/step
# Ext_rm_sim_0_6_roc_auc =  0.4074074074074074
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8147368421052632
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8821596244131455
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 891us/step
# Ext_rm_sim_0_9_roc_auc =  0.9337675554650926
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 74ms/step
# Ext_rm_sim_0_6_roc_auc =  0.4444444444444444
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8252631578947369
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.9010328638497653
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.941339303887645
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 69ms/step
# Ext_rm_sim_0_6_roc_auc =  0.25925925925925924
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.811578947368421
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.9010328638497654
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9448809281498066
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 69ms/step
# Ext_rm_sim_0_6_roc_auc =  0.18518518518518523
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8294736842105263
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.9142723004694836
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9515570934256055
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 69ms/step
# Ext_rm_sim_0_6_roc_auc =  0.48148148148148145
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8200000000000001
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.9012206572769953
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9429269285568899

# %% [markdown]
#  can also include train, val, test. Ext these base.

# %%
if not os.path.exists('esb'):os.mkdir('esb')
performance = []
num_folds = 5
n_Dense = 800
#n_feats = topN = 20
ext_files = ['train','val','test','Ext','Ext_rm_sim_0_6.csv','Ext_rm_sim_0_7.csv',
             'Ext_rm_sim_0_8.csv','Ext_rm_sim_0_9.csv']
## also can include train, val, test. Ext these base. 
#for n_Dense in [200,400,600,800,1200]:
for topN in [140,130,120,100,90,80,70,60,50,40,30,25,20,15,10]:
    n_feats = topN
    for i in range(num_folds): 
        results = {'fold':i,'Top_n_feats':n_feats,'n_Dense':n_Dense}
        rocs_dic = load_one_keras_fcnn_pred_ext_files(n_Dense,i,ext_files)
        results.update(rocs_dic)
        performance.append(results)
        pd.DataFrame([results]).to_csv('esb/esb_rmSim_append.csv',mode='a')
pd.DataFrame(performance).to_csv('esb/esb_rmSim.csv',mode='a')
# Out:
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999946405246773
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9313766596785465
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.974264705882353
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9328253720165414
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.03703703703703705
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7926315789473684
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8549295774647887
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9218400162833299
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9998275321889705
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9269780131600064
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9104411764705882
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9278434437172348
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 46ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.6989473684210527
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8496713615023475
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9186647669448402
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999672727051316
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9588135930047695
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9675324675324676
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9395981895737684
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.03703703703703705
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7957894736842105
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.872863849765258
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9307958477508651
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999456396074414
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9393762183235868
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9265449438202247
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9465663768682232
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7873684210526316
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8909859154929577
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 977us/step
# Ext_rm_sim_0_9_roc_auc =  0.938693262772237
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999800215152912
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9401230012300124
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.933686402317581
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9282341831916903
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.1111111111111111
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7873684210526315
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8662910798122065
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9275391817626704
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999946405246773
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9333100395993478
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9734313725490196
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9351698088632737
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7747368421052632
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8631924882629107
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9248931406472624
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9998139757671428
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.927245492965281
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9092156862745098
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.940705284751392
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.1111111111111111
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7821052631578947
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8896713615023474
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9354365967840422
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999733615041769
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.953795707472178
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9668109668109669
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.945166227084758
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.14814814814814814
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.848421052631579
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8865727699530517
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9381233462243029
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.999963249312073
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9353313840155947
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9293305243445693
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9476083488001042
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8136842105263158
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8928638497652581
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9394260126195807
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999792531120332
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9349077490774907
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9322831794314683
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9301227573182248
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.14814814814814814
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7789473684210526
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8726760563380281
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9301445145532261
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999969374426728
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9338923829489868
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.972843137254902
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9335742893425808
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7726315789473684
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8526760563380282
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9220435579075921
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9998938080290168
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9244102070293693
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9099999999999999
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9334440428510956
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.14814814814814814
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7347368421052631
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8630046948356807
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9253409322206392
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999741226040576
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.954391891891892
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9662337662337662
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9386213408876299
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7905263157894736
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8659154929577465
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9292896397313251
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999609523940777
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9383040935672514
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9288389513108614
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9415193253231741
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7757894736842105
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8756807511737089
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9318542641970283
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999815583218074
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9358917589175892
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9363117870722434
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9243267884471362
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 46ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7621052631578947
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8581220657276996
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9229391410543456
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999984687213364
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9333799208013045
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9732843137254902
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9337045358340659
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.11111111111111116
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7484210526315789
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8566197183098591
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9224913494809689
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999525525236032
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9261220777831274
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9142156862745099
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9321415779362443
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.18518518518518517
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7147368421052631
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.85962441314554
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9234276409525748
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999847780023867
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.957372813990461
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9649831649831649
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9401842987854514
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.03703703703703705
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7789473684210527
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8710798122065728
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9307551394260127
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999724369840547
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9345029239766082
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9262172284644195
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9430171599752531
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7621052631578947
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8794366197183098
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9334418888662732
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999838635315813
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9322017220172202
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9312420785804816
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.923968610595552
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7347368421052631
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8572769953051643
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9223285161815591
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  1.0
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9282552993244817
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9736764705882354
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9302855654325811
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.1111111111111111
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7473684210526316
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.847605633802817
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9177284754732341
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999789122327125
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9325415931097202
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9227941176470589
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9166422454495131
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.6589473684210526
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8172769953051643
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9038062283737024
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999824947027448
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9534479332273449
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.963924963924964
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9224382143206017
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7347368421052631
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8284507042253522
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9093425605536333
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999770308200457
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9370857699805069
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9263576779026217
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9260851160821856
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.716842105263158
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8374647887323944
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9121921432933034
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999838635315813
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9343173431734317
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9313326090892631
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9109113998241671
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.07407407407407407
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.6873684210526316
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.823943661971831
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9065336861388154
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999984687213364
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9283950617283951
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.971421568627451
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9242616652013936
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7463157894736842
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8419718309859154
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.911581518420517
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.999962343272701
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9354303750066869
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9208333333333335
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9180098336101071
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.11111111111111116
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.708421052631579
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8239436619718309
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9057602279666191
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999771670035802
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9581677265500795
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9634920634920635
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9254664452476311
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7642105263157895
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8325821596244132
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9124363932424182
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999709057053912
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9356237816764132
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9306179775280898
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9151769724203054
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.03703703703703705
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7231578947368422
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8206572769953052
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.8996132709139018
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999854003380975
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9259532595325952
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9311515480717001
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9125720425906028
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.736842105263158
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8297652582159625
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9083248524323225
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999969374426728
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9328674586536222
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.972156862745098
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.929699456220898
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0740740740740741
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7694736842105263
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8527699530516432
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.917891308772644
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999653558108849
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9371422457604451
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.919950980392157
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9186610660675328
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.03703703703703705
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.6831578947368422
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8261032863849765
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9065743944636677
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999855391022675
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9557829888712241
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9675324675324676
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9266712252938686
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.0
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.771578947368421
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8447887323943662
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.915163851007531
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999609523940776
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9381578947368421
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9291900749063671
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9343557682914917
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.11111111111111116
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.776842105263158
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8645070422535212
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.922124974557297
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9999869371446134
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9329397293972939
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9517019735650913
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# ...
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8294736842105263
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.9142723004694836
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 970us/step
# Ext_rm_sim_0_9_roc_auc =  0.9515570934256055
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9996303980328877
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 989us/step
# val_roc_auc =  0.939680196801968
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9579938439254028
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.943342776203966
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.48148148148148145
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8200000000000001
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.9012206572769953
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 941us/step
# Ext_rm_sim_0_9_roc_auc =  0.9429269285568899
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9994717088610503
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 965us/step
# val_roc_auc =  0.929140461215933
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9729901960784314
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 862us/step
# Ext_roc_auc =  0.9480967731431735
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.37037037037037035
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8157894736842105
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 986us/step
# Ext_rm_sim_0_8_roc_auc =  0.891924882629108
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9385304294728273
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9994193332650491
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9503022521799604
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9321078431372549
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 973us/step
# Ext_roc_auc =  0.9509621959558464
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.48148148148148145
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8200000000000001
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.9066666666666667
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9436189700793813
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9991430015343774
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 889us/step
# val_roc_auc =  0.9647257551669317
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 970us/step
# test_roc_auc =  0.9516594516594516
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9278108820943636
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.07407407407407407
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7536842105263157
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8571830985915493
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9169143089761856
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9992757051921065
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.934551656920078
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 1000us/step
# test_roc_auc =  0.9303838951310861
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 937us/step
# Ext_roc_auc =  0.9657777343622806
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.18518518518518523
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8147368421052632
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.927511737089202
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9601465499694688
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.999149377593361
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9382041820418204
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 876us/step
# test_roc_auc =  0.9582654354517472
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.944840610856045
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.5555555555555556
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.828421052631579
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.9055399061032864
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9441888866273153
# processing n_Dense:800, i: 0, ext_base:train
# true_file =  rand_/fold_0/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9997381513485205
# processing n_Dense:800, i: 0, ext_base:val
# true_file =  rand_/fold_0/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.919916142557652
# processing n_Dense:800, i: 0, ext_base:test
# true_file =  rand_/fold_0/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9687254901960785
# processing n_Dense:800, i: 0, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9338999055712938
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.22222222222222224
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7105263157894737
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 960us/step
# Ext_rm_sim_0_8_roc_auc =  0.8636619718309859
# processing n_Dense:800, i: 0, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9222878078567067
# processing n_Dense:800, i: 1, ext_base:train
# true_file =  rand_/fold_1/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9998358166689763
# processing n_Dense:800, i: 1, ext_base:val
# true_file =  rand_/fold_1/val_full.csv
# 11/11 [==============================] - 0s 904us/step
# val_roc_auc =  0.9401915155405768
# processing n_Dense:800, i: 1, ext_base:test
# true_file =  rand_/fold_1/test_full.csv
# 11/11 [==============================] - 0s 982us/step
# test_roc_auc =  0.928578431372549
# processing n_Dense:800, i: 1, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9353651786005014
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.2222222222222222
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7610526315789473
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.8778403755868545
# processing n_Dense:800, i: 1, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9267657235904743
# processing n_Dense:800, i: 2, ext_base:train
# true_file =  rand_/fold_2/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9992023673250687
# processing n_Dense:800, i: 2, ext_base:val
# true_file =  rand_/fold_2/val_full.csv
# 11/11 [==============================] - 0s 1ms/step
# val_roc_auc =  0.9646760731319555
# processing n_Dense:800, i: 2, ext_base:test
# true_file =  rand_/fold_2/test_full.csv
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc =  0.9544011544011544
# processing n_Dense:800, i: 2, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.925108267396047
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.18518518518518517
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.7684210526315789
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 970us/step
# Ext_rm_sim_0_8_roc_auc =  0.8531455399061033
# processing n_Dense:800, i: 2, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 922us/step
# Ext_rm_sim_0_9_roc_auc =  0.9137797679625483
# processing n_Dense:800, i: 3, ext_base:train
# true_file =  rand_/fold_3/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9994449114844369
# processing n_Dense:800, i: 3, ext_base:val
# true_file =  rand_/fold_3/val_full.csv
# 11/11 [==============================] - 0s 988us/step
# val_roc_auc =  0.9323099415204679
# processing n_Dense:800, i: 3, ext_base:test
# true_file =  rand_/fold_3/test_full.csv
# 11/11 [==============================] - 0s 930us/step
# test_roc_auc =  0.9306647940074907
# processing n_Dense:800, i: 3, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9687734036664388
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 47ms/step
# Ext_rm_sim_0_6_roc_auc =  0.29629629629629634
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8557894736842105
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 987us/step
# Ext_rm_sim_0_8_roc_auc =  0.9354929577464789
# processing n_Dense:800, i: 3, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.963647465906778
# processing n_Dense:800, i: 4, ext_base:train
# true_file =  rand_/fold_4/train_full.csv
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9995059167050868
# processing n_Dense:800, i: 4, ext_base:val
# true_file =  rand_/fold_4/val_full.csv
# 11/11 [==============================] - 0s 857us/step
# val_roc_auc =  0.9360393603936039
# processing n_Dense:800, i: 4, ext_base:test
# true_file =  rand_/fold_4/test_full.csv
# 11/11 [==============================] - 0s 957us/step
# test_roc_auc =  0.9583559659605286
# processing n_Dense:800, i: 4, ext_base:Ext
# true_file =  Ext.csv
# 14/14 [==============================] - 0s 919us/step
# Ext_roc_auc =  0.9420403112891147
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_6
# true_file =  Ext_rm_sim_0_6.csv
# 1/1 [==============================] - 0s 48ms/step
# Ext_rm_sim_0_6_roc_auc =  0.5925925925925926
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_7
# true_file =  Ext_rm_sim_0_7.csv
# 2/2 [==============================] - 0s 2ms/step
# Ext_rm_sim_0_7_roc_auc =  0.8431578947368421
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_8
# true_file =  Ext_rm_sim_0_8.csv
# 7/7 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_8_roc_auc =  0.907887323943662
# processing n_Dense:800, i: 4, ext_base:Ext_rm_sim_0_9
# true_file =  Ext_rm_sim_0_9.csv
# 12/12 [==============================] - 0s 1ms/step
# Ext_rm_sim_0_9_roc_auc =  0.9426826786077752

# %% [markdown]
# ## voting

# %%
def voting_np_array(arr):
    results=[]
    m,n=arr.shape
    half_n = n/2
    for i in range(m):
        if len(arr[i][arr[i]<0.5])>half_n: 
            results.append(0)
        else:
            results.append(1)
    return results

# %%
# save prob and return roc_auc
def voting_one_base_one_fold(i,ext_base):
    ## prediction
    y_prob_e = voting_np_array(X_e) 
    e_roc_auc = ROC_AUC(y_e,y_prob_e)
    pd.DataFrame(y_prob_e,columns=['prob']).to_csv(f'voting/p_{ext_base}_Top{n_feats}_fold{i}.csv',index=False)
    return e_roc_auc

# %%
if not os.path.exists('voting'):os.mkdir('voting')
ext_bases = ['train','val','test','Ext','Ext_rm_sim_0_6','Ext_rm_sim_0_7',
             'Ext_rm_sim_0_8','Ext_rm_sim_0_9']
performance = []
num_folds = 5
for topN in [140,130,120,100,90,80,70,60,50,40,30,25,20,15,10]:
    n_feats = topN
    for i in range(num_folds): 
        results = {'fold':i,'Top_n_feats':n_feats,}
        for ext_base in ext_bases:
            print(f'processing topN:{topN}, i: {i}')
            X_e = fetch_X_train_val_test_Ext_topN(ext_base,i,topN)
            y_e = fetch_y_train_val_test_Ext(ext_base,i)
            print('n_feats, X_e.shape = ', n_feats, X_e.shape)
            n_feats = X_e.shape[1]
            assert n_feats==topN
            e_roc_auc = voting_one_base_one_fold(i,ext_base)
            results.update({ext_base:e_roc_auc})
        performance.append(results)
        pd.DataFrame([results]).to_csv('voting/vot_append_topN.csv',mode='a')
pd.DataFrame(performance).to_csv('voting/vot_topN.csv',mode='a')
# Out:
# processing topN:140, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  140 (2769, 140)
# processing topN:140, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  140 (346, 140)
# processing topN:140, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  140 (347, 140)
# processing topN:140, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  140 (440, 140)
# processing topN:140, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  140 (12, 140)
# processing topN:140, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  140 (63, 140)
# processing topN:140, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  140 (221, 140)
# processing topN:140, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  140 (374, 140)
# processing topN:140, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  140 (2769, 140)
# processing topN:140, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  140 (346, 140)
# processing topN:140, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  140 (347, 140)
# processing topN:140, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  140 (440, 140)
# processing topN:140, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  140 (12, 140)
# processing topN:140, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  140 (63, 140)
# processing topN:140, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  140 (221, 140)
# processing topN:140, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  140 (374, 140)
# processing topN:140, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  140 (2769, 140)
# processing topN:140, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  140 (346, 140)
# processing topN:140, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  140 (347, 140)
# processing topN:140, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  140 (440, 140)
# processing topN:140, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  140 (12, 140)
# processing topN:140, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  140 (63, 140)
# processing topN:140, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  140 (221, 140)
# processing topN:140, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  140 (374, 140)
# processing topN:140, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  140 (2769, 140)
# processing topN:140, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  140 (346, 140)
# processing topN:140, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  140 (347, 140)
# processing topN:140, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  140 (440, 140)
# processing topN:140, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  140 (12, 140)
# processing topN:140, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  140 (63, 140)
# processing topN:140, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  140 (221, 140)
# processing topN:140, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  140 (374, 140)
# processing topN:140, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  140 (2769, 140)
# processing topN:140, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  140 (346, 140)
# processing topN:140, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  140 (347, 140)
# processing topN:140, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  140 (440, 140)
# processing topN:140, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  140 (12, 140)
# processing topN:140, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  140 (63, 140)
# processing topN:140, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  140 (221, 140)
# processing topN:140, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  140 (374, 140)
# processing topN:130, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  130 (2769, 130)
# processing topN:130, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  130 (346, 130)
# processing topN:130, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  130 (347, 130)
# processing topN:130, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  130 (440, 130)
# processing topN:130, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  130 (12, 130)
# processing topN:130, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  130 (63, 130)
# processing topN:130, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  130 (221, 130)
# processing topN:130, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  130 (374, 130)
# processing topN:130, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  130 (2769, 130)
# processing topN:130, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  130 (346, 130)
# processing topN:130, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  130 (347, 130)
# processing topN:130, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  130 (440, 130)
# processing topN:130, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  130 (12, 130)
# processing topN:130, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  130 (63, 130)
# processing topN:130, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  130 (221, 130)
# processing topN:130, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  130 (374, 130)
# processing topN:130, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  130 (2769, 130)
# processing topN:130, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  130 (346, 130)
# processing topN:130, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  130 (347, 130)
# processing topN:130, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  130 (440, 130)
# processing topN:130, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  130 (12, 130)
# processing topN:130, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  130 (63, 130)
# processing topN:130, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  130 (221, 130)
# processing topN:130, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  130 (374, 130)
# processing topN:130, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  130 (2769, 130)
# processing topN:130, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  130 (346, 130)
# processing topN:130, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  130 (347, 130)
# processing topN:130, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  130 (440, 130)
# processing topN:130, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  130 (12, 130)
# processing topN:130, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  130 (63, 130)
# processing topN:130, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  130 (221, 130)
# processing topN:130, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  130 (374, 130)
# processing topN:130, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  130 (2769, 130)
# processing topN:130, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  130 (346, 130)
# processing topN:130, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  130 (347, 130)
# processing topN:130, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  130 (440, 130)
# processing topN:130, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  130 (12, 130)
# processing topN:130, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  130 (63, 130)
# processing topN:130, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  130 (221, 130)
# processing topN:130, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  130 (374, 130)
# processing topN:120, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  120 (2769, 120)
# processing topN:120, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  120 (346, 120)
# processing topN:120, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  120 (347, 120)
# processing topN:120, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  120 (440, 120)
# processing topN:120, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  120 (12, 120)
# processing topN:120, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  120 (63, 120)
# processing topN:120, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  120 (221, 120)
# processing topN:120, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  120 (374, 120)
# processing topN:120, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  120 (2769, 120)
# processing topN:120, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  120 (346, 120)
# processing topN:120, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  120 (347, 120)
# processing topN:120, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  120 (440, 120)
# processing topN:120, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  120 (12, 120)
# processing topN:120, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  120 (63, 120)
# processing topN:120, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  120 (221, 120)
# processing topN:120, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  120 (374, 120)
# processing topN:120, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  120 (2769, 120)
# processing topN:120, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  120 (346, 120)
# processing topN:120, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  120 (347, 120)
# processing topN:120, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  120 (440, 120)
# processing topN:120, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  120 (12, 120)
# processing topN:120, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  120 (63, 120)
# processing topN:120, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  120 (221, 120)
# processing topN:120, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  120 (374, 120)
# processing topN:120, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  120 (2769, 120)
# processing topN:120, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  120 (346, 120)
# processing topN:120, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  120 (347, 120)
# processing topN:120, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  120 (440, 120)
# processing topN:120, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  120 (12, 120)
# processing topN:120, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  120 (63, 120)
# processing topN:120, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  120 (221, 120)
# processing topN:120, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  120 (374, 120)
# processing topN:120, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  120 (2769, 120)
# processing topN:120, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  120 (346, 120)
# processing topN:120, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  120 (347, 120)
# processing topN:120, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  120 (440, 120)
# processing topN:120, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  120 (12, 120)
# processing topN:120, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  120 (63, 120)
# processing topN:120, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  120 (221, 120)
# processing topN:120, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  120 (374, 120)
# processing topN:100, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  100 (2769, 100)
# processing topN:100, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  100 (346, 100)
# processing topN:100, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  100 (347, 100)
# processing topN:100, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  100 (440, 100)
# processing topN:100, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  100 (12, 100)
# processing topN:100, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  100 (63, 100)
# processing topN:100, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  100 (221, 100)
# processing topN:100, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  100 (374, 100)
# processing topN:100, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  100 (2769, 100)
# processing topN:100, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  100 (346, 100)
# processing topN:100, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  100 (347, 100)
# processing topN:100, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  100 (440, 100)
# processing topN:100, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  100 (12, 100)
# processing topN:100, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  100 (63, 100)
# processing topN:100, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  100 (221, 100)
# processing topN:100, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  100 (374, 100)
# processing topN:100, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  100 (2769, 100)
# processing topN:100, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  100 (346, 100)
# processing topN:100, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  100 (347, 100)
# processing topN:100, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  100 (440, 100)
# processing topN:100, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  100 (12, 100)
# processing topN:100, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  100 (63, 100)
# processing topN:100, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  100 (221, 100)
# processing topN:100, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  100 (374, 100)
# processing topN:100, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  100 (2769, 100)
# processing topN:100, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  100 (346, 100)
# processing topN:100, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  100 (347, 100)
# processing topN:100, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  100 (440, 100)
# processing topN:100, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  100 (12, 100)
# processing topN:100, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  100 (63, 100)
# processing topN:100, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  100 (221, 100)
# processing topN:100, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  100 (374, 100)
# processing topN:100, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  100 (2769, 100)
# processing topN:100, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  100 (346, 100)
# processing topN:100, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  100 (347, 100)
# processing topN:100, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  100 (440, 100)
# processing topN:100, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  100 (12, 100)
# processing topN:100, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  100 (63, 100)
# processing topN:100, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  100 (221, 100)
# processing topN:100, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  100 (374, 100)
# processing topN:90, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  90 (2769, 90)
# processing topN:90, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  90 (346, 90)
# processing topN:90, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  90 (347, 90)
# processing topN:90, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  90 (440, 90)
# processing topN:90, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  90 (12, 90)
# processing topN:90, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  90 (63, 90)
# processing topN:90, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  90 (221, 90)
# processing topN:90, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  90 (374, 90)
# processing topN:90, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  90 (2769, 90)
# processing topN:90, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  90 (346, 90)
# processing topN:90, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  90 (347, 90)
# processing topN:90, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  90 (440, 90)
# processing topN:90, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  90 (12, 90)
# processing topN:90, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  90 (63, 90)
# processing topN:90, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  90 (221, 90)
# processing topN:90, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  90 (374, 90)
# processing topN:90, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  90 (2769, 90)
# processing topN:90, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  90 (346, 90)
# processing topN:90, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  90 (347, 90)
# processing topN:90, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  90 (440, 90)
# processing topN:90, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  90 (12, 90)
# processing topN:90, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  90 (63, 90)
# processing topN:90, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  90 (221, 90)
# processing topN:90, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  90 (374, 90)
# processing topN:90, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  90 (2769, 90)
# processing topN:90, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  90 (346, 90)
# processing topN:90, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  90 (347, 90)
# processing topN:90, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  90 (440, 90)
# processing topN:90, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  90 (12, 90)
# processing topN:90, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  90 (63, 90)
# processing topN:90, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  90 (221, 90)
# processing topN:90, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  90 (374, 90)
# processing topN:90, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  90 (2769, 90)
# processing topN:90, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  90 (346, 90)
# processing topN:90, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  90 (347, 90)
# processing topN:90, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  90 (440, 90)
# processing topN:90, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  90 (12, 90)
# processing topN:90, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  90 (63, 90)
# processing topN:90, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  90 (221, 90)
# processing topN:90, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  90 (374, 90)
# processing topN:80, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  80 (2769, 80)
# processing topN:80, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  80 (346, 80)
# processing topN:80, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  80 (347, 80)
# processing topN:80, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  80 (440, 80)
# processing topN:80, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  80 (12, 80)
# processing topN:80, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  80 (63, 80)
# processing topN:80, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  80 (221, 80)
# processing topN:80, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  80 (374, 80)
# processing topN:80, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  80 (2769, 80)
# processing topN:80, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  80 (346, 80)
# processing topN:80, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  80 (347, 80)
# processing topN:80, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  80 (440, 80)
# processing topN:80, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  80 (12, 80)
# processing topN:80, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  80 (63, 80)
# processing topN:80, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  80 (221, 80)
# processing topN:80, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  80 (374, 80)
# processing topN:80, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  80 (2769, 80)
# processing topN:80, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  80 (346, 80)
# processing topN:80, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  80 (347, 80)
# processing topN:80, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  80 (440, 80)
# processing topN:80, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  80 (12, 80)
# processing topN:80, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  80 (63, 80)
# processing topN:80, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  80 (221, 80)
# processing topN:80, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  80 (374, 80)
# processing topN:80, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  80 (2769, 80)
# processing topN:80, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  80 (346, 80)
# processing topN:80, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  80 (347, 80)
# processing topN:80, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  80 (440, 80)
# processing topN:80, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  80 (12, 80)
# processing topN:80, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  80 (63, 80)
# processing topN:80, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  80 (221, 80)
# processing topN:80, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  80 (374, 80)
# processing topN:80, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  80 (2769, 80)
# processing topN:80, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  80 (346, 80)
# processing topN:80, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  80 (347, 80)
# processing topN:80, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  80 (440, 80)
# processing topN:80, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  80 (12, 80)
# processing topN:80, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  80 (63, 80)
# processing topN:80, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  80 (221, 80)
# processing topN:80, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  80 (374, 80)
# processing topN:70, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  70 (2769, 70)
# processing topN:70, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  70 (346, 70)
# processing topN:70, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  70 (347, 70)
# processing topN:70, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  70 (440, 70)
# processing topN:70, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  70 (12, 70)
# processing topN:70, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  70 (63, 70)
# processing topN:70, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  70 (221, 70)
# processing topN:70, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  70 (374, 70)
# processing topN:70, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  70 (2769, 70)
# processing topN:70, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  70 (346, 70)
# processing topN:70, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  70 (347, 70)
# processing topN:70, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  70 (440, 70)
# processing topN:70, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  70 (12, 70)
# processing topN:70, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  70 (63, 70)
# processing topN:70, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  70 (221, 70)
# processing topN:70, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  70 (374, 70)
# processing topN:70, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  70 (2769, 70)
# processing topN:70, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  70 (346, 70)
# processing topN:70, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  70 (347, 70)
# processing topN:70, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  70 (440, 70)
# processing topN:70, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  70 (12, 70)
# processing topN:70, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  70 (63, 70)
# processing topN:70, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  70 (221, 70)
# processing topN:70, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  70 (374, 70)
# processing topN:70, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  70 (2769, 70)
# processing topN:70, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  70 (346, 70)
# processing topN:70, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  70 (347, 70)
# processing topN:70, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  70 (440, 70)
# processing topN:70, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  70 (12, 70)
# processing topN:70, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  70 (63, 70)
# processing topN:70, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  70 (221, 70)
# processing topN:70, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  70 (374, 70)
# processing topN:70, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  70 (2769, 70)
# processing topN:70, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  70 (346, 70)
# processing topN:70, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  70 (347, 70)
# processing topN:70, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  70 (440, 70)
# processing topN:70, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  70 (12, 70)
# processing topN:70, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  70 (63, 70)
# processing topN:70, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  70 (221, 70)
# processing topN:70, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  70 (374, 70)
# processing topN:60, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  60 (2769, 60)
# processing topN:60, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  60 (346, 60)
# processing topN:60, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  60 (347, 60)
# processing topN:60, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  60 (440, 60)
# processing topN:60, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  60 (12, 60)
# processing topN:60, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  60 (63, 60)
# processing topN:60, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  60 (221, 60)
# processing topN:60, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  60 (374, 60)
# processing topN:60, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  60 (2769, 60)
# processing topN:60, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  60 (346, 60)
# processing topN:60, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  60 (347, 60)
# processing topN:60, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  60 (440, 60)
# processing topN:60, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  60 (12, 60)
# processing topN:60, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  60 (63, 60)
# processing topN:60, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  60 (221, 60)
# processing topN:60, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  60 (374, 60)
# processing topN:60, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  60 (2769, 60)
# processing topN:60, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  60 (346, 60)
# processing topN:60, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  60 (347, 60)
# processing topN:60, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  60 (440, 60)
# processing topN:60, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  60 (12, 60)
# processing topN:60, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  60 (63, 60)
# processing topN:60, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  60 (221, 60)
# processing topN:60, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  60 (374, 60)
# processing topN:60, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  60 (2769, 60)
# processing topN:60, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  60 (346, 60)
# processing topN:60, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  60 (347, 60)
# processing topN:60, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  60 (440, 60)
# processing topN:60, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  60 (12, 60)
# processing topN:60, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  60 (63, 60)
# processing topN:60, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  60 (221, 60)
# processing topN:60, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  60 (374, 60)
# processing topN:60, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  60 (2769, 60)
# processing topN:60, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  60 (346, 60)
# processing topN:60, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  60 (347, 60)
# processing topN:60, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  60 (440, 60)
# processing topN:60, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  60 (12, 60)
# processing topN:60, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  60 (63, 60)
# processing topN:60, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  60 (221, 60)
# processing topN:60, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  60 (374, 60)
# processing topN:50, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  50 (2769, 50)
# processing topN:50, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  50 (346, 50)
# processing topN:50, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  50 (347, 50)
# processing topN:50, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  50 (440, 50)
# processing topN:50, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  50 (12, 50)
# processing topN:50, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  50 (63, 50)
# processing topN:50, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  50 (221, 50)
# processing topN:50, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  50 (374, 50)
# processing topN:50, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  50 (2769, 50)
# processing topN:50, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  50 (346, 50)
# processing topN:50, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  50 (347, 50)
# processing topN:50, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  50 (440, 50)
# processing topN:50, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  50 (12, 50)
# processing topN:50, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  50 (63, 50)
# processing topN:50, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  50 (221, 50)
# processing topN:50, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  50 (374, 50)
# processing topN:50, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  50 (2769, 50)
# processing topN:50, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  50 (346, 50)
# processing topN:50, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  50 (347, 50)
# processing topN:50, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  50 (440, 50)
# processing topN:50, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  50 (12, 50)
# processing topN:50, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  50 (63, 50)
# processing topN:50, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  50 (221, 50)
# processing topN:50, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  50 (374, 50)
# processing topN:50, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  50 (2769, 50)
# processing topN:50, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  50 (346, 50)
# processing topN:50, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  50 (347, 50)
# processing topN:50, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  50 (440, 50)
# processing topN:50, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  50 (12, 50)
# processing topN:50, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  50 (63, 50)
# processing topN:50, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  50 (221, 50)
# processing topN:50, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  50 (374, 50)
# processing topN:50, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  50 (2769, 50)
# processing topN:50, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  50 (346, 50)
# processing topN:50, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  50 (347, 50)
# processing topN:50, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  50 (440, 50)
# processing topN:50, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  50 (12, 50)
# processing topN:50, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  50 (63, 50)
# processing topN:50, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  50 (221, 50)
# processing topN:50, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  50 (374, 50)
# processing topN:40, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  40 (2769, 40)
# processing topN:40, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  40 (346, 40)
# processing topN:40, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  40 (347, 40)
# processing topN:40, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  40 (440, 40)
# processing topN:40, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  40 (12, 40)
# processing topN:40, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  40 (63, 40)
# processing topN:40, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  40 (221, 40)
# processing topN:40, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  40 (374, 40)
# processing topN:40, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  40 (2769, 40)
# processing topN:40, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  40 (346, 40)
# processing topN:40, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  40 (347, 40)
# processing topN:40, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  40 (440, 40)
# processing topN:40, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  40 (12, 40)
# processing topN:40, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  40 (63, 40)
# processing topN:40, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  40 (221, 40)
# processing topN:40, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  40 (374, 40)
# processing topN:40, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  40 (2769, 40)
# processing topN:40, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  40 (346, 40)
# processing topN:40, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  40 (347, 40)
# processing topN:40, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  40 (440, 40)
# processing topN:40, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  40 (12, 40)
# processing topN:40, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  40 (63, 40)
# processing topN:40, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  40 (221, 40)
# processing topN:40, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  40 (374, 40)
# processing topN:40, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  40 (2769, 40)
# processing topN:40, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  40 (346, 40)
# processing topN:40, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  40 (347, 40)
# processing topN:40, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  40 (440, 40)
# processing topN:40, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  40 (12, 40)
# processing topN:40, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  40 (63, 40)
# processing topN:40, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  40 (221, 40)
# processing topN:40, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  40 (374, 40)
# processing topN:40, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  40 (2769, 40)
# processing topN:40, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  40 (346, 40)
# processing topN:40, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  40 (347, 40)
# processing topN:40, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  40 (440, 40)
# processing topN:40, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  40 (12, 40)
# processing topN:40, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  40 (63, 40)
# processing topN:40, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  40 (221, 40)
# processing topN:40, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  40 (374, 40)
# processing topN:30, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  30 (2769, 30)
# processing topN:30, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  30 (346, 30)
# processing topN:30, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  30 (347, 30)
# processing topN:30, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  30 (440, 30)
# processing topN:30, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  30 (12, 30)
# processing topN:30, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  30 (63, 30)
# processing topN:30, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  30 (221, 30)
# processing topN:30, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  30 (374, 30)
# processing topN:30, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  30 (2769, 30)
# processing topN:30, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  30 (346, 30)
# processing topN:30, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  30 (347, 30)
# processing topN:30, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  30 (440, 30)
# processing topN:30, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  30 (12, 30)
# processing topN:30, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  30 (63, 30)
# processing topN:30, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  30 (221, 30)
# processing topN:30, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  30 (374, 30)
# processing topN:30, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  30 (2769, 30)
# processing topN:30, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  30 (346, 30)
# processing topN:30, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  30 (347, 30)
# processing topN:30, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  30 (440, 30)
# processing topN:30, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  30 (12, 30)
# processing topN:30, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  30 (63, 30)
# processing topN:30, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  30 (221, 30)
# processing topN:30, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  30 (374, 30)
# processing topN:30, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  30 (2769, 30)
# processing topN:30, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  30 (346, 30)
# processing topN:30, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  30 (347, 30)
# processing topN:30, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  30 (440, 30)
# processing topN:30, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  30 (12, 30)
# processing topN:30, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  30 (63, 30)
# processing topN:30, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  30 (221, 30)
# processing topN:30, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  30 (374, 30)
# processing topN:30, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  30 (2769, 30)
# processing topN:30, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  30 (346, 30)
# processing topN:30, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  30 (347, 30)
# processing topN:30, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  30 (440, 30)
# processing topN:30, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  30 (12, 30)
# processing topN:30, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  30 (63, 30)
# processing topN:30, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  30 (221, 30)
# processing topN:30, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  30 (374, 30)
# processing topN:25, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  25 (2769, 25)
# processing topN:25, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  25 (346, 25)
# processing topN:25, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  25 (347, 25)
# processing topN:25, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  25 (440, 25)
# processing topN:25, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  25 (12, 25)
# processing topN:25, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  25 (63, 25)
# processing topN:25, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  25 (221, 25)
# processing topN:25, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  25 (374, 25)
# processing topN:25, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  25 (2769, 25)
# processing topN:25, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  25 (346, 25)
# processing topN:25, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  25 (347, 25)
# processing topN:25, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  25 (440, 25)
# processing topN:25, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  25 (12, 25)
# processing topN:25, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  25 (63, 25)
# processing topN:25, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  25 (221, 25)
# processing topN:25, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  25 (374, 25)
# processing topN:25, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  25 (2769, 25)
# processing topN:25, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  25 (346, 25)
# processing topN:25, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  25 (347, 25)
# processing topN:25, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  25 (440, 25)
# processing topN:25, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  25 (12, 25)
# processing topN:25, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  25 (63, 25)
# processing topN:25, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  25 (221, 25)
# processing topN:25, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  25 (374, 25)
# processing topN:25, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  25 (2769, 25)
# processing topN:25, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  25 (346, 25)
# processing topN:25, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  25 (347, 25)
# processing topN:25, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  25 (440, 25)
# processing topN:25, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  25 (12, 25)
# processing topN:25, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  25 (63, 25)
# processing topN:25, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  25 (221, 25)
# processing topN:25, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  25 (374, 25)
# processing topN:25, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  25 (2769, 25)
# processing topN:25, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  25 (346, 25)
# processing topN:25, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  25 (347, 25)
# processing topN:25, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  25 (440, 25)
# processing topN:25, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  25 (12, 25)
# processing topN:25, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  25 (63, 25)
# processing topN:25, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  25 (221, 25)
# processing topN:25, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  25 (374, 25)
# processing topN:20, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  20 (2769, 20)
# processing topN:20, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  20 (346, 20)
# processing topN:20, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  20 (347, 20)
# processing topN:20, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  20 (440, 20)
# processing topN:20, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  20 (12, 20)
# processing topN:20, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  20 (63, 20)
# processing topN:20, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  20 (221, 20)
# processing topN:20, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  20 (374, 20)
# processing topN:20, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  20 (2769, 20)
# processing topN:20, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  20 (346, 20)
# processing topN:20, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  20 (347, 20)
# processing topN:20, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  20 (440, 20)
# processing topN:20, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  20 (12, 20)
# processing topN:20, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  20 (63, 20)
# processing topN:20, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  20 (221, 20)
# processing topN:20, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  20 (374, 20)
# processing topN:20, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  20 (2769, 20)
# processing topN:20, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  20 (346, 20)
# processing topN:20, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  20 (347, 20)
# processing topN:20, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  20 (440, 20)
# processing topN:20, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  20 (12, 20)
# processing topN:20, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  20 (63, 20)
# processing topN:20, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  20 (221, 20)
# processing topN:20, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  20 (374, 20)
# processing topN:20, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  20 (2769, 20)
# processing topN:20, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  20 (346, 20)
# processing topN:20, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  20 (347, 20)
# processing topN:20, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  20 (440, 20)
# processing topN:20, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  20 (12, 20)
# processing topN:20, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  20 (63, 20)
# processing topN:20, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  20 (221, 20)
# processing topN:20, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  20 (374, 20)
# processing topN:20, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  20 (2769, 20)
# processing topN:20, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  20 (346, 20)
# processing topN:20, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  20 (347, 20)
# processing topN:20, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  20 (440, 20)
# processing topN:20, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  20 (12, 20)
# processing topN:20, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  20 (63, 20)
# processing topN:20, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  20 (221, 20)
# processing topN:20, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  20 (374, 20)
# processing topN:15, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  15 (2769, 15)
# processing topN:15, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  15 (346, 15)
# processing topN:15, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  15 (347, 15)
# processing topN:15, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  15 (440, 15)
# processing topN:15, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  15 (12, 15)
# processing topN:15, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  15 (63, 15)
# processing topN:15, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  15 (221, 15)
# processing topN:15, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  15 (374, 15)
# processing topN:15, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  15 (2769, 15)
# processing topN:15, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  15 (346, 15)
# processing topN:15, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  15 (347, 15)
# processing topN:15, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  15 (440, 15)
# processing topN:15, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  15 (12, 15)
# processing topN:15, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  15 (63, 15)
# processing topN:15, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  15 (221, 15)
# processing topN:15, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  15 (374, 15)
# processing topN:15, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  15 (2769, 15)
# processing topN:15, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  15 (346, 15)
# processing topN:15, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  15 (347, 15)
# processing topN:15, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  15 (440, 15)
# processing topN:15, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  15 (12, 15)
# processing topN:15, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  15 (63, 15)
# processing topN:15, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  15 (221, 15)
# processing topN:15, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  15 (374, 15)
# processing topN:15, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  15 (2769, 15)
# processing topN:15, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  15 (346, 15)
# processing topN:15, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  15 (347, 15)
# processing topN:15, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  15 (440, 15)
# processing topN:15, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  15 (12, 15)
# processing topN:15, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  15 (63, 15)
# processing topN:15, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  15 (221, 15)
# processing topN:15, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  15 (374, 15)
# processing topN:15, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  15 (2769, 15)
# processing topN:15, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  15 (346, 15)
# processing topN:15, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  15 (347, 15)
# processing topN:15, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  15 (440, 15)
# processing topN:15, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  15 (12, 15)
# processing topN:15, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  15 (63, 15)
# processing topN:15, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  15 (221, 15)
# processing topN:15, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  15 (374, 15)
# processing topN:10, i: 0
# true_file =  rand_/fold_0/train_full.csv
# n_feats, X_e.shape =  10 (2769, 10)
# processing topN:10, i: 0
# true_file =  rand_/fold_0/val_full.csv
# n_feats, X_e.shape =  10 (346, 10)
# processing topN:10, i: 0
# true_file =  rand_/fold_0/test_full.csv
# n_feats, X_e.shape =  10 (347, 10)
# processing topN:10, i: 0
# true_file =  Ext.csv
# n_feats, X_e.shape =  10 (440, 10)
# processing topN:10, i: 0
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  10 (12, 10)
# processing topN:10, i: 0
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  10 (63, 10)
# processing topN:10, i: 0
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  10 (221, 10)
# processing topN:10, i: 0
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  10 (374, 10)
# processing topN:10, i: 1
# true_file =  rand_/fold_1/train_full.csv
# n_feats, X_e.shape =  10 (2769, 10)
# processing topN:10, i: 1
# true_file =  rand_/fold_1/val_full.csv
# n_feats, X_e.shape =  10 (346, 10)
# processing topN:10, i: 1
# true_file =  rand_/fold_1/test_full.csv
# n_feats, X_e.shape =  10 (347, 10)
# processing topN:10, i: 1
# true_file =  Ext.csv
# n_feats, X_e.shape =  10 (440, 10)
# processing topN:10, i: 1
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  10 (12, 10)
# processing topN:10, i: 1
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  10 (63, 10)
# processing topN:10, i: 1
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  10 (221, 10)
# processing topN:10, i: 1
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  10 (374, 10)
# processing topN:10, i: 2
# true_file =  rand_/fold_2/train_full.csv
# n_feats, X_e.shape =  10 (2769, 10)
# processing topN:10, i: 2
# true_file =  rand_/fold_2/val_full.csv
# n_feats, X_e.shape =  10 (346, 10)
# processing topN:10, i: 2
# true_file =  rand_/fold_2/test_full.csv
# n_feats, X_e.shape =  10 (347, 10)
# processing topN:10, i: 2
# true_file =  Ext.csv
# n_feats, X_e.shape =  10 (440, 10)
# processing topN:10, i: 2
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  10 (12, 10)
# processing topN:10, i: 2
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  10 (63, 10)
# processing topN:10, i: 2
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  10 (221, 10)
# processing topN:10, i: 2
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  10 (374, 10)
# processing topN:10, i: 3
# true_file =  rand_/fold_3/train_full.csv
# n_feats, X_e.shape =  10 (2769, 10)
# processing topN:10, i: 3
# true_file =  rand_/fold_3/val_full.csv
# n_feats, X_e.shape =  10 (346, 10)
# processing topN:10, i: 3
# true_file =  rand_/fold_3/test_full.csv
# n_feats, X_e.shape =  10 (347, 10)
# processing topN:10, i: 3
# true_file =  Ext.csv
# n_feats, X_e.shape =  10 (440, 10)
# processing topN:10, i: 3
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  10 (12, 10)
# processing topN:10, i: 3
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  10 (63, 10)
# processing topN:10, i: 3
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  10 (221, 10)
# processing topN:10, i: 3
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  10 (374, 10)
# processing topN:10, i: 4
# true_file =  rand_/fold_4/train_full.csv
# n_feats, X_e.shape =  10 (2769, 10)
# processing topN:10, i: 4
# true_file =  rand_/fold_4/val_full.csv
# n_feats, X_e.shape =  10 (346, 10)
# processing topN:10, i: 4
# true_file =  rand_/fold_4/test_full.csv
# n_feats, X_e.shape =  10 (347, 10)
# processing topN:10, i: 4
# true_file =  Ext.csv
# n_feats, X_e.shape =  10 (440, 10)
# processing topN:10, i: 4
# true_file =  Ext_rm_sim_0_6.csv
# n_feats, X_e.shape =  10 (12, 10)
# processing topN:10, i: 4
# true_file =  Ext_rm_sim_0_7.csv
# n_feats, X_e.shape =  10 (63, 10)
# processing topN:10, i: 4
# true_file =  Ext_rm_sim_0_8.csv
# n_feats, X_e.shape =  10 (221, 10)
# processing topN:10, i: 4
# true_file =  Ext_rm_sim_0_9.csv
# n_feats, X_e.shape =  10 (374, 10)

# %% [markdown]
# # binarize prob in layer 2

# %%
arr = np.array([[0.9,0.8,0.1],[0.6,0.4,0.3]])
print(arr)
arr1=np.ones_like(arr)
arr1[arr<0.5]=0
arr1=arr1.astype(int)
print(arr1)
# Out:
# [[0.9 0.8 0.1]
#  [0.6 0.4 0.3]]
# [[1 1 0]
#  [1 0 0]]

# %%
def fetch_X_train_val_test_Ext_topN_prob_to_0_or_1(data_type,fold,topN,threshold=0.5):
    #i = 0;b = data_type = 'train'
    i = fold; b = data_type
    y_file = f'rand_/fold_{i}/{b}_full.csv'    
    X_train_files = []
    X_train_dfl = []
    for model,feature in zip(models[:topN],features[:topN]):
        pred_file = f'{model}/p_{data_type}_{feature}_fold{i}.csv'
        X_train_files.append(pred_file)
        if model=='DMPNN':X_train_dfl.append(pd.read_csv(pred_file).iloc[:,1])
        else:X_train_dfl.append(pd.read_csv(pred_file))
    #print('X_train_files = ',X_train_files)
    X_train_df = pd.concat(X_train_dfl,axis=1)
    X_train = X_train_df.values
    arr1=np.ones_like(X_train)
    #arr1[X_train<0.5]=0
    arr1[X_train<threshold]=0
    arr1=arr1.astype(int)
    #print(arr1)
    return arr1

# %%
# seem the keras model can only run once inside a function, otherwise will get GPU errors.
def run_one_keras_fcnn_for_01(n_Dense,i):
    model = Sequential()
    model.add(Dense(n_Dense, input_shape=(n_feats,), activation='relu'),)
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['AUC'])
    #print(model.summary)
    #get X and Y (main set and external set)
    y_train_2dim=y_train[:,np.newaxis]  ### change shape from(2769,) to (2769, 1)
    y_val_2dim = y_val[:,np.newaxis]
    print(y_train_2dim.shape)
    #model.fit(X_T, y_T_2dim,batch_size=4096,verbose=0, epochs=100)
    ### using early stop by monitor val_loss of X_valid, y_valid_2dim
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    model.fit(X_train, y_train_2dim, batch_size=4096, verbose=0, epochs=200, 
              validation_data=(X_val, y_val_2dim), callbacks=[early_stopping])    
    ## prediction
    y_prob_train = model.predict(X_train) 
    train_roc_auc = ROC_AUC(y_train,y_prob_train[:, 0])
    print('train_roc_auc = ', train_roc_auc )
    y_prob_val=model.predict(X_val)  ## no need other parameters here
    val_roc_auc = ROC_AUC(y_val,y_prob_val[:, 0])
    y_prob_test=model.predict(X_test)  
    test_roc_auc = ROC_AUC(y_test,y_prob_test[:, 0])
    print('test_roc_auc, val_roc_auc = ', test_roc_auc, val_roc_auc)
    y_prob_Ext=model.predict(X_Ext)  ## no need other parameters here
    Ext_roc_auc = ROC_AUC(y_Ext,y_prob_Ext[:, 0])
    print('Ext_roc_auc = ', Ext_roc_auc)    
    ## save predition
    if not os.path.exists(f'esb_01/{n_Dense}'):os.mkdir(f'esb_01/{n_Dense}')
    pd.DataFrame(y_prob_train[:,0],columns=['prob']).to_csv(f'esb_01/{n_Dense}/p_train_Top{n_feats}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_val[:, 0],columns=['prob']).to_csv(f'esb_01/{n_Dense}/p_val_Top{n_feats}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_test[:,0],columns=['prob']).to_csv(f'esb_01/{n_Dense}/p_test_Top{n_feats}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_Ext[:,0],columns=['prob']).to_csv(f'esb_01/{n_Dense}/p_Ext_Top{n_feats}_fold{i}.csv',index=False)   
    ## save model
    model_save_name = f'esb_01/{n_Dense}/model_esbTop{n_feats}_fold{i}.h5'
    model.save(model_save_name)    
    model = ''
    return train_roc_auc,val_roc_auc,test_roc_auc,Ext_roc_auc

# %%
if not os.path.exists('esb_01'):os.mkdir('esb_01')
performance = []
num_folds = 5
n_Dense = 800
#for topN in [50,40,30,25,20,15,10]:
topN = 20
thresholds = [0.3,0.4,0.5,0.6,0.7] 
for threshold in thresholds:
    for i in range(num_folds): 
        print(f'processing topN:{topN}, i: {i}')
        X_train = fetch_X_train_val_test_Ext_topN_prob_to_0_or_1('train',i,topN)
        y_train = fetch_y_train_val_test_Ext('train',i)
        X_val = fetch_X_train_val_test_Ext_topN_prob_to_0_or_1('val',i,topN)
        y_val = fetch_y_train_val_test_Ext('val',i)
        X_test = fetch_X_train_val_test_Ext_topN_prob_to_0_or_1('test',i,topN)
        y_test = fetch_y_train_val_test_Ext('test',i)
        X_Ext = fetch_X_train_val_test_Ext_topN_prob_to_0_or_1('Ext',i,topN)
        y_Ext = fetch_y_train_val_test_Ext('Ext',i)
        n_feats = X_train.shape[1]
        assert n_feats==topN
        train_roc_auc,val_roc_auc,test_roc_auc,Ext_roc_auc = run_one_keras_fcnn_for_01(n_Dense,i)
        results = {'threshold':threshold,'fold':i,'Top_n_feats':n_feats,'n_Dense':n_Dense,'train_roc_auc':train_roc_auc,
        'val_roc_auc':val_roc_auc,"test_roc_auc":test_roc_auc,'Ext_roc_auc':Ext_roc_auc}
        print('results = ',results)
        performance.append(results)
        pd.DataFrame([results]).to_csv('esb_01/esb_append_topN.csv',mode='a')
pd.DataFrame(performance).to_csv('esb_01/esb_topN.csv',mode='a')
# Out:
# processing topN:20, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# 2023-01-27 01:18:26.631159: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-27 01:18:28.812118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8089 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:25:00.0, compute capability: 8.6
# 2023-01-27 01:18:28.813588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 8089 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:61:00.0, compute capability: 8.6
# 2023-01-27 01:18:28.814862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 8089 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2023-01-27 01:18:28.816321: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 14245 MB memory:  -> device: 3, name: NVIDIA RTX A4000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-01-27 01:18:28.817554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 6116 MB memory:  -> device: 4, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:e1:00.0, compute capability: 8.6
# (2769, 1)
# 2023-01-27 01:18:30.174038: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9998246685930152
# 11/11 [==============================] - 0s 845us/step
# 11/11 [==============================] - 0s 959us/step
# test_roc_auc, val_roc_auc =  0.9563235294117647 0.918169112508735
# 14/14 [==============================] - 0s 852us/step
# Ext_roc_auc =  0.924294226824265
# results =  {'threshold': 0.3, 'fold': 0, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9998246685930152, 'val_roc_auc': 0.918169112508735, 'test_roc_auc': 0.9563235294117647, 'Ext_roc_auc': 0.924294226824265}
# processing topN:20, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9989907997083864
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.8992401960784314 0.9151286577863371
# 14/14 [==============================] - 0s 807us/step
# Ext_roc_auc =  0.9347790693888184
# results =  {'threshold': 0.3, 'fold': 1, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9989907997083864, 'val_roc_auc': 0.9151286577863371, 'test_roc_auc': 0.8992401960784314, 'Ext_roc_auc': 0.9347790693888184}
# processing topN:20, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 952us/step
# train_roc_auc =  0.9989062994714922
# 11/11 [==============================] - 0s 830us/step
# 11/11 [==============================] - 0s 828us/step
# test_roc_auc, val_roc_auc =  0.9570226070226071 0.9478090222575517
# 14/14 [==============================] - 0s 897us/step
# Ext_roc_auc =  0.9345022955944124
# results =  {'threshold': 0.3, 'fold': 2, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9989062994714922, 'val_roc_auc': 0.9478090222575517, 'test_roc_auc': 0.9570226070226071, 'Ext_roc_auc': 0.9345022955944124}
# processing topN:20, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 901us/step
# train_roc_auc =  0.9988913542475373
# 11/11 [==============================] - 0s 993us/step
# 11/11 [==============================] - 0s 799us/step
# test_roc_auc, val_roc_auc =  0.9084737827715355 0.9016812865497077
# 14/14 [==============================] - 0s 905us/step
# Ext_roc_auc =  0.949806258343916
# results =  {'threshold': 0.3, 'fold': 3, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988913542475373, 'val_roc_auc': 0.9016812865497077, 'test_roc_auc': 0.9084737827715355, 'Ext_roc_auc': 0.949806258343916}
# processing topN:20, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9988850468725987
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 901us/step
# test_roc_auc, val_roc_auc =  0.9378055404671374 0.9083148831488315
# 14/14 [==============================] - 0s 949us/step
# Ext_roc_auc =  0.9328090912051057
# results =  {'threshold': 0.3, 'fold': 4, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988850468725987, 'val_roc_auc': 0.9083148831488315, 'test_roc_auc': 0.9378055404671374, 'Ext_roc_auc': 0.9328090912051057}
# processing topN:20, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 881us/step
# train_roc_auc =  0.9998223716750199
# 11/11 [==============================] - 0s 940us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9563725490196079 0.9176566503610528
# 14/14 [==============================] - 0s 961us/step
# Ext_roc_auc =  0.9224382143206017
# results =  {'threshold': 0.4, 'fold': 0, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9998223716750199, 'val_roc_auc': 0.9176566503610528, 'test_roc_auc': 0.9563725490196079, 'Ext_roc_auc': 0.9224382143206017}
# processing topN:20, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 971us/step
# train_roc_auc =  0.9989968247847543
# 11/11 [==============================] - 0s 816us/step
# 11/11 [==============================] - 0s 830us/step
# test_roc_auc, val_roc_auc =  0.8992892156862746 0.9142192264484031
# 14/14 [==============================] - 0s 938us/step
# Ext_roc_auc =  0.9344860147829768
# results =  {'threshold': 0.4, 'fold': 1, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9989968247847543, 'val_roc_auc': 0.9142192264484031, 'test_roc_auc': 0.8992892156862746, 'Ext_roc_auc': 0.9344860147829768}
# processing topN:20, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 988us/step
# train_roc_auc =  0.9988964051730436
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 970us/step
# test_roc_auc, val_roc_auc =  0.9566859066859066 0.9477096581875994
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9376933346357982
# results =  {'threshold': 0.4, 'fold': 2, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988964051730436, 'val_roc_auc': 0.9477096581875994, 'test_roc_auc': 0.9566859066859066, 'Ext_roc_auc': 0.9376933346357982}
# processing topN:20, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 908us/step
# train_roc_auc =  0.9988385251336425
# 11/11 [==============================] - 0s 997us/step
# 11/11 [==============================] - 0s 918us/step
# test_roc_auc, val_roc_auc =  0.907677902621723 0.9019736842105263
# 14/14 [==============================] - 0s 978us/step
# Ext_roc_auc =  0.9515645859789653
# results =  {'threshold': 0.4, 'fold': 3, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988385251336425, 'val_roc_auc': 0.9019736842105263, 'test_roc_auc': 0.907677902621723, 'Ext_roc_auc': 0.9515645859789653}
# processing topN:20, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9988765944367605
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 889us/step
# test_roc_auc, val_roc_auc =  0.9369907658881043 0.9073308733087331
# 14/14 [==============================] - 0s 968us/step
# Ext_roc_auc =  0.9316694344046108
# results =  {'threshold': 0.4, 'fold': 4, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988765944367605, 'val_roc_auc': 0.9073308733087331, 'test_roc_auc': 0.9369907658881043, 'Ext_roc_auc': 0.9316694344046108}
# processing topN:20, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 846us/step
# train_roc_auc =  0.9998039963310563
# 11/11 [==============================] - 0s 999us/step
# 11/11 [==============================] - 0s 967us/step
# test_roc_auc, val_roc_auc =  0.9574999999999999 0.9175168879571396
# 14/14 [==============================] - 0s 909us/step
# Ext_roc_auc =  0.9244570349386213
# results =  {'threshold': 0.5, 'fold': 0, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9998039963310563, 'val_roc_auc': 0.9175168879571396, 'test_roc_auc': 0.9574999999999999, 'Ext_roc_auc': 0.9244570349386213}
# processing topN:20, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 861us/step
# train_roc_auc =  0.9990005904574841
# 11/11 [==============================] - 0s 836us/step
# 11/11 [==============================] - 0s 946us/step
# test_roc_auc, val_roc_auc =  0.8991421568627451 0.914326218370513
# 14/14 [==============================] - 0s 941us/step
# Ext_roc_auc =  0.9347790693888184
# results =  {'threshold': 0.5, 'fold': 1, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9990005904574841, 'val_roc_auc': 0.914326218370513, 'test_roc_auc': 0.8991421568627451, 'Ext_roc_auc': 0.9347790693888184}
# processing topN:20, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 869us/step
# train_roc_auc =  0.9988758554762658
# 11/11 [==============================] - 0s 824us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9571669071669073 0.9476599761526231
# 14/14 [==============================] - 0s 915us/step
# Ext_roc_auc =  0.9342418026114422
# results =  {'threshold': 0.5, 'fold': 2, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988758554762658, 'val_roc_auc': 0.9476599761526231, 'test_roc_auc': 0.9571669071669073, 'Ext_roc_auc': 0.9342418026114422}
# processing topN:20, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 830us/step
# train_roc_auc =  0.99889671372286
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, val_roc_auc =  0.9078651685393258 0.9019249512670566
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.951890202207678
# results =  {'threshold': 0.5, 'fold': 3, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.99889671372286, 'val_roc_auc': 0.9019249512670566, 'test_roc_auc': 0.9078651685393258, 'Ext_roc_auc': 0.951890202207678}
# processing topN:20, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 851us/step
# train_roc_auc =  0.9988934993084371
# 11/11 [==============================] - 0s 905us/step
# 11/11 [==============================] - 0s 919us/step
# test_roc_auc, val_roc_auc =  0.9378055404671372 0.9078228782287824
# 14/14 [==============================] - 0s 847us/step
# Ext_roc_auc =  0.9338510631369867
# results =  {'threshold': 0.5, 'fold': 4, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988934993084371, 'val_roc_auc': 0.9078228782287824, 'test_roc_auc': 0.9378055404671372, 'Ext_roc_auc': 0.9338510631369867}
# processing topN:20, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 853us/step
# train_roc_auc =  0.9998216060356879
# 11/11 [==============================] - 0s 812us/step
# 11/11 [==============================] - 0s 939us/step
# test_roc_auc, val_roc_auc =  0.9560784313725491 0.9172839506172838
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9247175279215916
# results =  {'threshold': 0.6, 'fold': 0, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9998216060356879, 'val_roc_auc': 0.9172839506172838, 'test_roc_auc': 0.9560784313725491, 'Ext_roc_auc': 0.9247175279215916}
# processing topN:20, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 925us/step
# train_roc_auc =  0.99892828954107
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 850us/step
# test_roc_auc, val_roc_auc =  0.8997303921568628 0.9155566254747767
# 14/14 [==============================] - 0s 910us/step
# Ext_roc_auc =  0.9334440428510957
# results =  {'threshold': 0.6, 'fold': 1, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.99892828954107, 'val_roc_auc': 0.9155566254747767, 'test_roc_auc': 0.8997303921568628, 'Ext_roc_auc': 0.9334440428510957}
# processing topN:20, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 886us/step
# train_roc_auc =  0.9989161937699409
# 11/11 [==============================] - 0s 901us/step
# 11/11 [==============================] - 0s 823us/step
# test_roc_auc, val_roc_auc =  0.9568302068302068 0.9473122019077902
# 14/14 [==============================] - 0s 850us/step
# Ext_roc_auc =  0.9340789944970858
# results =  {'threshold': 0.6, 'fold': 2, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9989161937699409, 'val_roc_auc': 0.9473122019077902, 'test_roc_auc': 0.9568302068302068, 'Ext_roc_auc': 0.9340789944970858}
# processing topN:20, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 913us/step
# train_roc_auc =  0.9988859947722147
# 11/11 [==============================] - 0s 831us/step
# 11/11 [==============================] - 0s 957us/step
# test_roc_auc, val_roc_auc =  0.9079588014981272 0.9009015594541911
# 14/14 [==============================] - 0s 987us/step
# Ext_roc_auc =  0.9511087232587672
# results =  {'threshold': 0.6, 'fold': 3, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988859947722147, 'val_roc_auc': 0.9009015594541911, 'test_roc_auc': 0.9079588014981272, 'Ext_roc_auc': 0.9511087232587672}
# processing topN:20, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 977us/step
# train_roc_auc =  0.9988627631781158
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 889us/step
# test_roc_auc, val_roc_auc =  0.9373981531776208 0.9087576875768758
# 14/14 [==============================] - 0s 1ms/step
# Ext_roc_auc =  0.9349581583146105
# results =  {'threshold': 0.6, 'fold': 4, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988627631781158, 'val_roc_auc': 0.9087576875768758, 'test_roc_auc': 0.9373981531776208, 'Ext_roc_auc': 0.9349581583146105}
# processing topN:20, i: 0
# true_file =  rand_/fold_0/train_full.csv
# true_file =  rand_/fold_0/val_full.csv
# true_file =  rand_/fold_0/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 875us/step
# train_roc_auc =  0.999800933773729
# 11/11 [==============================] - 0s 921us/step
# 11/11 [==============================] - 0s 982us/step
# test_roc_auc, val_roc_auc =  0.956078431372549 0.9174703004891682
# 14/14 [==============================] - 0s 877us/step
# Ext_roc_auc =  0.9249780209045618
# results =  {'threshold': 0.7, 'fold': 0, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.999800933773729, 'val_roc_auc': 0.9174703004891682, 'test_roc_auc': 0.956078431372549, 'Ext_roc_auc': 0.9249780209045618}
# processing topN:20, i: 1
# true_file =  rand_/fold_1/train_full.csv
# true_file =  rand_/fold_1/val_full.csv
# true_file =  rand_/fold_1/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 882us/step
# train_roc_auc =  0.9989719713447368
# 11/11 [==============================] - 0s 848us/step
# 11/11 [==============================] - 0s 981us/step
# test_roc_auc, val_roc_auc =  0.8994362745098039 0.9141657304873482
# 14/14 [==============================] - 0s 847us/step
# Ext_roc_auc =  0.933606850965452
# results =  {'threshold': 0.7, 'fold': 1, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9989719713447368, 'val_roc_auc': 0.9141657304873482, 'test_roc_auc': 0.8994362745098039, 'Ext_roc_auc': 0.933606850965452}
# processing topN:20, i: 2
# true_file =  rand_/fold_2/train_full.csv
# true_file =  rand_/fold_2/val_full.csv
# true_file =  rand_/fold_2/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 904us/step
# train_roc_auc =  0.9988933607735211
# 11/11 [==============================] - 0s 886us/step
# 11/11 [==============================] - 0s 818us/step
# test_roc_auc, val_roc_auc =  0.9568783068783069 0.9481071144674086
# 14/14 [==============================] - 0s 895us/step
# Ext_roc_auc =  0.9321252971248087
# results =  {'threshold': 0.7, 'fold': 2, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988933607735211, 'val_roc_auc': 0.9481071144674086, 'test_roc_auc': 0.9568783068783069, 'Ext_roc_auc': 0.9321252971248087}
# processing topN:20, i: 3
# true_file =  rand_/fold_3/train_full.csv
# true_file =  rand_/fold_3/val_full.csv
# true_file =  rand_/fold_3/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 4ms/step
# train_roc_auc =  0.998892885526201
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 890us/step
# test_roc_auc, val_roc_auc =  0.907443820224719 0.9024122807017544
# 14/14 [==============================] - 0s 859us/step
# Ext_roc_auc =  0.9516948324704503
# results =  {'threshold': 0.7, 'fold': 3, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.998892885526201, 'val_roc_auc': 0.9024122807017544, 'test_roc_auc': 0.907443820224719, 'Ext_roc_auc': 0.9516948324704503}
# processing topN:20, i: 4
# true_file =  rand_/fold_4/train_full.csv
# true_file =  rand_/fold_4/val_full.csv
# true_file =  rand_/fold_4/test_full.csv
# true_file =  Ext.csv
# (2769, 1)
# 87/87 [==============================] - 0s 996us/step
# train_roc_auc =  0.9988727524204704
# 11/11 [==============================] - 0s 957us/step
# 11/11 [==============================] - 0s 999us/step
# test_roc_auc, val_roc_auc =  0.9376697447039652 0.9082164821648216
# 14/14 [==============================] - 0s 932us/step
# Ext_roc_auc =  0.9326462830907492
# results =  {'threshold': 0.7, 'fold': 4, 'Top_n_feats': 20, 'n_Dense': 800, 'train_roc_auc': 0.9988727524204704, 'val_roc_auc': 0.9082164821648216, 'test_roc_auc': 0.9376697447039652, 'Ext_roc_auc': 0.9326462830907492}

# %%
# free GPU memory
from numba import cuda 
device = cuda.get_current_device()
device.reset()
cuda.close()
