# %%
from sklearn.ensemble import RandomForestClassifier
#import deepchem as dc
import numpy as np
import pandas as pd
import tempfile
#import chemprop
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import backend as K
from tensorflow.keras import initializers
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.linear_model import LogisticRegression
import xgboost
import os
from sklearn.svm import SVC
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# %%
def ROC_AUC(y_true, y_score):
	auc = roc_auc_score(y_true, y_score)
	return auc

# %%
fingerprint_list = ['MorganFP', 'RDkitFP', 'AtomPairFP', 'TorsionFP', 'AvalonFP', 
'EstateFP', 'MACCSFP', 'PharmacoErGFP', 'PharmacoPFP', 'PubChemFP', 'MHFP6', 'MAP4']
descriptor_list = ['Property', 'Constitution', 'Autocorr', 'Fragment', 'Charge', 
'Estate', 'MOE', 'Connectivity', 'Topology', 'Kappa', 'Path', 'Matrix', 'InfoContent']

# %%
def get_Xye_for_one_fingerprint(feature):
    #feature='AtomPairFP'
    csv_file = "Main.csv"
    df = pd.read_csv(csv_file)
    smiles_col = df.columns[0]
    values_col = df.columns[1]

    csv_feat_file = f"fp/Main_{feature}.csv"
    dff = pd.read_csv(csv_feat_file)

    print('values_col = ',values_col)
    #feats_col = df.columns[2:]

    MASK = -1
    #y = df[values_col].astype('int').fillna(MASK).values
    y = df[values_col].astype('int').fillna(MASK).values
    #X = df[feats_col].values
    X = dff.values
    n_feats = len(dff.columns)

    #read external set
    csv_file_e = "Ext.csv"
    df_e = pd.read_csv(csv_file_e)
    smiles_col = df_e.columns[0]
    values_col = df_e.columns[1]
    csv_feat_file_e = f"fp/Ext_{feature}.csv"
    df_ef = pd.read_csv(csv_feat_file_e)

    MASK = -1
    y_e = df_e[values_col].astype('int').fillna(MASK).values
    X_e = df_ef.values
    return X,y,X_e,y_e

# %%
def get_Xye_for_one_descriptor(feature):
    #feature='AtomPairFP'
    csv_file = "Main.csv"
    df = pd.read_csv(csv_file)
    smiles_col = df.columns[0]
    values_col = df.columns[1]

    csv_feat_file = f"fp/Main_{feature}S.csv"
    dff = pd.read_csv(csv_feat_file)

    print('values_col = ',values_col)
    #feats_col = df.columns[2:]

    MASK = -1
    #y = df[values_col].astype('int').fillna(MASK).values
    y = df[values_col].astype('int').fillna(MASK).values
    #X = df[feats_col].values
    X = dff.values
    n_feats = len(dff.columns)

    #read external set
    csv_file_e = "Ext.csv"
    df_e = pd.read_csv(csv_file_e)
    smiles_col = df_e.columns[0]
    values_col = df_e.columns[1]
    csv_feat_file_e = f"fp/Ext_{feature}S.csv"
    df_ef = pd.read_csv(csv_feat_file_e)

    MASK = -1
    y_e = df_e[values_col].astype('int').fillna(MASK).values
    X_e = df_ef.values
    return X,y,X_e,y_e

# %% [markdown]
# # run xgboost model

# %%
def run_xgb_with_save(feature,num_folds):   
    for i in range(num_folds): 
        #print(f'processing fold: {i}')
        pklf = f'./rand_MorganFP/get_split/split_indices_fold{i}.pckl'
        train_idx, valid_idx, test_idx = pd.read_pickle(pklf)
        print(len(train_idx), len(valid_idx), len(test_idx))
        #get X and Y (main set and external set)
        X_T = X[train_idx];y_T = y[train_idx]
        X_valid = X[valid_idx];y_valid = y[valid_idx]
        X_test = X[test_idx];y_test = y[test_idx] 
        xgboost_model = xgboost.XGBClassifier(gpu_id = 0,tree_method = 'gpu_hist',
  max_depth=5,learning_rate=0.05, n_estimators=3000, gamma=0.0, min_child_weight=5,
  max_delta_step=1, subsample=0.53, colsample_bytree=0.66, colsample_bylevel=1, reg_alpha=0,
  reg_lambda=1, scale_pos_weight=1, base_score=0.5, seed=2016)
        
        xgboost_model.fit(X_T, y_T)
        
        y_prob_T =  xgboost_model.predict_proba(X_T)
        train_roc_auc = ROC_AUC(y_T,y_prob_T[:, 1])
        #print('train_roc_auc = ', train_roc_auc)
        y_prob_test =  xgboost_model.predict_proba(X_test)
        test_roc_auc = ROC_AUC(y_test,y_prob_test[:, 1])
        y_prob_valid =  xgboost_model.predict_proba(X_valid)
        valid_roc_auc = ROC_AUC(y_valid,y_prob_valid[:, 1])
        #print('valid_roc_auc, test_roc_auc = ', valid_roc_auc, test_roc_auc)

        y_prob_e =  xgboost_model.predict_proba(X_e)
        e_roc_auc = ROC_AUC(y_e,y_prob_e[:, 1])
        print('e_roc_auc = ', e_roc_auc)
        if not os.path.exists('xgb'):os.mkdir('xgb')
        pd.DataFrame(y_prob_T[:,1],columns=['prob']).to_csv(f'xgb/p_train_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_valid[:, 1],columns=['prob']).to_csv(f'xgb/p_val_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_test[:,1],columns=['prob']).to_csv(f'xgb/p_test_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_e[:,1],columns=['prob']).to_csv(f'xgb/p_Ext_{feature}_fold{i}.csv',index=False) 
        ## save model
        model_file=f"xgb/model_{feature}_fold{i}.job"
        joblib.dump(xgboost_model,model_file,compress=3) 
        ## free gpu memory
        #xgboost_model = ''
        #free_memory_by_numba()
    return

# %%
num_folds = 5;
for feature in fingerprint_list:
    X,y,X_e,y_e = get_Xye_for_one_fingerprint(feature)
    print(f'processing feat: {feature}')
    run_xgb_with_save(feature,num_folds)
# Out:
# values_col =  label
# processing feat: MorganFP
# 2769 346 347
# e_roc_auc =  0.8363290026374914
# 2769 346 347
# e_roc_auc =  0.8626062322946175
# 2769 346 347
# e_roc_auc =  0.8580476050926378
# 2769 346 347
# e_roc_auc =  0.8632900263749146
# 2769 346 347
# e_roc_auc =  0.8700302823092704
# values_col =  label
# processing feat: RDkitFP
# 2769 346 347
# e_roc_auc =  0.8046791052066035
# 2769 346 347
# e_roc_auc =  0.8310377389209078
# 2769 346 347
# e_roc_auc =  0.8193806779329882
# 2769 346 347
# e_roc_auc =  0.7831395916772491
# 2769 346 347
# e_roc_auc =  0.7927778320471491
# values_col =  label
# processing feat: AtomPairFP
# 2769 346 347
# e_roc_auc =  0.9047735339129303
# 2769 346 347
# e_roc_auc =  0.917244635472632
# 2769 346 347
# e_roc_auc =  0.8967959363094657
# 2769 346 347
# e_roc_auc =  0.9051317117645143
# 2769 346 347
# e_roc_auc =  0.8878089283969913
# values_col =  label
# processing feat: TorsionFP
# 2769 346 347
# e_roc_auc =  0.8144475920679888
# 2769 346 347
# e_roc_auc =  0.8035394484061087
# 2769 346 347
# e_roc_auc =  0.8317052521897692
# 2769 346 347
# e_roc_auc =  0.8002181628732377
# 2769 346 347
# e_roc_auc =  0.8391944254501645
# values_col =  label
# processing feat: AvalonFP
# 2769 346 347
# e_roc_auc =  0.7685519846309141
# 2769 346 347
# e_roc_auc =  0.7395395786526001
# 2769 346 347
# e_roc_auc =  0.7521897691380939
# 2769 346 347
# e_roc_auc =  0.6934323206668621
# 2769 346 347
# e_roc_auc =  0.6893621178079515
# values_col =  label
# processing feat: EstateFP
# 2769 346 347
# e_roc_auc =  0.684380189508645
# 2769 346 347
# e_roc_auc =  0.662596463807756
# 2769 346 347
# e_roc_auc =  0.6573214809026081
# 2769 346 347
# e_roc_auc =  0.6152518641529093
# 2769 346 347
# e_roc_auc =  0.6166194523135033
# values_col =  label
# processing feat: MACCSFP
# 2769 346 347
# e_roc_auc =  0.7834489270945264
# 2769 346 347
# e_roc_auc =  0.780648627527596
# 2769 346 347
# e_roc_auc =  0.7821139005568036
# 2769 346 347
# e_roc_auc =  0.7810393670020513
# 2769 346 347
# e_roc_auc =  0.7893425808342289
# values_col =  label
# processing feat: PharmacoErGFP
# 2769 346 347
# e_roc_auc =  0.8201947185047703
# 2769 346 347
# e_roc_auc =  0.7975643906092279
# 2769 346 347
# e_roc_auc =  0.8002670053075446
# 2769 346 347
# e_roc_auc =  0.8322750805900166
# 2769 346 347
# e_roc_auc =  0.8211390055680375
# values_col =  label
# processing feat: PharmacoPFP
# 2769 346 347
# e_roc_auc =  0.8176549119208102
# 2769 346 347
# e_roc_auc =  0.80674676825893
# 2769 346 347
# e_roc_auc =  0.8026765654000196
# 2769 346 347
# e_roc_auc =  0.7633746865943799
# 2769 346 347
# e_roc_auc =  0.8253394549184332
# values_col =  label
# processing feat: PubChemFP
# 2769 346 347
# e_roc_auc =  0.7603138940444791
# 2769 346 347
# e_roc_auc =  0.7019309042362671
# 2769 346 347
# e_roc_auc =  0.7829116603171502
# 2769 346 347
# e_roc_auc =  0.7565041841685389
# 2769 346 347
# e_roc_auc =  0.8335449838819966
# values_col =  label
# processing feat: MHFP6
# 2769 346 347
# e_roc_auc =  0.8539611214222917
# 2769 346 347
# e_roc_auc =  0.8358568591058578
# 2769 346 347
# e_roc_auc =  0.8490443163687277
# 2769 346 347
# e_roc_auc =  0.8462114551789262
# 2769 346 347
# e_roc_auc =  0.8312656702810068
# values_col =  label
# processing feat: MAP4
# 2769 346 347
# e_roc_auc =  0.8908860017583277
# 2769 346 347
# e_roc_auc =  0.8971703949724854
# 2769 346 347
# e_roc_auc =  0.862134088762984
# 2769 346 347
# e_roc_auc =  0.8706977955781317
# 2769 346 347
# e_roc_auc =  0.870274494480805

# %%
num_folds = 5;
for feature in descriptor_list:
    X,y,X_e,y_e = get_Xye_for_one_descriptor(feature)
    print(f'processing feat: {feature}')
    run_xgb_with_save(feature,num_folds)
# Out:
# values_col =  label
# processing feat: Property
# 2769 346 347
# e_roc_auc =  0.8150337012796718
# 2769 346 347
# e_roc_auc =  0.8109634984207612
# 2769 346 347
# e_roc_auc =  0.8074794047735339
# 2769 346 347
# e_roc_auc =  0.7902868678974959
# 2769 346 347
# e_roc_auc =  0.7785972452867052
# values_col =  label
# processing feat: Constitution
# 2769 346 347
# e_roc_auc =  0.8180130897723943
# 2769 346 347
# e_roc_auc =  0.8201621568818991
# 2769 346 347
# e_roc_auc =  0.8650320731985282
# 2769 346 347
# e_roc_auc =  0.8588779264758556
# 2769 346 347
# e_roc_auc =  0.7887076291882388
# values_col =  label
# processing feat: Autocorr
# 2769 346 347
# e_roc_auc =  0.8937677053824362
# 2769 346 347
# e_roc_auc =  0.8822734525088731
# 2769 346 347
# e_roc_auc =  0.8945166227084759
# 2769 346 347
# e_roc_auc =  0.8442089153723422
# 2769 346 347
# e_roc_auc =  0.836166194523135
# values_col =  label
# processing feat: Fragment
# 2769 346 347
# e_roc_auc =  0.7331575005698284
# 2769 346 347
# e_roc_auc =  0.6938230601413174
# 2769 346 347
# e_roc_auc =  0.7201328514213148
# 2769 346 347
# e_roc_auc =  0.6840871349028036
# 2769 346 347
# e_roc_auc =  0.685845462537853
# values_col =  label
# processing feat: Charge
# 2769 346 347
# e_roc_auc =  0.7881378007879912
# 2769 346 347
# e_roc_auc =  0.8136335514962065
# 2769 346 347
# e_roc_auc =  0.8022044218683859
# 2769 346 347
# e_roc_auc =  0.7772622187489825
# 2769 346 347
# e_roc_auc =  0.8041906808635342
# values_col =  label
# processing feat: Estate
# 2769 346 347
# e_roc_auc =  0.8466673178991241
# 2769 346 347
# e_roc_auc =  0.8331216827846699
# 2769 346 347
# e_roc_auc =  0.8374523786265506
# 2769 346 347
# e_roc_auc =  0.797971410895119
# 2769 346 347
# e_roc_auc =  0.8199505063332355
# values_col =  label
# processing feat: MOE
# 2769 346 347
# e_roc_auc =  0.8539122789879848
# 2769 346 347
# e_roc_auc =  0.8316075673211553
# 2769 346 347
# e_roc_auc =  0.8601315489564
# 2769 346 347
# e_roc_auc =  0.8458858389502133
# 2769 346 347
# e_roc_auc =  0.8286444596398683
# values_col =  label
# processing feat: Connectivity
# 2769 346 347
# e_roc_auc =  0.8018788056396731
# 2769 346 347
# e_roc_auc =  0.8417342320341248
# 2769 346 347
# e_roc_auc =  0.8121682784669988
# 2769 346 347
# e_roc_auc =  0.8099215264888802
# 2769 346 347
# e_roc_auc =  0.8319331835498681
# values_col =  label
# processing feat: Topology
# 2769 346 347
# e_roc_auc =  0.8213506561167009
# 2769 346 347
# e_roc_auc =  0.8170199602748202
# 2769 346 347
# e_roc_auc =  0.7938198039790303
# 2769 346 347
# e_roc_auc =  0.7833023997916057
# 2769 346 347
# e_roc_auc =  0.7968805965289311
# values_col =  label
# processing feat: Kappa
# 2769 346 347
# e_roc_auc =  0.7223796033994334
# 2769 346 347
# e_roc_auc =  0.7286965582364625
# 2769 346 347
# e_roc_auc =  0.6859757090293381
# 2769 346 347
# e_roc_auc =  0.667057406141122
# 2769 346 347
# e_roc_auc =  0.7373905115430952
# values_col =  label
# processing feat: Path
# 2769 346 347
# e_roc_auc =  0.7506105304288366
# 2769 346 347
# e_roc_auc =  0.7414607144020058
# 2769 346 347
# e_roc_auc =  0.7499267363485396
# 2769 346 347
# e_roc_auc =  0.7107876656572564
# 2769 346 347
# e_roc_auc =  0.706750024421217
# values_col =  label
# processing feat: Matrix
# 2769 346 347
# e_roc_auc =  0.8775194555696656
# 2769 346 347
# e_roc_auc =  0.8288723909999675
# 2769 346 347
# e_roc_auc =  0.8197225749731367
# 2769 346 347
# e_roc_auc =  0.7885285402624468
# 2769 346 347
# e_roc_auc =  0.8750773338543193
# values_col =  label
# processing feat: InfoContent
# 2769 346 347
# e_roc_auc =  0.8094493829572466
# 2769 346 347
# e_roc_auc =  0.780241607241705
# 2769 346 347
# e_roc_auc =  0.7652958223437856
# 2769 346 347
# e_roc_auc =  0.7613884275992316
# 2769 346 347
# e_roc_auc =  0.768096121910716

# %% [markdown]
# # run fcnn model

# %%
# seem the keras model can only run once inside a function, otherwise will get GPU errors.
def run_one_keras_fcnn(feature,i):   
    model = Sequential()
    model.add(Dense(800, input_shape=(n_feats,), activation='relu'),)
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['AUC'])
    #print(model.summary)
    pklf = f'./rand_MorganFP/get_split/split_indices_fold{i}.pckl'
    train_idx, valid_idx, test_idx = pd.read_pickle(pklf)
    print(len(train_idx), len(valid_idx), len(test_idx))
    #get X and Y (main set and external set)
    X_T = X[train_idx];y_T = y[train_idx]
    X_valid = X[valid_idx];y_valid = y[valid_idx]
    X_test = X[test_idx];y_test = y[test_idx]     
    y_T_2dim=y_T[:,np.newaxis]  ### change shape from(2769,) to (2769, 1)
    y_valid_2dim = y_valid[:,np.newaxis]
    print(y_T_2dim.shape)
    #model.fit(X_T, y_T_2dim,batch_size=4096,verbose=0, epochs=100)
    ### using early stop by monitor val_loss of X_valid, y_valid_2dim
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    model.fit(X_T, y_T_2dim, batch_size=4096, verbose=0, epochs=100, 
              validation_data=(X_valid, y_valid_2dim), callbacks=[early_stopping])    
    ## prediction
    y_prob_T = model.predict(X_T) 
    train_roc_auc = ROC_AUC(y_T,y_prob_T[:, 0])
    print('train_roc_auc = ', train_roc_auc )
    y_prob_valid=model.predict(X_valid)  ## no need other parameters here
    valid_roc_auc = ROC_AUC(y_valid,y_prob_valid[:, 0])
    y_prob_test=model.predict(X_test)  
    test_roc_auc = ROC_AUC(y_test,y_prob_test[:, 0])
    print('test_roc_auc, valid_roc_auc = ', test_roc_auc, valid_roc_auc)
    y_prob_e=model.predict(X_e)  ## no need other parameters here
    e_roc_auc = ROC_AUC(y_e,y_prob_e[:, 0])
    print('e_roc_auc = ', e_roc_auc)    
    ## save predition
    if not os.path.exists('fcnn'):os.mkdir('fcnn')
    pd.DataFrame(y_prob_T[:,0],columns=['prob']).to_csv(f'fcnn/p_train_{feature}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_valid[:, 0],columns=['prob']).to_csv(f'fcnn/p_val_{feature}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_test[:,0],columns=['prob']).to_csv(f'fcnn/p_test_{feature}_fold{i}.csv',index=False)
    pd.DataFrame(y_prob_e[:,0],columns=['prob']).to_csv(f'fcnn/p_Ext_{feature}_fold{i}.csv',index=False) 
    ## save model
    model_save_name = f'fcnn/model_{feature}_fold{i}.h5'
    model.save(model_save_name)    
    model = ''
    ## empty gpu memory
    import torch
    torch.cuda.empty_cache()
    return

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"
num_folds = 5
for feature in fingerprint_list:
    csv_feat_file = f"fp/Main_{feature}.csv"
    tdf = pd.read_csv(csv_feat_file,nrows=3)
    n_feats = len(tdf.columns)
    print(f'processing feat: {feature}')
    X,y,X_e,y_e = get_Xye_for_one_fingerprint(feature)
    for i in range(num_folds): 
        run_one_keras_fcnn(feature,i)
# Out:
# processing feat: MorganFP
# values_col =  label
# 2023-01-23 01:25:53.092025: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-23 01:25:54.196618: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8037 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2769 346 347
# (2769, 1)
# 2023-01-23 01:25:57.693648: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9946412903166532
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9484313725490197 0.9276496622408573
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8613688906255088
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9972713935399131
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9013970588235294 0.9433477772428182
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8419621633942236
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9948595314060255
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9548100048100048 0.9490013910969793
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8425157109830355
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9960286287858952
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9070458801498127 0.9112573099415205
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8240858324378888
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.996082680190564
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9458401231214919 0.9289052890528905
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8300120478004624
# processing feat: RDkitFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9697909345240556
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9517647058823528 0.9226648031679479
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7915079287551692
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9762950901652677
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8978676470588236 0.9274594768095009
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8295399042688287
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9866708577900094
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9646224146224147 0.9530256359300476
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.785418905278239
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9638197133752598
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8836376404494383 0.8955165692007796
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7555110546709648
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9746188719840173
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.936289154445048 0.9274292742927429
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7524014196867572
# processing feat: AtomPairFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9924802733026159
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9609313725490196 0.9215467039366411
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.9317019960274819
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9946478493489904
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9186029411764706 0.9392820842026427
# 14/14 [==============================] - 0s 2ms/step
# e_roc_auc =  0.9202403047767901
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9974522181494923
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9673160173160172 0.9682780206677265
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.9414704828888673
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9943691055341941
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9131788389513109 0.9200779727095516
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.9304972159812445
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9912183033656062
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9484202426217634 0.9345141451414515
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.9171143889811469
# processing feat: TorsionFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9851917696834387
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9508823529411765 0.9155369205683671
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8146755234280876
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9640246455748827
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 2ms/step
# test_roc_auc, valid_roc_auc =  0.8931617647058824 0.9098593056224256
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8063071863501676
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9871552978640493
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9523088023088023 0.9526281796502384
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7701963465859138
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9797863560008514
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8982443820224719 0.8921539961013645
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7367555598971054
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9884205471031197
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9463833061741806 0.9169987699876999
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7442447331575006
# processing feat: AvalonFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9908869778531167
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9636274509803923 0.9305380852550664
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.5962195955846439
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9900928916149012
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.90375 0.9303482587064678
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.5847904659568233
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9875567780510972
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 2ms/step
# test_roc_auc, valid_roc_auc =  0.9575998075998077 0.9440828696343402
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.5798410992803882
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9859424790482796
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9023174157303371 0.9028265107212475
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.5602552831233109
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.990748424773321
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9446179612529423 0.928019680196802
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.5357526619126697
# processing feat: EstateFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.852329993614568
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.857328431372549 0.8302119729792686
# 14/14 [==============================] - 0s 989us/step
# e_roc_auc =  0.6243691185568688
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.851098145481494
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.7996078431372549 0.8234098325576419
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.6026830777245938
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 902us/step
# train_roc_auc =  0.8365465701794979
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8988696488696488 0.8857810015898252
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.6109537299339
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 892us/step
# train_roc_auc =  0.8522312261407644
# 11/11 [==============================] - 0s 963us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.7939606741573033 0.816812865497076
# 14/14 [==============================] - 0s 885us/step
# e_roc_auc =  0.6000781478948911
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.8528984170892885
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 848us/step
# test_roc_auc, valid_roc_auc =  0.8630499728408472 0.7831242312423125
# 14/14 [==============================] - 0s 805us/step
# e_roc_auc =  0.5847090618996451
# processing feat: MACCSFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.939326911150618
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9318627450980392 0.889727463312369
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7458076910553222
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 985us/step
# train_roc_auc =  0.939922457267146
# 11/11 [==============================] - 0s 837us/step
# 11/11 [==============================] - 0s 815us/step
# test_roc_auc, valid_roc_auc =  0.8730147058823527 0.9110362167656342
# 14/14 [==============================] - 0s 854us/step
# e_roc_auc =  0.7385790107778971
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9425525615577582
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 924us/step
# test_roc_auc, valid_roc_auc =  0.9406685906685905 0.9360592209856916
# 14/14 [==============================] - 0s 886us/step
# e_roc_auc =  0.7376021620917586
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9415809533434705
# 11/11 [==============================] - 0s 884us/step
# 11/11 [==============================] - 0s 974us/step
# test_roc_auc, valid_roc_auc =  0.8441479400749063 0.8697612085769981
# 14/14 [==============================] - 0s 935us/step
# e_roc_auc =  0.7244798280746312
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9438835100660827
# 11/11 [==============================] - 0s 987us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9231848632989318 0.9043788437884378
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7365276285370063
# processing feat: PharmacoErGFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9435873112124817
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9393382352941176 0.9035872350337759
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8358242974829866
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 983us/step
# train_roc_auc =  0.9496469305248444
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 961us/step
# test_roc_auc, valid_roc_auc =  0.8740931372549019 0.9229925640614133
# 14/14 [==============================] - 0s 908us/step
# e_roc_auc =  0.8247533457067501
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9395066398353588
# 11/11 [==============================] - 0s 989us/step
# 11/11 [==============================] - 0s 879us/step
# test_roc_auc, valid_roc_auc =  0.9474025974025974 0.9364069952305246
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8306144378235811
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9498418189140478
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8753043071161049 0.871832358674464
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8382338575754616
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9493714461349315
# 11/11 [==============================] - 0s 987us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9162819120043454 0.9156457564575646
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8373221321350657
# processing feat: PharmacoPFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9407188434558509
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9272549019607844 0.8813650128115537
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8089935202370486
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9434211438004977
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 867us/step
# test_roc_auc, valid_roc_auc =  0.8796078431372548 0.9141389825068207
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.816157077268731
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9301500584524709
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9385040885040885 0.9343451907790143
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8087655888769496
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9623251853995642
# 11/11 [==============================] - 0s 956us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8758426966292135 0.8860623781676414
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7467031356842825
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9402474258490856
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9156481984428753 0.9112915129151291
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7956106932369509
# processing feat: PubChemFP
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9687305240494971
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.953186274509804 0.9086419753086419
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7004981928299306
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9690567140438505
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8999019607843137 0.9203712619697213
# 14/14 [==============================] - 0s 2ms/step
# e_roc_auc =  0.652827976946371
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9621740970311017
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9700577200577201 0.9405057631160573
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.677835303311517
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9612253444994173
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8874297752808988 0.8874512670565302
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.6840545732799324
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9731347010911326
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9282093065363027 0.9090774907749077
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7084106671876527
# processing feat: MHFP6
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9282044685773962
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9124019607843138 0.8704402515723271
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8068118915046726
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.918546616015858
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8648529411764706 0.8947734446049322
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8059327276871481
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.8404258962712194
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8999037999037999 0.8675476947535772
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7609325648790336
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.842793572917193
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.766807116104869 0.8126218323586745
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7494057503825992
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.8061725833717536
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8073510773130544 0.7768757687576876
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.6050926378170688
# processing feat: MAP4
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9973589271249171
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9648529411764706 0.9249010016305614
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.9006870502425841
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9928937989914023
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9137990196078432 0.9347349275129727
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8966168473836735
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9889377937845538
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9654882154882155 0.9575963831478538
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8960307381719905
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9931138398496897
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9164794007490636 0.909551656920078
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8930350688678323
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9859570462578761
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9356328082563824 0.9212792127921279
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8677346878968448

# %%
for feature in descriptor_list:
    csv_feat_file = f"fp/Main_{feature}S.csv"
    tdf = pd.read_csv(csv_feat_file,nrows=3)
    n_feats = len(tdf.columns)
    print(f'processing feat: {feature}')
    X,y,X_e,y_e = get_Xye_for_one_descriptor(feature)
    for i in range(num_folds): 
        run_one_keras_fcnn(feature,i)
# Out:
# processing feat: Property
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 913us/step
# train_roc_auc =  0.8487169416077508
# 11/11 [==============================] - 0s 883us/step
# 11/11 [==============================] - 0s 799us/step
# test_roc_auc, valid_roc_auc =  0.8755637254901959 0.805008152806895
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7255218000065123
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 945us/step
# train_roc_auc =  0.8480498334066383
# 11/11 [==============================] - 0s 866us/step
# 11/11 [==============================] - 0s 998us/step
# test_roc_auc, valid_roc_auc =  0.8148774509803922 0.8659391215963195
# 14/14 [==============================] - 0s 852us/step
# e_roc_auc =  0.7244472664517599
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 914us/step
# train_roc_auc =  0.8416584975279476
# 11/11 [==============================] - 0s 837us/step
# 11/11 [==============================] - 0s 884us/step
# test_roc_auc, valid_roc_auc =  0.8703463203463203 0.8493392289348172
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7258474162352253
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 853us/step
# train_roc_auc =  0.8578686285408906
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8106507490636704 0.7860136452241715
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7189769138093842
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 911us/step
# train_roc_auc =  0.852552251421546
# 11/11 [==============================] - 0s 931us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8416621401412276 0.8023616236162361
# 14/14 [==============================] - 0s 957us/step
# e_roc_auc =  0.7091107420793852
# processing feat: Constitution
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 959us/step
# train_roc_auc =  0.9341913853324942
# 11/11 [==============================] - 0s 971us/step
# 11/11 [==============================] - 0s 882us/step
# test_roc_auc, valid_roc_auc =  0.9065441176470589 0.9025157232704403
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7417537690078474
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 921us/step
# train_roc_auc =  0.9333061702807084
# 11/11 [==============================] - 0s 916us/step
# 11/11 [==============================] - 0s 810us/step
# test_roc_auc, valid_roc_auc =  0.8750980392156862 0.8942384849943829
# 14/14 [==============================] - 0s 833us/step
# e_roc_auc =  0.7391162775552733
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 988us/step
# train_roc_auc =  0.9310591922599186
# 11/11 [==============================] - 0s 957us/step
# 11/11 [==============================] - 0s 810us/step
# test_roc_auc, valid_roc_auc =  0.9379028379028379 0.924508147853736
# 14/14 [==============================] - 0s 989us/step
# e_roc_auc =  0.7491126957767575
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9358371270762222
# 11/11 [==============================] - 0s 932us/step
# 11/11 [==============================] - 0s 877us/step
# test_roc_auc, valid_roc_auc =  0.8757022471910112 0.8766812865497076
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7375207580345804
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 896us/step
# train_roc_auc =  0.9363819732595666
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 865us/step
# test_roc_auc, valid_roc_auc =  0.8890322288611261 0.875990159901599
# 14/14 [==============================] - 0s 909us/step
# e_roc_auc =  0.7176907297059686
# processing feat: Autocorr
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 926us/step
# train_roc_auc =  0.9743924269082412
# 11/11 [==============================] - 0s 835us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9328921568627451 0.9187980433263452
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8414086158054118
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 952us/step
# train_roc_auc =  0.9798393413386515
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 961us/step
# test_roc_auc, valid_roc_auc =  0.8980147058823529 0.9328090729149949
# 14/14 [==============================] - 0s 818us/step
# e_roc_auc =  0.8197551365960081
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9855881932097713
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 996us/step
# test_roc_auc, valid_roc_auc =  0.9665464165464166 0.932606319554849
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.80383250301195
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9845398277924016
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8960440074906367 0.9022904483430799
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7961153983914558
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9162770862148456
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 980us/step
# test_roc_auc, valid_roc_auc =  0.8826045627376425 0.8515129151291513
# 14/14 [==============================] - 0s 864us/step
# e_roc_auc =  0.6793819803979031
# processing feat: Fragment
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 867us/step
# train_roc_auc =  0.9124319155224188
# 11/11 [==============================] - 0s 970us/step
# 11/11 [==============================] - 0s 911us/step
# test_roc_auc, valid_roc_auc =  0.8610049019607844 0.8557186116934545
# 14/14 [==============================] - 0s 873us/step
# e_roc_auc =  0.5655139852170232
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 953us/step
# train_roc_auc =  0.9088292975363463
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8270343137254901 0.8835660407639223
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.5729705968545472
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 764us/step
# train_roc_auc =  0.8973439897464623
# 11/11 [==============================] - 0s 865us/step
# 11/11 [==============================] - 0s 872us/step
# test_roc_auc, valid_roc_auc =  0.8988936988936989 0.9005862480127186
# 14/14 [==============================] - 0s 979us/step
# e_roc_auc =  0.5383575917423724
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 934us/step
# train_roc_auc =  0.9120586663481607
# 11/11 [==============================] - 0s 847us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8278558052434457 0.8572855750487329
# 14/14 [==============================] - 0s 825us/step
# e_roc_auc =  0.5413206994236592
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 913us/step
# train_roc_auc =  0.9013566159520516
# 11/11 [==============================] - 0s 822us/step
# 11/11 [==============================] - 0s 962us/step
# test_roc_auc, valid_roc_auc =  0.8814955640050698 0.8336285362853628
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.5498192829930644
# processing feat: Charge
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 860us/step
# train_roc_auc =  0.761568427484002
# 11/11 [==============================] - 0s 816us/step
# 11/11 [==============================] - 0s 848us/step
# test_roc_auc, valid_roc_auc =  0.7536764705882352 0.6723969252271138
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8113867995180879
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.860725840950034
# 11/11 [==============================] - 0s 852us/step
# 11/11 [==============================] - 0s 823us/step
# test_roc_auc, valid_roc_auc =  0.8317401960784313 0.8484459423313541
# 14/14 [==============================] - 0s 749us/step
# e_roc_auc =  0.7611442154276968
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 873us/step
# train_roc_auc =  0.8548415085608515
# 11/11 [==============================] - 0s 810us/step
# 11/11 [==============================] - 0s 918us/step
# test_roc_auc, valid_roc_auc =  0.8955026455026455 0.8666782591414944
# 14/14 [==============================] - 0s 803us/step
# e_roc_auc =  0.7515710983035395
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 889us/step
# train_roc_auc =  0.8680788118502595
# 11/11 [==============================] - 0s 863us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8157537453183521 0.8289473684210527
# 14/14 [==============================] - 0s 866us/step
# e_roc_auc =  0.7508873042232425
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 919us/step
# train_roc_auc =  0.8675326571384663
# 11/11 [==============================] - 0s 824us/step
# 11/11 [==============================] - 0s 805us/step
# test_roc_auc, valid_roc_auc =  0.8375203693644758 0.8109717097170971
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7496499625541337
# processing feat: Estate
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9602725063509782
# 11/11 [==============================] - 0s 872us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8942647058823529 0.9040531097134872
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7802090456188336
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 931us/step
# train_roc_auc =  0.9264974574177728
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8688970588235294 0.8764243299630878
# 14/14 [==============================] - 0s 907us/step
# e_roc_auc =  0.7736967210445768
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.9169765611680752
# 11/11 [==============================] - 0s 848us/step
# 11/11 [==============================] - 0s 892us/step
# test_roc_auc, valid_roc_auc =  0.9210918710918712 0.9192418521462641
# 14/14 [==============================] - 0s 969us/step
# e_roc_auc =  0.788512259451011
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 922us/step
# train_roc_auc =  0.9507556094565646
# 11/11 [==============================] - 0s 976us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8786048689138577 0.8741715399610136
# 14/14 [==============================] - 0s 987us/step
# e_roc_auc =  0.7373579499202239
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 891us/step
# train_roc_auc =  0.9364830182879974
# 11/11 [==============================] - 0s 885us/step
# 11/11 [==============================] - 0s 863us/step
# test_roc_auc, valid_roc_auc =  0.8883079847908745 0.8833948339483396
# 14/14 [==============================] - 0s 793us/step
# e_roc_auc =  0.7431539187913125
# processing feat: MOE
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 923us/step
# train_roc_auc =  0.9515143580343894
# 11/11 [==============================] - 0s 794us/step
# 11/11 [==============================] - 0s 808us/step
# test_roc_auc, valid_roc_auc =  0.9280882352941177 0.9086885627766131
# 14/14 [==============================] - 0s 961us/step
# e_roc_auc =  0.8467487219563024
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 753us/step
# train_roc_auc =  0.9476375675561688
# 11/11 [==============================] - 0s 884us/step
# 11/11 [==============================] - 0s 939us/step
# test_roc_auc, valid_roc_auc =  0.8927696078431373 0.9218424008987322
# 14/14 [==============================] - 0s 868us/step
# e_roc_auc =  0.8324541695158086
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 876us/step
# train_roc_auc =  0.9453819503641101
# 11/11 [==============================] - 0s 860us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.956926406926407 0.9340470985691574
# 14/14 [==============================] - 0s 863us/step
# e_roc_auc =  0.7881378007879913
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 847us/step
# train_roc_auc =  0.9591385945005658
# 11/11 [==============================] - 0s 810us/step
# 11/11 [==============================] - 0s 974us/step
# test_roc_auc, valid_roc_auc =  0.8997893258426967 0.9036062378167642
# 14/14 [==============================] - 0s 922us/step
# e_roc_auc =  0.810116896226108
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 829us/step
# train_roc_auc =  0.9519248501613646
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 850us/step
# test_roc_auc, valid_roc_auc =  0.9084057577403586 0.9038130381303813
# 14/14 [==============================] - 0s 800us/step
# e_roc_auc =  0.7857933639412588
# processing feat: Connectivity
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 941us/step
# train_roc_auc =  0.8767022076444494
# 11/11 [==============================] - 0s 950us/step
# 11/11 [==============================] - 0s 815us/step
# test_roc_auc, valid_roc_auc =  0.8719117647058825 0.8367575122292102
# 14/14 [==============================] - 0s 833us/step
# e_roc_auc =  0.86368076584937
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 961us/step
# train_roc_auc =  0.8206507986238726
# 11/11 [==============================] - 0s 811us/step
# 11/11 [==============================] - 0s 819us/step
# test_roc_auc, valid_roc_auc =  0.7685049019607842 0.8317552024822126
# 14/14 [==============================] - 0s 813us/step
# e_roc_auc =  0.7815929145908632
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 842us/step
# train_roc_auc =  0.8823347195499159
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.9130591630591631 0.872689785373609
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.8727003353847157
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 862us/step
# train_roc_auc =  0.88786216654493
# 11/11 [==============================] - 0s 822us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8366338951310861 0.8111111111111111
# 14/14 [==============================] - 0s 889us/step
# e_roc_auc =  0.8667741200221418
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 983us/step
# train_roc_auc =  0.8849635008452436
# 11/11 [==============================] - 0s 870us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.867304906753576 0.8442312423124231
# 14/14 [==============================] - 0s 852us/step
# e_roc_auc =  0.8737423073165966
# processing feat: Topology
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 835us/step
# train_roc_auc =  0.7792730713928051
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 994us/step
# test_roc_auc, valid_roc_auc =  0.8023774509803921 0.757535522944328
# 14/14 [==============================] - 0s 985us/step
# e_roc_auc =  0.7797206212757644
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 806us/step
# train_roc_auc =  0.7908251643339579
# 11/11 [==============================] - 0s 886us/step
# 11/11 [==============================] - 0s 817us/step
# test_roc_auc, valid_roc_auc =  0.7568382352941176 0.8228213769860376
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7629513854970531
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 919us/step
# train_roc_auc =  0.8207240647604667
# 11/11 [==============================] - 0s 840us/step
# 11/11 [==============================] - 0s 873us/step
# test_roc_auc, valid_roc_auc =  0.8605098605098604 0.8325467011128775
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.6889062550877536
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 872us/step
# train_roc_auc =  0.7870512013646755
# 11/11 [==============================] - 0s 794us/step
# 11/11 [==============================] - 0s 918us/step
# test_roc_auc, valid_roc_auc =  0.7676498127340824 0.7096003898635478
# 14/14 [==============================] - 0s 946us/step
# e_roc_auc =  0.7521409267037868
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 860us/step
# train_roc_auc =  0.7837832334409097
# 11/11 [==============================] - 0s 845us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.7808482708672823 0.7540959409594096
# 14/14 [==============================] - 0s 806us/step
# e_roc_auc =  0.7653609455895282
# processing feat: Kappa
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 1s 1ms/step
# train_roc_auc =  0.7854850861114556
# 11/11 [==============================] - 0s 830us/step
# 11/11 [==============================] - 0s 955us/step
# test_roc_auc, valid_roc_auc =  0.799485294117647 0.7470300489168413
# 14/14 [==============================] - 0s 912us/step
# e_roc_auc =  0.7287942431050762
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 856us/step
# train_roc_auc =  0.7742539449187519
# 11/11 [==============================] - 0s 903us/step
# 11/11 [==============================] - 0s 833us/step
# test_roc_auc, valid_roc_auc =  0.7736274509803921 0.8149842186914888
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7267754224870567
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 1ms/step
# train_roc_auc =  0.7787634866898854
# 11/11 [==============================] - 0s 986us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8335978835978836 0.7762321144674085
# 14/14 [==============================] - 0s 903us/step
# e_roc_auc =  0.7092898310051774
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 897us/step
# train_roc_auc =  0.7819922394797327
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.760182584269663 0.7404483430799221
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7096480088567614
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 985us/step
# train_roc_auc =  0.7863589211618258
# 11/11 [==============================] - 0s 999us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.7681966322650733 0.7648462484624845
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7141740744358699
# processing feat: Path
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 693us/step
# train_roc_auc =  0.7621170080652447
# 11/11 [==============================] - 0s 963us/step
# 11/11 [==============================] - 0s 939us/step
# test_roc_auc, valid_roc_auc =  0.7384313725490196 0.7197763801537387
# 14/14 [==============================] - 0s 975us/step
# e_roc_auc =  0.7985086776724952
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 898us/step
# train_roc_auc =  0.7726042036957819
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 898us/step
# test_roc_auc, valid_roc_auc =  0.7358578431372549 0.8083507195206763
# 14/14 [==============================] - 0s 930us/step
# e_roc_auc =  0.7910195044120998
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 971us/step
# train_roc_auc =  0.8022072657639008
# 11/11 [==============================] - 0s 835us/step
# 11/11 [==============================] - 0s 980us/step
# test_roc_auc, valid_roc_auc =  0.846921596921597 0.8141146661367251
# 14/14 [==============================] - 0s 993us/step
# e_roc_auc =  0.7067825860440884
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 712us/step
# train_roc_auc =  0.7642558215386593
# 11/11 [==============================] - 0s 796us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.7201544943820225 0.6881091617933723
# 14/14 [==============================] - 0s 961us/step
# e_roc_auc =  0.7985738009182377
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 883us/step
# train_roc_auc =  0.803967650222837
# 11/11 [==============================] - 0s 920us/step
# 11/11 [==============================] - 0s 875us/step
# test_roc_auc, valid_roc_auc =  0.8308211117146479 0.7959655596555965
# 14/14 [==============================] - 0s 871us/step
# e_roc_auc =  0.6923577871121097
# processing feat: Matrix
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 923us/step
# train_roc_auc =  0.8024482083273996
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 851us/step
# test_roc_auc, valid_roc_auc =  0.8380392156862746 0.7820172373631493
# 14/14 [==============================] - 0s 33ms/step
# e_roc_auc =  0.7447005958776985
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 916us/step
# train_roc_auc =  0.8378685840468028
# 11/11 [==============================] - 0s 895us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.7866911764705882 0.8641202589204515
# 14/14 [==============================] - 0s 917us/step
# e_roc_auc =  0.7435935007000749
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 975us/step
# train_roc_auc =  0.7700740093523953
# 11/11 [==============================] - 0s 961us/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8055315055315057 0.7752136327503973
# 14/14 [==============================] - 0s 902us/step
# e_roc_auc =  0.556657223796034
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 928us/step
# train_roc_auc =  0.8003227935422916
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.7746956928838952 0.7353313840155946
# 14/14 [==============================] - 0s 830us/step
# e_roc_auc =  0.7147113412132461
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 938us/step
# train_roc_auc =  0.7938992623328723
# 11/11 [==============================] - 0s 874us/step
# 11/11 [==============================] - 0s 905us/step
# test_roc_auc, valid_roc_auc =  0.7900823827629911 0.7534071340713406
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7050079775976035
# processing feat: InfoContent
# values_col =  label
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 932us/step
# train_roc_auc =  0.8475941315276495
# 11/11 [==============================] - 0s 947us/step
# 11/11 [==============================] - 0s 828us/step
# test_roc_auc, valid_roc_auc =  0.8716666666666668 0.8086885627766132
# 14/14 [==============================] - 0s 865us/step
# e_roc_auc =  0.7760737195141807
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 912us/step
# train_roc_auc =  0.8533925698758231
# 11/11 [==============================] - 0s 834us/step
# 11/11 [==============================] - 0s 878us/step
# test_roc_auc, valid_roc_auc =  0.8124264705882354 0.8512277323062107
# 14/14 [==============================] - 0s 943us/step
# e_roc_auc =  0.7599882778157663
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 837us/step
# train_roc_auc =  0.8461680143208553
# 11/11 [==============================] - 0s 824us/step
# 11/11 [==============================] - 0s 812us/step
# test_roc_auc, valid_roc_auc =  0.864911014911015 0.8486685214626392
# 14/14 [==============================] - 0s 1ms/step
# e_roc_auc =  0.7498941747256684
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 901us/step
# train_roc_auc =  0.8635688133662252
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# test_roc_auc, valid_roc_auc =  0.8082631086142322 0.807066276803119
# 14/14 [==============================] - 0s 819us/step
# e_roc_auc =  0.743772589625867
# 2769 346 347
# (2769, 1)
# 87/87 [==============================] - 0s 869us/step
# train_roc_auc =  0.8331443061318581
# 11/11 [==============================] - 0s 964us/step
# 11/11 [==============================] - 0s 986us/step
# test_roc_auc, valid_roc_auc =  0.8200932464240449 0.8029028290282904
# 14/14 [==============================] - 0s 871us/step
# e_roc_auc =  0.7363159779883429

# %% [markdown]
# free GPU memory

# %%
# free GPU memory
from numba import cuda 
device = cuda.get_current_device()
device.reset()
cuda.close()

# %% [markdown]
# LogisticRegression

# %% [markdown]
# #  Log_model.predict(X_T) will output 0,1;  while Log_model.predict_proba will output proba with 2 colums.

# %%
def run_log_with_save(feature,num_folds):  
    for i in range(num_folds): 
        #print(f'processing fold: {i}')
        pklf = f'./rand_MorganFP/get_split/split_indices_fold{i}.pckl'
        train_idx, valid_idx, test_idx = pd.read_pickle(pklf)
        print(len(train_idx), len(valid_idx), len(test_idx))
        #get X and Y (main set and external set)
        X_T = X[train_idx];y_T = y[train_idx]
        X_valid = X[valid_idx];y_valid = y[valid_idx]
        X_test = X[test_idx];y_test = y[test_idx] 
        #Log_model = LogisticRegression(
        #  penalty= 'l2', C=1.0, class_weight="balanced", dual=False, fit_intercept=True,
        #  max_iter=100,  multi_class='ovr',  n_jobs=-1,
        #  random_state=None,solver='liblinear',tol=0.0001,verbose=0,warm_start=False)
        # following is the parameters from deepchem 
        Log_model = LogisticRegression( penalty='l2', C=1. / 1. , class_weight="balanced",  n_jobs=2)
        Log_model.fit(X_T, y_T)
        y_prob_T = Log_model.predict_proba(X_T)[:,1]
        train_roc_auc = ROC_AUC(y_T,y_prob_T)
        #print('train_roc_auc = ', train_roc_auc )
        y_prob_valid=Log_model.predict_proba(X_valid)[:,1]  ## no need other parameters here
        valid_roc_auc = ROC_AUC(y_valid,y_prob_valid)
        y_prob_test=Log_model.predict_proba(X_test)[:,1]
        test_roc_auc = ROC_AUC(y_test,y_prob_test)
        #print('test_roc_auc, valid_roc_auc = ', test_roc_auc, valid_roc_auc)
        y_prob_e=Log_model.predict_proba(X_e)[:,1]  ## no need other parameters here
        e_roc_auc = ROC_AUC(y_e,y_prob_e)
        print('e_roc_auc = ', e_roc_auc)
        if not os.path.exists('log'):os.mkdir('log')
        pd.DataFrame(y_prob_T,columns=['prob']).to_csv(f'log/p_train_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_valid,columns=['prob']).to_csv(f'log/p_val_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_test,columns=['prob']).to_csv(f'log/p_test_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_e,columns=['prob']).to_csv(f'log/p_Ext_{feature}_fold{i}.csv',index=False)
        model_file=f"log/model_{feature}_fold{i}.job"
        joblib.dump(Log_model,model_file,compress=3)
    return

# %%
num_folds = 5
for feature in fingerprint_list:
    X,y,X_e,y_e = get_Xye_for_one_fingerprint(feature)
    print(f'processing feat: {feature}')
    run_log_with_save(feature,num_folds)    
for feature in descriptor_list:    
    X,y,X_e,y_e = get_Xye_for_one_descriptor(feature)
    print(f'processing feat: {feature}')
    run_log_with_save(feature,num_folds)
# Out:
# values_col =  label
# processing feat: MorganFP
# 2769 346 347
# e_roc_auc =  0.7922568460812087
# 2769 346 347
# e_roc_auc =  0.8105239165119988
# 2769 346 347
# e_roc_auc =  0.834847448796848
# 2769 346 347
# e_roc_auc =  0.7827162905799225
# 2769 346 347
# e_roc_auc =  0.8247533457067499
# values_col =  label
# processing feat: RDkitFP
# 2769 346 347
# e_roc_auc =  0.6560190159877567
# 2769 346 347
# e_roc_auc =  0.6656084139233499
# 2769 346 347
# e_roc_auc =  0.5689980788642507
# 2769 346 347
# e_roc_auc =  0.6137377486893947
# 2769 346 347
# e_roc_auc =  0.6269740483865717
# values_col =  label
# processing feat: AtomPairFP
# 2769 346 347
# e_roc_auc =  0.8977565041841686
# 2769 346 347
# e_roc_auc =  0.9256618149848589
# 2769 346 347
# e_roc_auc =  0.9070040050796131
# 2769 346 347
# e_roc_auc =  0.9207612907427306
# 2769 346 347
# e_roc_auc =  0.8739051154309532
# values_col =  label
# processing feat: TorsionFP
# 2769 346 347
# e_roc_auc =  0.6600892188466673
# 2769 346 347
# e_roc_auc =  0.6608055745498356
# 2769 346 347
# e_roc_auc =  0.6302464914851356
# 2769 346 347
# e_roc_auc =  0.5768942724105369
# 2769 346 347
# e_roc_auc =  0.6329328253720164
# values_col =  label
# processing feat: AvalonFP
# 2769 346 347
# e_roc_auc =  0.6607241704926574
# 2769 346 347
# e_roc_auc =  0.651965093940282
# 2769 346 347
# e_roc_auc =  0.6159356582332064
# 2769 346 347
# e_roc_auc =  0.5653348962912312
# 2769 346 347
# e_roc_auc =  0.5977174302367231
# values_col =  label
# processing feat: EstateFP
# 2769 346 347
# e_roc_auc =  0.604539090228257
# 2769 346 347
# e_roc_auc =  0.6022434958158315
# 2769 346 347
# e_roc_auc =  0.593761193057862
# 2769 346 347
# e_roc_auc =  0.5990524567744456
# 2769 346 347
# e_roc_auc =  0.5530103220344502
# values_col =  label
# processing feat: MACCSFP
# 2769 346 347
# e_roc_auc =  0.6850802644003777
# 2769 346 347
# e_roc_auc =  0.6194197518804337
# 2769 346 347
# e_roc_auc =  0.6497509035850346
# 2769 346 347
# e_roc_auc =  0.62731594542672
# 2769 346 347
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e_roc_auc =  0.6257367067174627
# values_col =  label
# processing feat: PharmacoErGFP
# 2769 346 347
# e_roc_auc =  0.8189248152127901
# 2769 346 347
# e_roc_auc =  0.8100843346032366
# 2769 346 347
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e_roc_auc =  0.7967991924717528
# 2769 346 347
# e_roc_auc =  0.825941844941552
# 2769 346 347
# e_roc_auc =  0.7952362345739311
# values_col =  label
# processing feat: PharmacoPFP
# 2769 346 347
# e_roc_auc =  0.5556152518641528
# 2769 346 347
# e_roc_auc =  0.5809970368923187
# 2769 346 347
# e_roc_auc =  0.5049330858649995
# 2769 346 347
# e_roc_auc =  0.489450034189704
# 2769 346 347
# e_roc_auc =  0.5405717820976197
# values_col =  label
# processing feat: PubChemFP
# 2769 346 347
# e_roc_auc =  0.638321773957214
# 2769 346 347
# e_roc_auc =  0.6293347660447397
# 2769 346 347
# e_roc_auc =  0.6205105662466218
# 2769 346 347
# e_roc_auc =  0.6188010810458793
# 2769 346 347
# e_roc_auc =  0.6470482888867181
# values_col =  label
# processing feat: MHFP6
# 2769 346 347
# e_roc_auc =  0.8079841099280388
# 2769 346 347
# e_roc_auc =  0.757904333952004
# 2769 346 347
# e_roc_auc =  0.7830419068086353
# 2769 346 347
# e_roc_auc =  0.8116310116896225
# 2769 346 347
# e_roc_auc =  0.7400931262414119
# values_col =  label
# processing feat: MAP4
# 2769 346 347
# e_roc_auc =  0.8499234801862525
# 2769 346 347
# e_roc_auc =  0.8552473055257074
# 2769 346 347
# e_roc_auc =  0.8327309433102146
# 2769 346 347
# e_roc_auc =  0.8426947999088275
# 2769 346 347
# e_roc_auc =  0.8203738074305623
# values_col =  label
# processing feat: Property
# 2769 346 347
# e_roc_auc =  0.7045846765002768
# 2769 346 347
# e_roc_auc =  0.692797369020872
# 2769 346 347
# e_roc_auc =  0.7042264986486927
# 2769 346 347
# e_roc_auc =  0.6904529321741395
# 2769 346 347
# e_roc_auc =  0.6796750350037446
# values_col =  label
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# processing feat: Constitution
# 2769 346 347
# e_roc_auc =  0.7204259060271563
# 2769 346 347
# e_roc_auc =  0.727442935755918
# 2769 346 347
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e_roc_auc =  0.731675946729185
# 2769 346 347
# e_roc_auc =  0.7245612321318096
# 2769 346 347
# e_roc_auc =  0.6906645827228028
# values_col =  label
# processing feat: Autocorr
# 2769 346 347
# e_roc_auc =  0.8279606655595714
# 2769 346 347
# e_roc_auc =  0.803474325160366
# 2769 346 347
# e_roc_auc =  0.7963107681286835
# 2769 346 347
# e_roc_auc =  0.7762853700628439
# 2769 346 347
# e_roc_auc =  0.8291328839829377
# values_col =  label
# processing feat: Fragment
# 2769 346 347
# e_roc_auc =  0.44858519748624276
# 2769 346 347
# e_roc_auc =  0.436569958646739
# 2769 346 347
# e_roc_auc =  0.4192960177135229
# 2769 346 347
# e_roc_auc =  0.42401745302985894
# 2769 346 347
# e_roc_auc =  0.428429552928918
# values_col =  label
# processing feat: Charge
# 2769 346 347
# e_roc_auc =  0.7746898505421511
# 2769 346 347
# e_roc_auc =  0.7888378756797239
# 2769 346 347
# e_roc_auc =  0.7742014261990817
# 2769 346 347
# e_roc_auc =  0.7703754355117058
# 2769 346 347
# e_roc_auc =  0.7898310051772981
# values_col =  label
# processing feat: Estate
# 2769 346 347
# e_roc_auc =  0.7680472794764092
# 2769 346 347
# e_roc_auc =  0.7496825241770051
# 2769 346 347
# e_roc_auc =  0.7672658005274983
# 2769 346 347
# e_roc_auc =  0.7346716160333431
# 2769 346 347
# e_roc_auc =  0.7288919279736903
# values_col =  label
# processing feat: MOE
# 2769 346 347
# e_roc_auc =  0.8469115300706587
# 2769 346 347
# e_roc_auc =  0.8562078734004103
# 2769 346 347
# e_roc_auc =  0.8477906938881834
# 2769 346 347
# e_roc_auc =  0.8230601413174432
# 2769 346 347
# e_roc_auc =  0.8326006968187294
# values_col =  label
# processing feat: Connectivity
# 2769 346 347
# e_roc_auc =  0.7622187489824492
# 2769 346 347
# e_roc_auc =  0.7840675979290808
# 2769 346 347
# e_roc_auc =  0.766826218618736
# 2769 346 347
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e_roc_auc =  0.7655237537038846
# 2769 346 347
# e_roc_auc =  0.7537038846016085
# values_col =  label
# processing feat: Topology
# 2769 346 347
# e_roc_auc =  0.6893946794308228
# 2769 346 347
# e_roc_auc =  0.6729673406922602
# 2769 346 347
# e_roc_auc =  0.6733417993552798
# 2769 346 347
# e_roc_auc =  0.6815147666959721
# 2769 346 347
# e_roc_auc =  0.6702484451825079
# values_col =  label
# processing feat: Kappa
# 2769 346 347
# e_roc_auc =  0.723258767216958
# 2769 346 347
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/phzd/miniconda3/envs/chemprop1.4.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e_roc_auc =  0.7233890137084433
# 2769 346 347
# e_roc_auc =  0.7162905799225032
# 2769 346 347
# e_roc_auc =  0.7170720588714142
# 2769 346 347
# e_roc_auc =  0.7089967763993358
# values_col =  label
# processing feat: Path
# 2769 346 347
# e_roc_auc =  0.726807984109928
# 2769 346 347
# e_roc_auc =  0.7123180619322067
# 2769 346 347
# e_roc_auc =  0.7094526391195337
# 2769 346 347
# e_roc_auc =  0.6928136498323076
# 2769 346 347
# e_roc_auc =  0.7041450945915144
# values_col =  label
# processing feat: Matrix
# 2769 346 347
# e_roc_auc =  0.7769040408973983
# 2769 346 347
# e_roc_auc =  0.766370355898538
# 2769 346 347
# e_roc_auc =  0.769870730357201
# 2769 346 347
# e_roc_auc =  0.7413141870990849
# 2769 346 347
# e_roc_auc =  0.7603952981016574
# values_col =  label
# processing feat: InfoContent
# 2769 346 347
# e_roc_auc =  0.7708964214776464
# 2769 346 347
# e_roc_auc =  0.7478427924847774
# 2769 346 347
# e_roc_auc =  0.7538341310930937
# 2769 346 347
# e_roc_auc =  0.737488196411709
# 2769 346 347
# e_roc_auc =  0.7449610888606689

# %% [markdown]
# # svm

# %%
def run_svm_with_save(feature,num_folds):  
    for i in range(num_folds): 
        #print(f'processing fold: {i}')
        pklf = f'./rand_MorganFP/get_split/split_indices_fold{i}.pckl'
        train_idx, valid_idx, test_idx = pd.read_pickle(pklf)
        print(len(train_idx), len(valid_idx), len(test_idx))
        #get X and Y (main set and external set)
        X_T = X[train_idx];y_T = y[train_idx]
        X_valid = X[valid_idx];y_valid = y[valid_idx]
        X_test = X[test_idx];y_test = y[test_idx] 
        svm_clf = svm.SVC(C=1.0, coef0=0.0, degree=3, gamma='auto', kernel='linear', probability=True, shrinking=True)
        ## below is from deepchem
        #svm_clf = svm.SVC(C=1.0, gamma=0.05, class_weight="balanced", probability=True)  ## much slower 
        svm_clf.fit(X_T, y_T)
        #y_p_T = svm_clf.predict(X_T)  ## svm_clf.predict(X_T) is diff from svm_clf.predict_proba(X_T)
        y_prob_T = svm_clf.predict_proba(X_T)[:,1]
        train_roc_auc = ROC_AUC(y_T,y_prob_T)
        #print('train_roc_auc = ', train_roc_auc )
        y_prob_valid=svm_clf.predict_proba(X_valid)[:,1]  ## no need other parameters here
        valid_roc_auc = ROC_AUC(y_valid,y_prob_valid)
        y_prob_test=svm_clf.predict_proba(X_test)[:,1]  
        test_roc_auc = ROC_AUC(y_test,y_prob_test)
        #print('test_roc_auc, valid_roc_auc = ', test_roc_auc, valid_roc_auc)
        y_prob_e=svm_clf.predict_proba(X_e)[:,1]  ## no need other parameters here
        e_roc_auc = ROC_AUC(y_e,y_prob_e)
        print('e_roc_auc = ', e_roc_auc)
        if not os.path.exists('svm'):os.mkdir('svm')
        pd.DataFrame(y_prob_T,columns=['prob']).to_csv(f'svm/p_train_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_valid,columns=['prob']).to_csv(f'svm/p_val_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_test,columns=['prob']).to_csv(f'svm/p_test_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_e,columns=['prob']).to_csv(f'svm/p_Ext_{feature}_fold{i}.csv',index=False)
        model_file=f"svm/model_{feature}_fold{i}.job"
        joblib.dump(svm_clf,model_file,compress=3)
    return

# %%
from sklearn import svm
num_folds = 5;
for feature in fingerprint_list:
    X,y,X_e,y_e = get_Xye_for_one_fingerprint(feature)
    print(f'processing feat: {feature}')
    run_svm_with_save(feature,num_folds)
# Out:
# values_col =  label
# processing feat: MorganFP
# 2769 346 347
# e_roc_auc =  0.7301129888313633
# 2769 346 347
# e_roc_auc =  0.8134707433818502
# 2769 346 347
# e_roc_auc =  0.8417667936569958
# 2769 346 347
# e_roc_auc =  0.7355670606623033
# 2769 346 347
# e_roc_auc =  0.8167269056689784
# values_col =  label
# processing feat: RDkitFP
# 2769 346 347
# e_roc_auc =  0.5739962879749927
# 2769 346 347
# e_roc_auc =  0.5877698544495457
# 2769 346 347
# e_roc_auc =  0.545602552831233
# 2769 346 347
# e_roc_auc =  0.6196802448634039
# 2769 346 347
# e_roc_auc =  0.5977337110481586
# values_col =  label
# processing feat: AtomPairFP
# 2769 346 347
# e_roc_auc =  0.853716909250757
# 2769 346 347
# e_roc_auc =  0.9062062453192666
# 2769 346 347
# e_roc_auc =  0.8614340138712514
# 2769 346 347
# e_roc_auc =  0.8965680049493667
# 2769 346 347
# e_roc_auc =  0.8554752368858063
# values_col =  label
# processing feat: TorsionFP
# 2769 346 347
# e_roc_auc =  0.6192081013317703
# 2769 346 347
# e_roc_auc =  0.5924750089544464
# 2769 346 347
# e_roc_auc =  0.6819380677932989
# 2769 346 347
# e_roc_auc =  0.5380970987594021
# 2769 346 347
# e_roc_auc =  0.5549965810295985
# values_col =  label
# processing feat: AvalonFP
# 2769 346 347
# e_roc_auc =  0.7083618247533456
# 2769 346 347
# e_roc_auc =  0.7309270294031455
# 2769 346 347
# e_roc_auc =  0.6372472404024616
# 2769 346 347
# e_roc_auc =  0.5750219790954381
# 2769 346 347
# e_roc_auc =  0.6350330500472143
# values_col =  label
# processing feat: EstateFP
# 2769 346 347
# e_roc_auc =  0.5359968740842044
# 2769 346 347
# e_roc_auc =  0.537787763342125
# 2769 346 347
# e_roc_auc =  0.5229071016899483
# 2769 346 347
# e_roc_auc =  0.5318941096024227
# 2769 346 347
# e_roc_auc =  0.5232652795415325
# values_col =  label
# processing feat: MACCSFP
# 2769 346 347
# e_roc_auc =  0.6835498681254274
# 2769 346 347
# e_roc_auc =  0.6603985542639446
# 2769 346 347
# e_roc_auc =  0.663198853830875
# 2769 346 347
# e_roc_auc =  0.6623196900133502
# 2769 346 347
# e_roc_auc =  0.6673993031812706
# values_col =  label
# processing feat: PharmacoErGFP
# 2769 346 347
# e_roc_auc =  0.7722965712611116
# 2769 346 347
# e_roc_auc =  0.7748526586565074
# 2769 346 347
# e_roc_auc =  0.7795903747842793
# 2769 346 347
# e_roc_auc =  0.7812184559278433
# 2769 346 347
# e_roc_auc =  0.7263195597668587
# values_col =  label
# processing feat: PharmacoPFP
# 2769 346 347
# e_roc_auc =  0.556022272150044
# 2769 346 347
# e_roc_auc =  0.5457653609455895
# 2769 346 347
# e_roc_auc =  0.43544658265767955
# 2769 346 347
# e_roc_auc =  0.44003777148253076
# 2769 346 347
# e_roc_auc =  0.48380059262153624
# values_col =  label
# processing feat: PubChemFP
# 2769 346 347
# e_roc_auc =  0.6095535801504347
# 2769 346 347
# e_roc_auc =  0.6093582104132069
# 2769 346 347
# e_roc_auc =  0.5901794145420207
# 2769 346 347
# e_roc_auc =  0.5737032333691511
# 2769 346 347
# e_roc_auc =  0.6520302171860246
# values_col =  label
# processing feat: MHFP6
# 2769 346 347
# e_roc_auc =  0.7865097196444271
# 2769 346 347
# e_roc_auc =  0.7382371137377487
# 2769 346 347
# e_roc_auc =  0.7404513040929961
# 2769 346 347
# e_roc_auc =  0.7744293575591807
# 2769 346 347
# e_roc_auc =  0.7055126827521082
# values_col =  label
# processing feat: MAP4
# 2769 346 347
# e_roc_auc =  0.8434762788577382
# 2769 346 347
# e_roc_auc =  0.8454788186643222
# 2769 346 347
# e_roc_auc =  0.8244928527237798
# 2769 346 347
# e_roc_auc =  0.8325355735729868
# 2769 346 347
# e_roc_auc =  0.8246556608381362

# %%
for feature in descriptor_list:
    X,y,X_e,y_e = get_Xye_for_one_descriptor(feature)
    print(f'processing feat: {feature}')
    run_svm_with_save(feature,num_folds)
# Out:
# values_col =  label
# processing feat: Property
# 2769 346 347
# e_roc_auc =  0.8000879163817524
# 2769 346 347
# e_roc_auc =  0.767461170264726
# 2769 346 347
# e_roc_auc =  0.7773273419947251
# 2769 346 347
# e_roc_auc =  0.7731268926443294
# 2769 346 347
# e_roc_auc =  0.7657516850639836
# values_col =  label
# processing feat: Constitution
# 2769 346 347
# e_roc_auc =  0.6987724268177524
# 2769 346 347
# e_roc_auc =  0.7096154472338901
# 2769 346 347
# e_roc_auc =  0.6952557715476541
# 2769 346 347
# e_roc_auc =  0.689427241053694
# 2769 346 347
# e_roc_auc =  0.6710299241314187
# values_col =  label
# processing feat: Autocorr
# 2769 346 347
# e_roc_auc =  0.8512422259125394
# 2769 346 347
# e_roc_auc =  0.8104425124548209
# 2769 346 347
# e_roc_auc =  0.8316075673211553
# 2769 346 347
# e_roc_auc =  0.8229461756373938
# 2769 346 347
# e_roc_auc =  0.8370779199635309
# values_col =  label
# processing feat: Fragment
# 2769 346 347
# e_roc_auc =  0.5707238448764287
# 2769 346 347
# e_roc_auc =  0.5507961316792029
# 2769 346 347
# e_roc_auc =  0.5231838754843542
# 2769 346 347
# e_roc_auc =  0.5984663475627625
# 2769 346 347
# e_roc_auc =  0.5718309400540522
# values_col =  label
# processing feat: Charge
# 2769 346 347
# e_roc_auc =  0.7330760965126503
# 2769 346 347
# e_roc_auc =  0.7683077724593794
# 2769 346 347
# e_roc_auc =  0.7462961153983916
# 2769 346 347
# e_roc_auc =  0.7267917032984924
# 2769 346 347
# e_roc_auc =  0.7460519032268569
# values_col =  label
# processing feat: Estate
# 2769 346 347
# e_roc_auc =  0.7894239848914069
# 2769 346 347
# e_roc_auc =  0.755462212236658
# 2769 346 347
# e_roc_auc =  0.7626257692683404
# 2769 346 347
# e_roc_auc =  0.7620396600566572
# 2769 346 347
# e_roc_auc =  0.741721207384976
# values_col =  label
# processing feat: MOE
# 2769 346 347
# e_roc_auc =  0.871316466412686
# 2769 346 347
# e_roc_auc =  0.880905864348279
# 2769 346 347
# e_roc_auc =  0.868044023314122
# 2769 346 347
# e_roc_auc =  0.8618735957800138
# 2769 346 347
# e_roc_auc =  0.8614340138712513
# values_col =  label
# processing feat: Connectivity
# 2769 346 347
# e_roc_auc =  0.8246556608381361
# 2769 346 347
# e_roc_auc =  0.8456416267786787
# 2769 346 347
# e_roc_auc =  0.8144150304451173
# 2769 346 347
# e_roc_auc =  0.8171339259548696
# 2769 346 347
# e_roc_auc =  0.8168245905375924
# values_col =  label
# processing feat: Topology
# 2769 346 347
# e_roc_auc =  0.630914004753997
# 2769 346 347
# e_roc_auc =  0.6032366253134056
# 2769 346 347
# e_roc_auc =  0.6022923382501384
# 2769 346 347
# e_roc_auc =  0.6074370746638013
# 2769 346 347
# e_roc_auc =  0.6090325941844941
# values_col =  label
# processing feat: Kappa
# 2769 346 347
# e_roc_auc =  0.8607013773566474
# 2769 346 347
# e_roc_auc =  0.2540783432646283
# 2769 346 347
# e_roc_auc =  0.6315652372114225
# 2769 346 347
# e_roc_auc =  0.4480479307088665
# 2769 346 347
# e_roc_auc =  0.7495034352512129
# values_col =  label
# processing feat: Path
# 2769 346 347
# e_roc_auc =  0.83794080296962
# 2769 346 347
# e_roc_auc =  0.8393735143759566
# 2769 346 347
# e_roc_auc =  0.8086027807625931
# 2769 346 347
# e_roc_auc =  0.8422714988115008
# 2769 346 347
# e_roc_auc =  0.8497281104490249
# values_col =  label
# processing feat: Matrix
# 2769 346 347
# e_roc_auc =  0.7500407020285892
# 2769 346 347
# e_roc_auc =  0.773550193741656
# 2769 346 347
# e_roc_auc =  0.7502360717658169
# 2769 346 347
# e_roc_auc =  0.7128227670867116
# 2769 346 347
# e_roc_auc =  0.728680277425027
# values_col =  label
# processing feat: InfoContent
# 2769 346 347
# e_roc_auc =  0.6546188662042915
# 2769 346 347
# e_roc_auc =  0.6509556836312721
# 2769 346 347
# e_roc_auc =  0.6344632216469669
# 2769 346 347
# e_roc_auc =  0.6201686692064733
# 2769 346 347
# e_roc_auc =  0.6379473152941942

# %% [markdown]
# # rf

# %%
def run_rf_with_save(feature,num_folds):  
    for i in range(num_folds): 
        #print(f'processing fold: {i}')
        pklf = f'./rand_MorganFP/get_split/split_indices_fold{i}.pckl'
        train_idx, valid_idx, test_idx = pd.read_pickle(pklf)
        print(len(train_idx), len(valid_idx), len(test_idx))
        #get X and Y (main set and external set)
        X_T = X[train_idx];y_T = y[train_idx]
        X_valid = X[valid_idx];y_valid = y[valid_idx]
        X_test = X[test_idx];y_test = y[test_idx] 
        #rf_clf = RandomForestClassifier(n_estimators=100, criterion='gini', n_jobs=1)  ## Yang JM's paramters
        #rf_clf = RandomForestClassifier(class_weight="balanced", n_estimators=50, n_jobs=-1) # dc parameters
        rf_clf = RandomForestClassifier(class_weight="balanced", n_estimators=500, n_jobs=-1)  ## my parameters
        rf_clf.fit(X_T, y_T)

        y_prob_T = rf_clf.predict_proba(X_T)[:,1]
        train_roc_auc = ROC_AUC(y_T,y_prob_T)
        #print('train_roc_auc = ', train_roc_auc )
        y_prob_valid=rf_clf.predict_proba(X_valid)[:,1]  ## no need other parameters here
        valid_roc_auc = ROC_AUC(y_valid,y_prob_valid)
        y_prob_test=rf_clf.predict_proba(X_test)[:,1]  
        test_roc_auc = ROC_AUC(y_test,y_prob_test)
        #print('test_roc_auc, valid_roc_auc = ', test_roc_auc, valid_roc_auc)
        y_prob_e=rf_clf.predict_proba(X_e)[:,1]  ## no need other parameters here
        e_roc_auc = ROC_AUC(y_e,y_prob_e)
        print('e_roc_auc = ', e_roc_auc)

        if not os.path.exists('rf'):os.mkdir('rf')
        pd.DataFrame(y_prob_T,columns=['prob']).to_csv(f'rf/p_train_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_valid,columns=['prob']).to_csv(f'rf/p_val_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_test,columns=['prob']).to_csv(f'rf/p_test_{feature}_fold{i}.csv',index=False)
        pd.DataFrame(y_prob_e,columns=['prob']).to_csv(f'rf/p_Ext_{feature}_fold{i}.csv',index=False)
        model_file=f"rf/model_{feature}_fold{i}.job"
        joblib.dump(rf_clf,model_file,compress=3)
    return

# %%
num_folds = 5;
for feature in fingerprint_list:
    X,y,X_e,y_e = get_Xye_for_one_fingerprint(feature)
    print(f'processing feat: {feature}')
    run_rf_with_save(feature,num_folds)
# Out:
# values_col =  label
# processing feat: MorganFP
# 2769 346 347
# e_roc_auc =  0.8848946631500114
# 2769 346 347
# e_roc_auc =  0.8912441796099118
# 2769 346 347
# e_roc_auc =  0.887597277848328
# 2769 346 347
# e_roc_auc =  0.8874995929797139
# 2769 346 347
# e_roc_auc =  0.8827130344176354
# values_col =  label
# processing feat: RDkitFP
# 2769 346 347
# e_roc_auc =  0.872228191853082
# 2769 346 347
# e_roc_auc =  0.8716095210185275
# 2769 346 347
# e_roc_auc =  0.8668718048907558
# 2769 346 347
# e_roc_auc =  0.871137377486894
# 2769 346 347
# e_roc_auc =  0.8534238546449155
# values_col =  label
# processing feat: AtomPairFP
# 2769 346 347
# e_roc_auc =  0.9047246914786233
# 2769 346 347
# e_roc_auc =  0.8936863013252581
# 2769 346 347
# e_roc_auc =  0.8986845104360002
# 2769 346 347
# e_roc_auc =  0.8925303637133275
# 2769 346 347
# e_roc_auc =  0.8859854775161995
# values_col =  label
# processing feat: TorsionFP
# 2769 346 347
# e_roc_auc =  0.8636807658493699
# 2769 346 347
# e_roc_auc =  0.8682556738627853
# 2769 346 347
# e_roc_auc =  0.8664647846048648
# 2769 346 347
# e_roc_auc =  0.8675067565367457
# 2769 346 347
# e_roc_auc =  0.8494838982774902
# values_col =  label
# processing feat: AvalonFP
# 2769 346 347
# e_roc_auc =  0.8294259385887793
# 2769 346 347
# e_roc_auc =  0.8215785874767999
# 2769 346 347
# e_roc_auc =  0.8223600664257106
# 2769 346 347
# e_roc_auc =  0.79774347953502
# 2769 346 347
# e_roc_auc =  0.8114030803295236
# values_col =  label
# processing feat: EstateFP
# 2769 346 347
# e_roc_auc =  0.6445736055485007
# 2769 346 347
# e_roc_auc =  0.6336817426980561
# 2769 346 347
# e_roc_auc =  0.6079743414411773
# 2769 346 347
# e_roc_auc =  0.5963172804532577
# 2769 346 347
# e_roc_auc =  0.6040018234508808
# values_col =  label
# processing feat: MACCSFP
# 2769 346 347
# e_roc_auc =  0.7893263000227931
# 2769 346 347
# e_roc_auc =  0.7906124841262088
# 2769 346 347
# e_roc_auc =  0.7946501253622479
# 2769 346 347
# e_roc_auc =  0.8080817947966527
# 2769 346 347
# e_roc_auc =  0.7904659568232881
# values_col =  label
# processing feat: PharmacoErGFP
# 2769 346 347
# e_roc_auc =  0.8469440916935299
# 2769 346 347
# e_roc_auc =  0.8418156360913028
# 2769 346 347
# e_roc_auc =  0.8473185503565499
# 2769 346 347
# e_roc_auc =  0.8502653772264009
# 2769 346 347
# e_roc_auc =  0.8476278857738269
# values_col =  label
# processing feat: PharmacoPFP
# 2769 346 347
# e_roc_auc =  0.8161570772687312
# 2769 346 347
# e_roc_auc =  0.8034092019146233
# 2769 346 347
# e_roc_auc =  0.8226531210315522
# 2769 346 347
# e_roc_auc =  0.8204714922991763
# 2769 346 347
# e_roc_auc =  0.8352870307056104
# values_col =  label
# processing feat: PubChemFP
# 2769 346 347
# e_roc_auc =  0.7860375761127935
# 2769 346 347
# e_roc_auc =  0.7591253948096772
# 2769 346 347
# e_roc_auc =  0.7796717788414574
# 2769 346 347
# e_roc_auc =  0.7754876103024975
# 2769 346 347
# e_roc_auc =  0.7738106867246264
# values_col =  label
# processing feat: MHFP6
# 2769 346 347
# e_roc_auc =  0.826479111718928
# 2769 346 347
# e_roc_auc =  0.8241509556836312
# 2769 346 347
# e_roc_auc =  0.8259092833186806
# 2769 346 347
# e_roc_auc =  0.8306958418807593
# 2769 346 347
# e_roc_auc =  0.8077887401908111
# values_col =  label
# processing feat: MAP4
# 2769 346 347
# e_roc_auc =  0.888329914362932
# 2769 346 347
# e_roc_auc =  0.8771124352837745
# 2769 346 347
# e_roc_auc =  0.8877275243398131
# 2769 346 347
# e_roc_auc =  0.8672788251766469
# 2769 346 347
# e_roc_auc =  0.8768845039236757

# %%
for feature in descriptor_list:    
    X,y,X_e,y_e = get_Xye_for_one_descriptor(feature)
    print(f'processing feat: {feature}')
    run_rf_with_save(feature,num_folds)
# Out:
# values_col =  label
# processing feat: Property
# 2769 346 347
# e_roc_auc =  0.8247859073296213
# 2769 346 347
# e_roc_auc =  0.8218879228940771
# 2769 346 347
# e_roc_auc =  0.7949106183452184
# 2769 346 347
# e_roc_auc =  0.8169548370290776
# 2769 346 347
# e_roc_auc =  0.7980690957637329
# values_col =  label
# processing feat: Constitution
# 2769 346 347
# e_roc_auc =  0.8087655888769496
# 2769 346 347
# e_roc_auc =  0.8130637230959592
# 2769 346 347
# e_roc_auc =  0.8102308619061573
# 2769 346 347
# e_roc_auc =  0.8101657386604149
# 2769 346 347
# e_roc_auc =  0.7985738009182377
# values_col =  label
# processing feat: Autocorr
# 2769 346 347
# e_roc_auc =  0.9273224577512943
# 2769 346 347
# e_roc_auc =  0.9271759304483735
# 2769 346 347
# e_roc_auc =  0.9419426264205009
# 2769 346 347
# e_roc_auc =  0.9223242486405523
# 2769 346 347
# e_roc_auc =  0.9182052033473348
# values_col =  label
# processing feat: Fragment
# 2769 346 347
# e_roc_auc =  0.6717137182117157
# 2769 346 347
# e_roc_auc =  0.649555533847807
# 2769 346 347
# e_roc_auc =  0.65724007684543
# 2769 346 347
# e_roc_auc =  0.6559376119305786
# 2769 346 347
# e_roc_auc =  0.6732115528637947
# values_col =  label
# processing feat: Charge
# 2769 346 347
# e_roc_auc =  0.8282048777311061
# 2769 346 347
# e_roc_auc =  0.8297352740060565
# 2769 346 347
# e_roc_auc =  0.8361010712773925
# 2769 346 347
# e_roc_auc =  0.8310214581094721
# 2769 346 347
# e_roc_auc =  0.8267233238904628
# values_col =  label
# processing feat: Estate
# 2769 346 347
# e_roc_auc =  0.8082446029110091
# 2769 346 347
# e_roc_auc =  0.789733320308684
# 2769 346 347
# e_roc_auc =  0.8091563283514049
# 2769 346 347
# e_roc_auc =  0.8081469180423952
# 2769 346 347
# e_roc_auc =  0.7871772329132884
# values_col =  label
# processing feat: MOE
# 2769 346 347
# e_roc_auc =  0.8477906938881832
# 2769 346 347
# e_roc_auc =  0.837484940249422
# 2769 346 347
# e_roc_auc =  0.8572010028979844
# 2769 346 347
# e_roc_auc =  0.8577871121096675
# 2769 346 347
# e_roc_auc =  0.8283514050340268
# values_col =  label
# processing feat: Connectivity
# 2769 346 347
# e_roc_auc =  0.8451532024356094
# 2769 346 347
# e_roc_auc =  0.8568102634235291
# 2769 346 347
# e_roc_auc =  0.8593175083846178
# 2769 346 347
# e_roc_auc =  0.8611898016997168
# 2769 346 347
# e_roc_auc =  0.8614340138712513
# values_col =  label
# processing feat: Topology
# 2769 346 347
# e_roc_auc =  0.852088828107193
# 2769 346 347
# e_roc_auc =  0.8469278108820943
# 2769 346 347
# e_roc_auc =  0.8092865748428902
# 2769 346 347
# e_roc_auc =  0.7998925466445246
# 2769 346 347
# e_roc_auc =  0.8000553547588812
# values_col =  label
# processing feat: Kappa
# 2769 346 347
# e_roc_auc =  0.7014750415160691
# 2769 346 347
# e_roc_auc =  0.7025170134479503
# 2769 346 347
# e_roc_auc =  0.676418872716616
# 2769 346 347
# e_roc_auc =  0.6870339617726547
# 2769 346 347
# e_roc_auc =  0.6889550975220605
# values_col =  label
# processing feat: Path
# 2769 346 347
# e_roc_auc =  0.801243853993683
# 2769 346 347
# e_roc_auc =  0.8039953111263064
# 2769 346 347
# e_roc_auc =  0.7853375012210608
# 2769 346 347
# e_roc_auc =  0.7772133763146756
# 2769 346 347
# e_roc_auc =  0.7924847774413077
# values_col =  label
# processing feat: Matrix
# 2769 346 347
# e_roc_auc =  0.8720328221158542
# 2769 346 347
# e_roc_auc =  0.8536517860050143
# 2769 346 347
# e_roc_auc =  0.8125590179414541
# 2769 346 347
# e_roc_auc =  0.8247533457067501
# 2769 346 347
# e_roc_auc =  0.8633714304320929
# values_col =  label
# processing feat: InfoContent
# 2769 346 347
# e_roc_auc =  0.8355638045000162
# 2769 346 347
# e_roc_auc =  0.8380059262153626
# 2769 346 347
# e_roc_auc =  0.8345706750024422
# 2769 346 347
# e_roc_auc =  0.8575917423724397
# 2769 346 347
# e_roc_auc =  0.8325355735729869
